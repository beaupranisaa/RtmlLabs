# %%
import torchvision
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.datasets import CocoDetection
import torch

import utils
from coco_utils_city import get_city
import transforms

# Load a model pre-trained on COCO and put it in inference mode

print('Loading pretrained model...')
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
model.eval()

# Load the COCO 2017 train and val sets. We use the CocoDetection class definition
# from ./coco_utils.py, not the original torchvision.CocoDetection class. Also, we
# use transforms from ./transforms, not torchvision.transforms, because they need
# to transform the bboxes and masks along with the image.

# coco_path = "./COCO"

preprocess = transforms.Compose([
    transforms.ToTensor()
])
print('Loading Cityscapes train, val datasets...')
coco_train_dataset = get_city('train',preprocess)
coco_val_dataset = get_city('val',preprocess)

def collate_fn(batch):
    return tuple(zip(*batch))

train_dataloader = torch.utils.data.DataLoader(coco_train_dataset, batch_size=1, shuffle=True, num_workers=0, collate_fn=collate_fn)
val_dataloader = torch.utils.data.DataLoader(coco_val_dataset, batch_size=1, shuffle=False, num_workers=0, collate_fn=collate_fn)
# Out:
# Loading pretrained model...
# Loading Cityscapes train, val datasets...
# loading annotations into memory...
# Done (t=5.73s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.00s)
# creating index...
# index created!

# %%
from chosen_gpu import get_freer_gpu
device = torch.device(get_freer_gpu())# if torch.cuda.is_available() else torch.device("cpu")
print("Configured device: ", device)
# Out:
# Configured device:  cuda:1

# %%
#put model to device
model.to(device)
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign()
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign()
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 91, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt

# Array of labels for COCO dataset (91 elements)

coco_names = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Random colors to use for labeling objects

COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3)).astype(np.uint8)

# Overlay masks, bounding boxes, and labels on input numpy image

def draw_segmentation_map(image, masks, boxes, labels):
    alpha = 1
    beta = 0.5 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # convert from RGB to OpenCV BGR format
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    for i in range(len(masks)):
        mask = masks[i,:,:]
        red_map = np.zeros_like(mask).astype(np.uint8)
        green_map = np.zeros_like(mask).astype(np.uint8)
        blue_map = np.zeros_like(mask).astype(np.uint8)
        # apply a randon color mask to each object
        color = COLORS[random.randrange(0, len(COLORS))]
        red_map[mask > 0.5] = color[0]
        green_map[mask > 0.5] = color[1]
        blue_map[mask > 0.5] = color[2]
        # combine all the masks into a single image
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
        # apply colored mask to the image
        image = cv2.addWeighted(image, alpha, segmentation_map, beta, gamma)
        # draw the bounding box around each object
        p1 = (int(boxes[i][0]), int(boxes[i][1]))
        p2 = (int(boxes[i][2]), int(boxes[i][3]))
        color = (int(color[0]), int(color[1]), int(color[2]))
        cv2.rectangle(image, p1, p2, color, 2)
        # put the label text above the objects
        p = (int(boxes[i][0]), int(boxes[i][1]-10))
        cv2.putText(image, labels[i], p, cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Overlay masks, bounding boxes, and labels of objects with scores greater than
# threshold on one of the images in the input tensor using the predictions output by Mask R-CNN.

def prediction_to_mask_image(images, predictions, img_index, threshold):
    scores = predictions[img_index]['scores']
    boxes_to_use = scores >= threshold
    img = (images[img_index].cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    masks = predictions[img_index]['masks'][boxes_to_use, :, :].cpu().detach().squeeze(1).numpy()
    boxes = predictions[img_index]['boxes'][boxes_to_use, :].cpu().detach().numpy()
    labels = predictions[img_index]['labels'][boxes_to_use].cpu().numpy()
    labels = [ coco_names[l] for l in labels ]

    return draw_segmentation_map(img, masks, boxes, labels)

# %%
from engine import train_one_epoch, evaluate
import utils
# Training
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=3,gamma=0.1)
num_epochs = 10
for epoch in range(num_epochs):
    
    # train for one epoch, printing every 10 iterations
    print(f"=========== {epoch} ===========")
    # Save Image
    model.eval()
    images, targets = next(iter(val_dataloader))
    images = [img.to(device) for img in images]
    predictions = model(images)
    masked_img = prediction_to_mask_image(images, predictions, 0, 0.5)
    plt.imsave(f'city_results/images/epoch-{epoch}.jpg',masked_img)    
    torch.save(model.state_dict(), ('city_results/weights/mask-rcnn-%02d-epochs.pth' % epoch))
    
    train_one_epoch(model, optimizer, train_dataloader, device, epoch, print_freq=10)
    lr_scheduler.step()
    evaluate(model, val_dataloader, device=device)

# for images, targets in train_dataloader:
#     images = list(image.to(device) for image in images)
#     targets = [{k: v for k, v in t.items()} for t in targets]
#     output = model(images,targets)   # Returns losses and detections
#     print(output)
#     break
# Out:
# =========== 0 ===========
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# Epoch: [0]  [   0/2965]  eta: 0:21:37  lr: 0.000010  loss: 0.8201 (0.8201)  loss_classifier: 0.3281 (0.3281)  loss_box_reg: 0.1202 (0.1202)  loss_mask: 0.1905 (0.1905)  loss_objectness: 0.1109 (0.1109)  loss_rpn_box_reg: 0.0704 (0.0704)  time: 0.4376  data: 0.2165  max mem: 0
# Epoch: [0]  [  10/2965]  eta: 0:19:19  lr: 0.000060  loss: 1.4559 (1.3967)  loss_classifier: 0.3281 (0.4810)  loss_box_reg: 0.3645 (0.3427)  loss_mask: 0.2919 (0.3070)  loss_objectness: 0.0791 (0.0867)  loss_rpn_box_reg: 0.1723 (0.1794)  time: 0.3925  data: 0.2138  max mem: 0
# Epoch: [0]  [  20/2965]  eta: 0:19:21  lr: 0.000110  loss: 1.4662 (1.4534)  loss_classifier: 0.2769 (0.4374)  loss_box_reg: 0.3452 (0.3541)  loss_mask: 0.2919 (0.3070)  loss_objectness: 0.0791 (0.1150)  loss_rpn_box_reg: 0.2500 (0.2398)  time: 0.3922  data: 0.2181  max mem: 0
# Epoch: [0]  [  30/2965]  eta: 0:19:16  lr: 0.000160  loss: 1.5580 (1.5080)  loss_classifier: 0.2607 (0.4134)  loss_box_reg: 0.3436 (0.3601)  loss_mask: 0.3028 (0.3223)  loss_objectness: 0.0722 (0.1696)  loss_rpn_box_reg: 0.2666 (0.2425)  time: 0.3950  data: 0.2214  max mem: 0
# Epoch: [0]  [  40/2965]  eta: 0:18:46  lr: 0.000210  loss: 1.3058 (1.4797)  loss_classifier: 0.2520 (0.4082)  loss_box_reg: 0.3546 (0.3591)  loss_mask: 0.3835 (0.3391)  loss_objectness: 0.0699 (0.1476)  loss_rpn_box_reg: 0.1915 (0.2257)  time: 0.3753  data: 0.2044  max mem: 0
# Epoch: [0]  [  50/2965]  eta: 0:18:35  lr: 0.000260  loss: 1.3058 (1.4548)  loss_classifier: 0.3031 (0.4106)  loss_box_reg: 0.4186 (0.3689)  loss_mask: 0.3677 (0.3372)  loss_objectness: 0.0518 (0.1282)  loss_rpn_box_reg: 0.1068 (0.2098)  time: 0.3649  data: 0.1945  max mem: 0
# Epoch: [0]  [  60/2965]  eta: 0:18:23  lr: 0.000310  loss: 1.4047 (1.4441)  loss_classifier: 0.3390 (0.4080)  loss_box_reg: 0.3886 (0.3670)  loss_mask: 0.3618 (0.3456)  loss_objectness: 0.0535 (0.1196)  loss_rpn_box_reg: 0.0747 (0.2039)  time: 0.3694  data: 0.1992  max mem: 0
# Epoch: [0]  [  70/2965]  eta: 0:18:55  lr: 0.000360  loss: 1.4538 (1.4582)  loss_classifier: 0.3390 (0.4146)  loss_box_reg: 0.3436 (0.3742)  loss_mask: 0.3734 (0.3470)  loss_objectness: 0.0701 (0.1152)  loss_rpn_box_reg: 0.1112 (0.2072)  time: 0.4161  data: 0.2426  max mem: 0
# Epoch: [0]  [  80/2965]  eta: 0:19:07  lr: 0.000410  loss: 1.5823 (1.4615)  loss_classifier: 0.2818 (0.4018)  loss_box_reg: 0.4031 (0.3763)  loss_mask: 0.4025 (0.3465)  loss_objectness: 0.0777 (0.1173)  loss_rpn_box_reg: 0.2571 (0.2195)  time: 0.4520  data: 0.2738  max mem: 0
# Epoch: [0]  [  90/2965]  eta: 0:18:43  lr: 0.000460  loss: 1.1698 (1.4073)  loss_classifier: 0.1988 (0.3796)  loss_box_reg: 0.3235 (0.3658)  loss_mask: 0.2752 (0.3384)  loss_objectness: 0.0617 (0.1112)  loss_rpn_box_reg: 0.1947 (0.2123)  time: 0.3866  data: 0.2138  max mem: 0
# Epoch: [0]  [ 100/2965]  eta: 0:18:31  lr: 0.000509  loss: 1.0714 (1.3930)  loss_classifier: 0.1988 (0.3784)  loss_box_reg: 0.3034 (0.3590)  loss_mask: 0.2695 (0.3337)  loss_objectness: 0.0465 (0.1043)  loss_rpn_box_reg: 0.1124 (0.2176)  time: 0.3479  data: 0.1787  max mem: 0
# Epoch: [0]  [ 110/2965]  eta: 0:18:22  lr: 0.000559  loss: 1.0868 (1.3808)  loss_classifier: 0.2101 (0.3701)  loss_box_reg: 0.3453 (0.3588)  loss_mask: 0.2972 (0.3359)  loss_objectness: 0.0339 (0.0986)  loss_rpn_box_reg: 0.2093 (0.2174)  time: 0.3646  data: 0.1947  max mem: 0
# Epoch: [0]  [ 120/2965]  eta: 0:18:17  lr: 0.000609  loss: 1.1589 (1.3859)  loss_classifier: 0.2675 (0.3681)  loss_box_reg: 0.3863 (0.3608)  loss_mask: 0.3486 (0.3372)  loss_objectness: 0.0357 (0.0978)  loss_rpn_box_reg: 0.2225 (0.2219)  time: 0.3745  data: 0.2026  max mem: 0
# Epoch: [0]  [ 130/2965]  eta: 0:18:11  lr: 0.000659  loss: 1.3053 (1.3829)  loss_classifier: 0.2741 (0.3643)  loss_box_reg: 0.3831 (0.3625)  loss_mask: 0.3354 (0.3355)  loss_objectness: 0.0445 (0.0964)  loss_rpn_box_reg: 0.2383 (0.2242)  time: 0.3788  data: 0.2046  max mem: 0
# Epoch: [0]  [ 140/2965]  eta: 0:18:05  lr: 0.000709  loss: 1.1122 (1.3765)  loss_classifier: 0.2167 (0.3583)  loss_box_reg: 0.3831 (0.3637)  loss_mask: 0.3092 (0.3345)  loss_objectness: 0.0490 (0.0947)  loss_rpn_box_reg: 0.1209 (0.2253)  time: 0.3769  data: 0.2026  max mem: 0
# Epoch: [0]  [ 150/2965]  eta: 0:18:02  lr: 0.000759  loss: 1.1484 (1.3808)  loss_classifier: 0.2227 (0.3541)  loss_box_reg: 0.3675 (0.3638)  loss_mask: 0.3058 (0.3327)  loss_objectness: 0.0709 (0.0955)  loss_rpn_box_reg: 0.1976 (0.2346)  time: 0.3814  data: 0.2071  max mem: 0
# Epoch: [0]  [ 160/2965]  eta: 0:17:58  lr: 0.000809  loss: 1.3167 (1.3630)  loss_classifier: 0.2323 (0.3469)  loss_box_reg: 0.3645 (0.3615)  loss_mask: 0.3006 (0.3302)  loss_objectness: 0.0588 (0.0933)  loss_rpn_box_reg: 0.2531 (0.2311)  time: 0.3844  data: 0.2115  max mem: 0
# Epoch: [0]  [ 170/2965]  eta: 0:17:59  lr: 0.000859  loss: 1.0933 (1.3556)  loss_classifier: 0.1919 (0.3430)  loss_box_reg: 0.3398 (0.3622)  loss_mask: 0.2851 (0.3294)  loss_objectness: 0.0501 (0.0918)  loss_rpn_box_reg: 0.1930 (0.2293)  time: 0.4002  data: 0.2237  max mem: 0
# Epoch: [0]  [ 180/2965]  eta: 0:17:56  lr: 0.000909  loss: 1.0889 (1.3517)  loss_classifier: 0.2213 (0.3409)  loss_box_reg: 0.3632 (0.3632)  loss_mask: 0.3363 (0.3304)  loss_objectness: 0.0416 (0.0916)  loss_rpn_box_reg: 0.0958 (0.2255)  time: 0.4039  data: 0.2269  max mem: 0
# Epoch: [0]  [ 190/2965]  eta: 0:17:55  lr: 0.000959  loss: 1.2999 (1.3521)  loss_classifier: 0.2509 (0.3384)  loss_box_reg: 0.3758 (0.3643)  loss_mask: 0.3205 (0.3289)  loss_objectness: 0.0557 (0.0913)  loss_rpn_box_reg: 0.2268 (0.2291)  time: 0.3995  data: 0.2248  max mem: 0
# Epoch: [0]  [ 200/2965]  eta: 0:17:51  lr: 0.001009  loss: 1.2036 (1.3359)  loss_classifier: 0.2244 (0.3320)  loss_box_reg: 0.3380 (0.3602)  loss_mask: 0.3034 (0.3271)  loss_objectness: 0.0593 (0.0897)  loss_rpn_box_reg: 0.2378 (0.2269)  time: 0.3953  data: 0.2214  max mem: 0
# Epoch: [0]  [ 210/2965]  eta: 0:17:46  lr: 0.001059  loss: 1.0554 (1.3250)  loss_classifier: 0.2359 (0.3296)  loss_box_reg: 0.3368 (0.3593)  loss_mask: 0.3034 (0.3252)  loss_objectness: 0.0460 (0.0879)  loss_rpn_box_reg: 0.1258 (0.2230)  time: 0.3819  data: 0.2102  max mem: 0
# Epoch: [0]  [ 220/2965]  eta: 0:17:47  lr: 0.001109  loss: 1.3200 (1.3219)  loss_classifier: 0.2784 (0.3300)  loss_box_reg: 0.3604 (0.3584)  loss_mask: 0.2917 (0.3234)  loss_objectness: 0.0440 (0.0864)  loss_rpn_box_reg: 0.1258 (0.2237)  time: 0.4019  data: 0.2283  max mem: 0
# Epoch: [0]  [ 230/2965]  eta: 0:17:41  lr: 0.001159  loss: 1.1934 (1.3152)  loss_classifier: 0.2196 (0.3255)  loss_box_reg: 0.3188 (0.3569)  loss_mask: 0.2881 (0.3228)  loss_objectness: 0.0726 (0.0879)  loss_rpn_box_reg: 0.1368 (0.2219)  time: 0.3981  data: 0.2248  max mem: 0
# Epoch: [0]  [ 240/2965]  eta: 0:17:34  lr: 0.001209  loss: 1.1934 (1.3107)  loss_classifier: 0.2196 (0.3228)  loss_box_reg: 0.3430 (0.3560)  loss_mask: 0.2908 (0.3211)  loss_objectness: 0.0608 (0.0868)  loss_rpn_box_reg: 0.2159 (0.2240)  time: 0.3688  data: 0.1976  max mem: 0
# Epoch: [0]  [ 250/2965]  eta: 0:17:29  lr: 0.001259  loss: 1.3236 (1.3051)  loss_classifier: 0.2640 (0.3214)  loss_box_reg: 0.3744 (0.3546)  loss_mask: 0.3169 (0.3204)  loss_objectness: 0.0416 (0.0851)  loss_rpn_box_reg: 0.2502 (0.2237)  time: 0.3680  data: 0.1968  max mem: 0
# Epoch: [0]  [ 260/2965]  eta: 0:17:26  lr: 0.001309  loss: 1.4280 (1.3186)  loss_classifier: 0.3042 (0.3240)  loss_box_reg: 0.3984 (0.3585)  loss_mask: 0.3188 (0.3215)  loss_objectness: 0.0416 (0.0854)  loss_rpn_box_reg: 0.2502 (0.2293)  time: 0.3860  data: 0.2118  max mem: 0
# Epoch: [0]  [ 270/2965]  eta: 0:17:23  lr: 0.001359  loss: 1.3525 (1.3142)  loss_classifier: 0.2728 (0.3222)  loss_box_reg: 0.4094 (0.3583)  loss_mask: 0.2766 (0.3196)  loss_objectness: 0.0563 (0.0847)  loss_rpn_box_reg: 0.2427 (0.2295)  time: 0.3980  data: 0.2204  max mem: 0
# Epoch: [0]  [ 280/2965]  eta: 0:17:23  lr: 0.001409  loss: 1.2117 (1.3086)  loss_classifier: 0.2394 (0.3208)  loss_box_reg: 0.3777 (0.3583)  loss_mask: 0.2763 (0.3191)  loss_objectness: 0.0441 (0.0834)  loss_rpn_box_reg: 0.1885 (0.2270)  time: 0.4109  data: 0.2336  max mem: 0
# Epoch: [0]  [ 290/2965]  eta: 0:17:15  lr: 0.001459  loss: 1.2134 (1.3057)  loss_classifier: 0.2627 (0.3182)  loss_box_reg: 0.3727 (0.3581)  loss_mask: 0.3066 (0.3189)  loss_objectness: 0.0446 (0.0827)  loss_rpn_box_reg: 0.1681 (0.2278)  time: 0.3860  data: 0.2120  max mem: 0
# Epoch: [0]  [ 300/2965]  eta: 0:17:10  lr: 0.001508  loss: 1.1001 (1.2995)  loss_classifier: 0.2254 (0.3156)  loss_box_reg: 0.3195 (0.3567)  loss_mask: 0.2956 (0.3173)  loss_objectness: 0.0446 (0.0814)  loss_rpn_box_reg: 0.1938 (0.2285)  time: 0.3586  data: 0.1858  max mem: 0
# Epoch: [0]  [ 310/2965]  eta: 0:17:06  lr: 0.001558  loss: 1.1746 (1.3008)  loss_classifier: 0.2231 (0.3146)  loss_box_reg: 0.3653 (0.3580)  loss_mask: 0.2956 (0.3189)  loss_objectness: 0.0480 (0.0806)  loss_rpn_box_reg: 0.1956 (0.2287)  time: 0.3746  data: 0.2012  max mem: 0
# Epoch: [0]  [ 320/2965]  eta: 0:17:00  lr: 0.001608  loss: 1.1969 (1.2946)  loss_classifier: 0.2380 (0.3121)  loss_box_reg: 0.3783 (0.3570)  loss_mask: 0.3465 (0.3183)  loss_objectness: 0.0480 (0.0804)  loss_rpn_box_reg: 0.2037 (0.2268)  time: 0.3727  data: 0.2008  max mem: 0
# Epoch: [0]  [ 330/2965]  eta: 0:16:52  lr: 0.001658  loss: 1.1172 (1.2887)  loss_classifier: 0.2001 (0.3103)  loss_box_reg: 0.3350 (0.3562)  loss_mask: 0.2981 (0.3183)  loss_objectness: 0.0372 (0.0798)  loss_rpn_box_reg: 0.0720 (0.2241)  time: 0.3492  data: 0.1796  max mem: 0
# Epoch: [0]  [ 340/2965]  eta: 0:16:47  lr: 0.001708  loss: 1.0167 (1.2814)  loss_classifier: 0.2448 (0.3078)  loss_box_reg: 0.3295 (0.3551)  loss_mask: 0.2981 (0.3166)  loss_objectness: 0.0411 (0.0790)  loss_rpn_box_reg: 0.0706 (0.2229)  time: 0.3489  data: 0.1790  max mem: 0
# Epoch: [0]  [ 350/2965]  eta: 0:16:42  lr: 0.001758  loss: 1.2624 (1.2833)  loss_classifier: 0.2368 (0.3065)  loss_box_reg: 0.3387 (0.3548)  loss_mask: 0.3150 (0.3170)  loss_objectness: 0.0394 (0.0781)  loss_rpn_box_reg: 0.2155 (0.2269)  time: 0.3702  data: 0.1984  max mem: 0
# Epoch: [0]  [ 360/2965]  eta: 0:16:41  lr: 0.001808  loss: 1.2991 (1.2870)  loss_classifier: 0.2720 (0.3059)  loss_box_reg: 0.3871 (0.3555)  loss_mask: 0.3177 (0.3179)  loss_objectness: 0.0438 (0.0780)  loss_rpn_box_reg: 0.3583 (0.2297)  time: 0.3960  data: 0.2221  max mem: 0
# Epoch: [0]  [ 370/2965]  eta: 0:16:38  lr: 0.001858  loss: 1.2945 (1.2849)  loss_classifier: 0.2578 (0.3041)  loss_box_reg: 0.4051 (0.3554)  loss_mask: 0.3184 (0.3180)  loss_objectness: 0.0527 (0.0778)  loss_rpn_box_reg: 0.2463 (0.2296)  time: 0.4108  data: 0.2347  max mem: 0
# Epoch: [0]  [ 380/2965]  eta: 0:16:35  lr: 0.001908  loss: 1.1398 (1.2818)  loss_classifier: 0.2371 (0.3027)  loss_box_reg: 0.3569 (0.3552)  loss_mask: 0.3231 (0.3183)  loss_objectness: 0.0528 (0.0774)  loss_rpn_box_reg: 0.1653 (0.2282)  time: 0.3968  data: 0.2214  max mem: 0
# Epoch: [0]  [ 390/2965]  eta: 0:16:30  lr: 0.001958  loss: 1.1506 (1.2778)  loss_classifier: 0.2371 (0.3019)  loss_box_reg: 0.3777 (0.3555)  loss_mask: 0.3240 (0.3178)  loss_objectness: 0.0581 (0.0767)  loss_rpn_box_reg: 0.1106 (0.2260)  time: 0.3837  data: 0.2098  max mem: 0
# Epoch: [0]  [ 400/2965]  eta: 0:16:26  lr: 0.002008  loss: 1.2153 (1.2793)  loss_classifier: 0.2469 (0.3020)  loss_box_reg: 0.4134 (0.3569)  loss_mask: 0.3240 (0.3183)  loss_objectness: 0.0475 (0.0762)  loss_rpn_box_reg: 0.1563 (0.2259)  time: 0.3760  data: 0.2020  max mem: 0
# Epoch: [0]  [ 410/2965]  eta: 0:16:23  lr: 0.002058  loss: 1.4378 (1.2876)  loss_classifier: 0.3262 (0.3031)  loss_box_reg: 0.4552 (0.3599)  loss_mask: 0.3380 (0.3197)  loss_objectness: 0.0630 (0.0775)  loss_rpn_box_reg: 0.1897 (0.2273)  time: 0.3908  data: 0.2140  max mem: 0
# Epoch: [0]  [ 420/2965]  eta: 0:16:19  lr: 0.002108  loss: 1.4378 (1.2885)  loss_classifier: 0.2786 (0.3022)  loss_box_reg: 0.4584 (0.3602)  loss_mask: 0.3736 (0.3200)  loss_objectness: 0.0700 (0.0775)  loss_rpn_box_reg: 0.2721 (0.2287)  time: 0.3889  data: 0.2127  max mem: 0
# Epoch: [0]  [ 430/2965]  eta: 0:16:23  lr: 0.002158  loss: 1.4609 (1.2958)  loss_classifier: 0.2724 (0.3027)  loss_box_reg: 0.4121 (0.3618)  loss_mask: 0.3487 (0.3210)  loss_objectness: 0.0780 (0.0780)  loss_rpn_box_reg: 0.3310 (0.2323)  time: 0.4436  data: 0.2629  max mem: 0
# Epoch: [0]  [ 440/2965]  eta: 0:16:20  lr: 0.002208  loss: 1.4717 (1.3049)  loss_classifier: 0.2872 (0.3023)  loss_box_reg: 0.4195 (0.3628)  loss_mask: 0.3381 (0.3207)  loss_objectness: 0.0630 (0.0795)  loss_rpn_box_reg: 0.3447 (0.2395)  time: 0.4645  data: 0.2812  max mem: 0
# Epoch: [0]  [ 450/2965]  eta: 0:16:14  lr: 0.002258  loss: 1.3568 (1.3025)  loss_classifier: 0.2570 (0.3015)  loss_box_reg: 0.3878 (0.3631)  loss_mask: 0.3007 (0.3210)  loss_objectness: 0.0548 (0.0790)  loss_rpn_box_reg: 0.2584 (0.2380)  time: 0.3831  data: 0.2067  max mem: 0
# Epoch: [0]  [ 460/2965]  eta: 0:16:08  lr: 0.002308  loss: 1.2008 (1.3002)  loss_classifier: 0.2500 (0.3003)  loss_box_reg: 0.3801 (0.3634)  loss_mask: 0.3046 (0.3207)  loss_objectness: 0.0548 (0.0788)  loss_rpn_box_reg: 0.1377 (0.2369)  time: 0.3503  data: 0.1771  max mem: 0
# Epoch: [0]  [ 470/2965]  eta: 0:16:05  lr: 0.002358  loss: 1.1915 (1.2995)  loss_classifier: 0.2570 (0.2998)  loss_box_reg: 0.3868 (0.3640)  loss_mask: 0.2775 (0.3204)  loss_objectness: 0.0553 (0.0785)  loss_rpn_box_reg: 0.1348 (0.2368)  time: 0.3741  data: 0.1993  max mem: 0
# Epoch: [0]  [ 480/2965]  eta: 0:16:00  lr: 0.002408  loss: 1.0729 (1.2971)  loss_classifier: 0.2570 (0.2987)  loss_box_reg: 0.3868 (0.3642)  loss_mask: 0.2845 (0.3205)  loss_objectness: 0.0374 (0.0783)  loss_rpn_box_reg: 0.0674 (0.2354)  time: 0.3823  data: 0.2072  max mem: 0
# Epoch: [0]  [ 490/2965]  eta: 0:15:54  lr: 0.002458  loss: 1.0639 (1.2937)  loss_classifier: 0.2134 (0.2971)  loss_box_reg: 0.3341 (0.3638)  loss_mask: 0.2864 (0.3202)  loss_objectness: 0.0332 (0.0777)  loss_rpn_box_reg: 0.0426 (0.2350)  time: 0.3536  data: 0.1818  max mem: 0
# Epoch: [0]  [ 500/2965]  eta: 0:15:50  lr: 0.002507  loss: 1.1758 (1.2951)  loss_classifier: 0.2134 (0.2971)  loss_box_reg: 0.4144 (0.3650)  loss_mask: 0.3179 (0.3207)  loss_objectness: 0.0380 (0.0779)  loss_rpn_box_reg: 0.0814 (0.2344)  time: 0.3628  data: 0.1883  max mem: 0
# Epoch: [0]  [ 510/2965]  eta: 0:15:44  lr: 0.002557  loss: 1.2893 (1.2956)  loss_classifier: 0.2365 (0.2970)  loss_box_reg: 0.4440 (0.3660)  loss_mask: 0.3289 (0.3212)  loss_objectness: 0.0839 (0.0779)  loss_rpn_box_reg: 0.1181 (0.2335)  time: 0.3656  data: 0.1893  max mem: 0
# Epoch: [0]  [ 520/2965]  eta: 0:15:40  lr: 0.002607  loss: 1.2363 (1.2949)  loss_classifier: 0.2412 (0.2969)  loss_box_reg: 0.3807 (0.3663)  loss_mask: 0.3077 (0.3212)  loss_objectness: 0.0691 (0.0774)  loss_rpn_box_reg: 0.1473 (0.2330)  time: 0.3577  data: 0.1841  max mem: 0
# Epoch: [0]  [ 530/2965]  eta: 0:15:36  lr: 0.002657  loss: 1.3310 (1.2969)  loss_classifier: 0.2779 (0.2967)  loss_box_reg: 0.3912 (0.3676)  loss_mask: 0.3047 (0.3211)  loss_objectness: 0.0540 (0.0772)  loss_rpn_box_reg: 0.2200 (0.2343)  time: 0.3762  data: 0.2009  max mem: 0
# Epoch: [0]  [ 540/2965]  eta: 0:15:33  lr: 0.002707  loss: 1.4828 (1.2971)  loss_classifier: 0.2918 (0.2964)  loss_box_reg: 0.4280 (0.3686)  loss_mask: 0.3298 (0.3212)  loss_objectness: 0.0354 (0.0768)  loss_rpn_box_reg: 0.2539 (0.2342)  time: 0.3999  data: 0.2214  max mem: 0
# Epoch: [0]  [ 550/2965]  eta: 0:15:28  lr: 0.002757  loss: 1.1473 (1.2944)  loss_classifier: 0.2658 (0.2950)  loss_box_reg: 0.3503 (0.3681)  loss_mask: 0.2978 (0.3206)  loss_objectness: 0.0354 (0.0763)  loss_rpn_box_reg: 0.2157 (0.2344)  time: 0.3818  data: 0.2068  max mem: 0
# Epoch: [0]  [ 560/2965]  eta: 0:15:22  lr: 0.002807  loss: 1.0960 (1.2930)  loss_classifier: 0.2114 (0.2954)  loss_box_reg: 0.3444 (0.3683)  loss_mask: 0.2978 (0.3211)  loss_objectness: 0.0389 (0.0759)  loss_rpn_box_reg: 0.0809 (0.2323)  time: 0.3443  data: 0.1742  max mem: 0
# Epoch: [0]  [ 570/2965]  eta: 0:15:18  lr: 0.002857  loss: 1.0654 (1.2895)  loss_classifier: 0.2114 (0.2944)  loss_box_reg: 0.3087 (0.3675)  loss_mask: 0.3153 (0.3206)  loss_objectness: 0.0453 (0.0757)  loss_rpn_box_reg: 0.0661 (0.2314)  time: 0.3524  data: 0.1807  max mem: 0
# Epoch: [0]  [ 580/2965]  eta: 0:15:14  lr: 0.002907  loss: 1.2560 (1.2914)  loss_classifier: 0.2754 (0.2944)  loss_box_reg: 0.4142 (0.3687)  loss_mask: 0.3160 (0.3213)  loss_objectness: 0.0520 (0.0755)  loss_rpn_box_reg: 0.0934 (0.2315)  time: 0.3733  data: 0.1985  max mem: 0
# Epoch: [0]  [ 590/2965]  eta: 0:15:09  lr: 0.002957  loss: 1.4047 (1.2928)  loss_classifier: 0.3110 (0.2949)  loss_box_reg: 0.3799 (0.3689)  loss_mask: 0.3346 (0.3208)  loss_objectness: 0.0712 (0.0764)  loss_rpn_box_reg: 0.2608 (0.2318)  time: 0.3743  data: 0.1997  max mem: 0
# Epoch: [0]  [ 600/2965]  eta: 0:15:06  lr: 0.003007  loss: 1.4020 (1.2926)  loss_classifier: 0.2503 (0.2942)  loss_box_reg: 0.3670 (0.3687)  loss_mask: 0.2822 (0.3200)  loss_objectness: 0.0855 (0.0768)  loss_rpn_box_reg: 0.2679 (0.2329)  time: 0.3802  data: 0.2052  max mem: 0
# Epoch: [0]  [ 610/2965]  eta: 0:15:02  lr: 0.003057  loss: 1.4020 (1.2925)  loss_classifier: 0.2712 (0.2940)  loss_box_reg: 0.4229 (0.3696)  loss_mask: 0.2822 (0.3200)  loss_objectness: 0.0806 (0.0767)  loss_rpn_box_reg: 0.2618 (0.2322)  time: 0.3873  data: 0.2126  max mem: 0
# Epoch: [0]  [ 620/2965]  eta: 0:14:59  lr: 0.003107  loss: 1.4688 (1.2961)  loss_classifier: 0.3287 (0.2955)  loss_box_reg: 0.4526 (0.3707)  loss_mask: 0.3735 (0.3208)  loss_objectness: 0.0597 (0.0767)  loss_rpn_box_reg: 0.1880 (0.2324)  time: 0.3933  data: 0.2187  max mem: 0
# Epoch: [0]  [ 630/2965]  eta: 0:14:54  lr: 0.003157  loss: 1.4212 (1.2973)  loss_classifier: 0.3287 (0.2949)  loss_box_reg: 0.3827 (0.3708)  loss_mask: 0.3703 (0.3214)  loss_objectness: 0.0565 (0.0766)  loss_rpn_box_reg: 0.2156 (0.2336)  time: 0.3771  data: 0.2044  max mem: 0
# Epoch: [0]  [ 640/2965]  eta: 0:14:52  lr: 0.003207  loss: 1.2706 (1.2974)  loss_classifier: 0.2695 (0.2947)  loss_box_reg: 0.3575 (0.3709)  loss_mask: 0.3098 (0.3215)  loss_objectness: 0.0662 (0.0766)  loss_rpn_box_reg: 0.2109 (0.2337)  time: 0.3899  data: 0.2152  max mem: 0
# Epoch: [0]  [ 650/2965]  eta: 0:14:49  lr: 0.003257  loss: 1.4728 (1.3019)  loss_classifier: 0.2785 (0.2956)  loss_box_reg: 0.3971 (0.3722)  loss_mask: 0.3518 (0.3224)  loss_objectness: 0.0686 (0.0765)  loss_rpn_box_reg: 0.2887 (0.2352)  time: 0.4265  data: 0.2471  max mem: 0
# Epoch: [0]  [ 660/2965]  eta: 0:14:45  lr: 0.003307  loss: 1.3871 (1.3008)  loss_classifier: 0.2785 (0.2951)  loss_box_reg: 0.3971 (0.3717)  loss_mask: 0.3282 (0.3216)  loss_objectness: 0.0541 (0.0762)  loss_rpn_box_reg: 0.3350 (0.2362)  time: 0.3952  data: 0.2194  max mem: 0
# Epoch: [0]  [ 670/2965]  eta: 0:14:42  lr: 0.003357  loss: 1.2815 (1.3002)  loss_classifier: 0.2564 (0.2945)  loss_box_reg: 0.3592 (0.3715)  loss_mask: 0.2688 (0.3215)  loss_objectness: 0.0421 (0.0761)  loss_rpn_box_reg: 0.2806 (0.2366)  time: 0.3870  data: 0.2122  max mem: 0
# Epoch: [0]  [ 680/2965]  eta: 0:14:39  lr: 0.003407  loss: 1.1872 (1.2986)  loss_classifier: 0.2564 (0.2943)  loss_box_reg: 0.3592 (0.3714)  loss_mask: 0.2979 (0.3211)  loss_objectness: 0.0421 (0.0757)  loss_rpn_box_reg: 0.2399 (0.2361)  time: 0.4063  data: 0.2294  max mem: 0
# Epoch: [0]  [ 690/2965]  eta: 0:14:34  lr: 0.003457  loss: 1.1976 (1.2972)  loss_classifier: 0.2496 (0.2937)  loss_box_reg: 0.4140 (0.3713)  loss_mask: 0.3362 (0.3217)  loss_objectness: 0.0509 (0.0756)  loss_rpn_box_reg: 0.1080 (0.2350)  time: 0.3908  data: 0.2152  max mem: 0
# Epoch: [0]  [ 700/2965]  eta: 0:14:31  lr: 0.003506  loss: 1.2599 (1.2972)  loss_classifier: 0.2411 (0.2934)  loss_box_reg: 0.4140 (0.3718)  loss_mask: 0.3432 (0.3216)  loss_objectness: 0.0424 (0.0752)  loss_rpn_box_reg: 0.0984 (0.2352)  time: 0.3901  data: 0.2143  max mem: 0
# Epoch: [0]  [ 710/2965]  eta: 0:14:27  lr: 0.003556  loss: 1.2703 (1.2976)  loss_classifier: 0.2396 (0.2929)  loss_box_reg: 0.3960 (0.3717)  loss_mask: 0.3162 (0.3215)  loss_objectness: 0.0465 (0.0752)  loss_rpn_box_reg: 0.2965 (0.2364)  time: 0.3844  data: 0.2074  max mem: 0
# Epoch: [0]  [ 720/2965]  eta: 0:14:24  lr: 0.003606  loss: 1.3298 (1.2983)  loss_classifier: 0.2787 (0.2931)  loss_box_reg: 0.3994 (0.3725)  loss_mask: 0.3226 (0.3215)  loss_objectness: 0.0628 (0.0750)  loss_rpn_box_reg: 0.1873 (0.2363)  time: 0.3953  data: 0.2171  max mem: 0
# Epoch: [0]  [ 730/2965]  eta: 0:14:21  lr: 0.003656  loss: 1.3995 (1.2996)  loss_classifier: 0.2866 (0.2927)  loss_box_reg: 0.4234 (0.3729)  loss_mask: 0.3143 (0.3213)  loss_objectness: 0.0615 (0.0752)  loss_rpn_box_reg: 0.3432 (0.2376)  time: 0.4146  data: 0.2357  max mem: 0
# Epoch: [0]  [ 740/2965]  eta: 0:14:17  lr: 0.003706  loss: 1.3512 (1.3019)  loss_classifier: 0.2866 (0.2934)  loss_box_reg: 0.4102 (0.3743)  loss_mask: 0.3306 (0.3221)  loss_objectness: 0.0686 (0.0753)  loss_rpn_box_reg: 0.2087 (0.2368)  time: 0.3934  data: 0.2172  max mem: 0
# Epoch: [0]  [ 750/2965]  eta: 0:14:14  lr: 0.003756  loss: 1.3329 (1.3040)  loss_classifier: 0.2949 (0.2934)  loss_box_reg: 0.4102 (0.3746)  loss_mask: 0.3307 (0.3220)  loss_objectness: 0.0773 (0.0755)  loss_rpn_box_reg: 0.2087 (0.2385)  time: 0.4071  data: 0.2297  max mem: 0
# Epoch: [0]  [ 760/2965]  eta: 0:14:11  lr: 0.003806  loss: 1.4163 (1.3039)  loss_classifier: 0.2803 (0.2931)  loss_box_reg: 0.3608 (0.3746)  loss_mask: 0.2744 (0.3215)  loss_objectness: 0.0773 (0.0755)  loss_rpn_box_reg: 0.3107 (0.2391)  time: 0.4222  data: 0.2418  max mem: 0
# Epoch: [0]  [ 770/2965]  eta: 0:14:08  lr: 0.003856  loss: 1.3728 (1.3057)  loss_classifier: 0.3031 (0.2937)  loss_box_reg: 0.4043 (0.3754)  loss_mask: 0.2744 (0.3213)  loss_objectness: 0.0605 (0.0755)  loss_rpn_box_reg: 0.2332 (0.2398)  time: 0.4099  data: 0.2302  max mem: 0
# Epoch: [0]  [ 780/2965]  eta: 0:14:04  lr: 0.003906  loss: 1.3266 (1.3065)  loss_classifier: 0.2869 (0.2931)  loss_box_reg: 0.4217 (0.3759)  loss_mask: 0.3218 (0.3214)  loss_objectness: 0.0502 (0.0751)  loss_rpn_box_reg: 0.1845 (0.2410)  time: 0.3848  data: 0.2078  max mem: 0
# Epoch: [0]  [ 790/2965]  eta: 0:14:00  lr: 0.003956  loss: 1.2979 (1.3086)  loss_classifier: 0.2635 (0.2932)  loss_box_reg: 0.4198 (0.3766)  loss_mask: 0.3284 (0.3216)  loss_objectness: 0.0502 (0.0750)  loss_rpn_box_reg: 0.2530 (0.2423)  time: 0.3796  data: 0.2024  max mem: 0
# Epoch: [0]  [ 800/2965]  eta: 0:13:56  lr: 0.004006  loss: 1.2650 (1.3062)  loss_classifier: 0.2326 (0.2926)  loss_box_reg: 0.4031 (0.3760)  loss_mask: 0.3104 (0.3210)  loss_objectness: 0.0649 (0.0751)  loss_rpn_box_reg: 0.2157 (0.2415)  time: 0.3961  data: 0.2195  max mem: 0
# Epoch: [0]  [ 810/2965]  eta: 0:13:53  lr: 0.004056  loss: 1.2201 (1.3058)  loss_classifier: 0.1924 (0.2924)  loss_box_reg: 0.3632 (0.3758)  loss_mask: 0.2801 (0.3208)  loss_objectness: 0.0773 (0.0754)  loss_rpn_box_reg: 0.1715 (0.2414)  time: 0.3934  data: 0.2196  max mem: 0
# Epoch: [0]  [ 820/2965]  eta: 0:13:48  lr: 0.004106  loss: 1.2470 (1.3038)  loss_classifier: 0.1924 (0.2913)  loss_box_reg: 0.3632 (0.3753)  loss_mask: 0.2792 (0.3205)  loss_objectness: 0.0649 (0.0752)  loss_rpn_box_reg: 0.1925 (0.2415)  time: 0.3752  data: 0.2017  max mem: 0
# Epoch: [0]  [ 830/2965]  eta: 0:13:47  lr: 0.004156  loss: 1.2735 (1.3072)  loss_classifier: 0.2469 (0.2916)  loss_box_reg: 0.3924 (0.3762)  loss_mask: 0.3041 (0.3205)  loss_objectness: 0.0533 (0.0753)  loss_rpn_box_reg: 0.2425 (0.2435)  time: 0.4277  data: 0.2496  max mem: 0
# Epoch: [0]  [ 840/2965]  eta: 0:13:42  lr: 0.004206  loss: 1.2001 (1.3043)  loss_classifier: 0.2604 (0.2906)  loss_box_reg: 0.4140 (0.3753)  loss_mask: 0.2957 (0.3199)  loss_objectness: 0.0664 (0.0755)  loss_rpn_box_reg: 0.2525 (0.2430)  time: 0.4172  data: 0.2407  max mem: 0
# Epoch: [0]  [ 850/2965]  eta: 0:13:37  lr: 0.004256  loss: 1.1248 (1.3060)  loss_classifier: 0.1752 (0.2900)  loss_box_reg: 0.3328 (0.3749)  loss_mask: 0.2881 (0.3198)  loss_objectness: 0.0664 (0.0765)  loss_rpn_box_reg: 0.2525 (0.2448)  time: 0.3431  data: 0.1728  max mem: 0
# Epoch: [0]  [ 860/2965]  eta: 0:13:33  lr: 0.004306  loss: 1.3290 (1.3061)  loss_classifier: 0.2295 (0.2894)  loss_box_reg: 0.3646 (0.3751)  loss_mask: 0.3234 (0.3203)  loss_objectness: 0.0619 (0.0768)  loss_rpn_box_reg: 0.2705 (0.2445)  time: 0.3582  data: 0.1869  max mem: 0
# Epoch: [0]  [ 870/2965]  eta: 0:13:29  lr: 0.004356  loss: 1.2488 (1.3045)  loss_classifier: 0.2464 (0.2890)  loss_box_reg: 0.3831 (0.3750)  loss_mask: 0.3244 (0.3200)  loss_objectness: 0.0725 (0.0770)  loss_rpn_box_reg: 0.1209 (0.2435)  time: 0.3864  data: 0.2137  max mem: 0
# Epoch: [0]  [ 880/2965]  eta: 0:13:25  lr: 0.004406  loss: 1.2836 (1.3042)  loss_classifier: 0.2754 (0.2889)  loss_box_reg: 0.3632 (0.3748)  loss_mask: 0.2701 (0.3195)  loss_objectness: 0.0902 (0.0772)  loss_rpn_box_reg: 0.1501 (0.2437)  time: 0.3905  data: 0.2158  max mem: 0
# Epoch: [0]  [ 890/2965]  eta: 0:13:22  lr: 0.004456  loss: 1.3402 (1.3048)  loss_classifier: 0.2754 (0.2888)  loss_box_reg: 0.3857 (0.3751)  loss_mask: 0.3023 (0.3191)  loss_objectness: 0.0805 (0.0773)  loss_rpn_box_reg: 0.2978 (0.2445)  time: 0.3904  data: 0.2148  max mem: 0
# Epoch: [0]  [ 900/2965]  eta: 0:13:18  lr: 0.004505  loss: 1.3402 (1.3037)  loss_classifier: 0.2409 (0.2885)  loss_box_reg: 0.3818 (0.3752)  loss_mask: 0.3104 (0.3191)  loss_objectness: 0.0574 (0.0772)  loss_rpn_box_reg: 0.1985 (0.2437)  time: 0.3897  data: 0.2153  max mem: 0
# Epoch: [0]  [ 910/2965]  eta: 0:13:13  lr: 0.004555  loss: 1.1427 (1.3024)  loss_classifier: 0.2468 (0.2885)  loss_box_reg: 0.3592 (0.3752)  loss_mask: 0.2821 (0.3184)  loss_objectness: 0.0478 (0.0770)  loss_rpn_box_reg: 0.1665 (0.2433)  time: 0.3664  data: 0.1924  max mem: 0
# Epoch: [0]  [ 920/2965]  eta: 0:13:09  lr: 0.004605  loss: 1.1752 (1.3020)  loss_classifier: 0.2452 (0.2880)  loss_box_reg: 0.3592 (0.3751)  loss_mask: 0.2808 (0.3185)  loss_objectness: 0.0552 (0.0769)  loss_rpn_box_reg: 0.2214 (0.2435)  time: 0.3601  data: 0.1863  max mem: 0
# Epoch: [0]  [ 930/2965]  eta: 0:13:05  lr: 0.004655  loss: 1.2011 (1.3021)  loss_classifier: 0.2262 (0.2879)  loss_box_reg: 0.3766 (0.3753)  loss_mask: 0.2808 (0.3183)  loss_objectness: 0.0578 (0.0769)  loss_rpn_box_reg: 0.2311 (0.2437)  time: 0.3840  data: 0.2094  max mem: 0
# Epoch: [0]  [ 940/2965]  eta: 0:13:02  lr: 0.004705  loss: 1.4859 (1.3035)  loss_classifier: 0.3141 (0.2885)  loss_box_reg: 0.4140 (0.3763)  loss_mask: 0.3110 (0.3186)  loss_objectness: 0.0530 (0.0767)  loss_rpn_box_reg: 0.1480 (0.2434)  time: 0.4104  data: 0.2325  max mem: 0
# Epoch: [0]  [ 950/2965]  eta: 0:12:59  lr: 0.004755  loss: 1.3732 (1.3048)  loss_classifier: 0.3084 (0.2884)  loss_box_reg: 0.4248 (0.3766)  loss_mask: 0.3383 (0.3187)  loss_objectness: 0.0722 (0.0773)  loss_rpn_box_reg: 0.1960 (0.2438)  time: 0.4260  data: 0.2454  max mem: 0
# Epoch: [0]  [ 960/2965]  eta: 0:12:55  lr: 0.004805  loss: 1.3548 (1.3052)  loss_classifier: 0.2727 (0.2885)  loss_box_reg: 0.4248 (0.3765)  loss_mask: 0.3350 (0.3187)  loss_objectness: 0.0835 (0.0772)  loss_rpn_box_reg: 0.2755 (0.2444)  time: 0.3995  data: 0.2222  max mem: 0
# Epoch: [0]  [ 970/2965]  eta: 0:12:51  lr: 0.004855  loss: 1.1643 (1.3038)  loss_classifier: 0.2727 (0.2884)  loss_box_reg: 0.3774 (0.3760)  loss_mask: 0.3038 (0.3186)  loss_objectness: 0.0657 (0.0770)  loss_rpn_box_reg: 0.1795 (0.2438)  time: 0.3712  data: 0.1980  max mem: 0
# Epoch: [0]  [ 980/2965]  eta: 0:12:47  lr: 0.004905  loss: 1.1434 (1.3041)  loss_classifier: 0.2587 (0.2883)  loss_box_reg: 0.3681 (0.3762)  loss_mask: 0.3118 (0.3187)  loss_objectness: 0.0514 (0.0770)  loss_rpn_box_reg: 0.1795 (0.2440)  time: 0.3926  data: 0.2180  max mem: 0
# Epoch: [0]  [ 990/2965]  eta: 0:12:44  lr: 0.004955  loss: 1.4433 (1.3058)  loss_classifier: 0.2554 (0.2881)  loss_box_reg: 0.3681 (0.3765)  loss_mask: 0.3150 (0.3187)  loss_objectness: 0.0767 (0.0774)  loss_rpn_box_reg: 0.2768 (0.2452)  time: 0.4097  data: 0.2325  max mem: 0
# Epoch: [0]  [1000/2965]  eta: 0:12:41  lr: 0.005000  loss: 1.5449 (1.3069)  loss_classifier: 0.3002 (0.2881)  loss_box_reg: 0.4372 (0.3770)  loss_mask: 0.3235 (0.3189)  loss_objectness: 0.0939 (0.0774)  loss_rpn_box_reg: 0.3209 (0.2456)  time: 0.4150  data: 0.2371  max mem: 0
# Epoch: [0]  [1010/2965]  eta: 0:12:37  lr: 0.005000  loss: 1.4095 (1.3080)  loss_classifier: 0.3149 (0.2881)  loss_box_reg: 0.4372 (0.3777)  loss_mask: 0.3484 (0.3191)  loss_objectness: 0.0631 (0.0773)  loss_rpn_box_reg: 0.2731 (0.2458)  time: 0.4099  data: 0.2327  max mem: 0
# Epoch: [0]  [1020/2965]  eta: 0:12:33  lr: 0.005000  loss: 1.3476 (1.3080)  loss_classifier: 0.2768 (0.2881)  loss_box_reg: 0.4249 (0.3778)  loss_mask: 0.3127 (0.3195)  loss_objectness: 0.0658 (0.0773)  loss_rpn_box_reg: 0.2297 (0.2453)  time: 0.3928  data: 0.2178  max mem: 0
# Epoch: [0]  [1030/2965]  eta: 0:12:29  lr: 0.005000  loss: 1.2030 (1.3068)  loss_classifier: 0.2484 (0.2878)  loss_box_reg: 0.3759 (0.3774)  loss_mask: 0.3076 (0.3192)  loss_objectness: 0.0528 (0.0772)  loss_rpn_box_reg: 0.1916 (0.2453)  time: 0.3769  data: 0.2023  max mem: 0
# Epoch: [0]  [1040/2965]  eta: 0:12:25  lr: 0.005000  loss: 1.1648 (1.3073)  loss_classifier: 0.2484 (0.2879)  loss_box_reg: 0.3754 (0.3779)  loss_mask: 0.3179 (0.3196)  loss_objectness: 0.0560 (0.0772)  loss_rpn_box_reg: 0.1916 (0.2448)  time: 0.3873  data: 0.2113  max mem: 0
# Epoch: [0]  [1050/2965]  eta: 0:12:22  lr: 0.005000  loss: 1.3102 (1.3077)  loss_classifier: 0.2673 (0.2877)  loss_box_reg: 0.3851 (0.3776)  loss_mask: 0.3356 (0.3201)  loss_objectness: 0.0595 (0.0776)  loss_rpn_box_reg: 0.2000 (0.2447)  time: 0.4022  data: 0.2277  max mem: 0
# Epoch: [0]  [1060/2965]  eta: 0:12:18  lr: 0.005000  loss: 1.3102 (1.3079)  loss_classifier: 0.2673 (0.2875)  loss_box_reg: 0.3902 (0.3778)  loss_mask: 0.3221 (0.3203)  loss_objectness: 0.0763 (0.0776)  loss_rpn_box_reg: 0.2753 (0.2446)  time: 0.3853  data: 0.2119  max mem: 0
# Epoch: [0]  [1070/2965]  eta: 0:12:13  lr: 0.005000  loss: 1.3779 (1.3083)  loss_classifier: 0.2852 (0.2875)  loss_box_reg: 0.4371 (0.3784)  loss_mask: 0.3287 (0.3205)  loss_objectness: 0.0688 (0.0777)  loss_rpn_box_reg: 0.2273 (0.2443)  time: 0.3682  data: 0.1942  max mem: 0
# Epoch: [0]  [1080/2965]  eta: 0:12:10  lr: 0.005000  loss: 1.4810 (1.3098)  loss_classifier: 0.2974 (0.2880)  loss_box_reg: 0.4390 (0.3787)  loss_mask: 0.3287 (0.3206)  loss_objectness: 0.0572 (0.0775)  loss_rpn_box_reg: 0.2273 (0.2450)  time: 0.3963  data: 0.2208  max mem: 0
# Epoch: [0]  [1090/2965]  eta: 0:12:06  lr: 0.005000  loss: 1.2668 (1.3088)  loss_classifier: 0.2938 (0.2876)  loss_box_reg: 0.3745 (0.3785)  loss_mask: 0.3037 (0.3203)  loss_objectness: 0.0572 (0.0776)  loss_rpn_box_reg: 0.1840 (0.2448)  time: 0.3886  data: 0.2123  max mem: 0
# Epoch: [0]  [1100/2965]  eta: 0:12:02  lr: 0.005000  loss: 1.3250 (1.3105)  loss_classifier: 0.2842 (0.2881)  loss_box_reg: 0.3986 (0.3787)  loss_mask: 0.3291 (0.3203)  loss_objectness: 0.0867 (0.0780)  loss_rpn_box_reg: 0.1974 (0.2453)  time: 0.3785  data: 0.2028  max mem: 0
# Epoch: [0]  [1110/2965]  eta: 0:11:58  lr: 0.005000  loss: 1.5298 (1.3114)  loss_classifier: 0.3278 (0.2883)  loss_box_reg: 0.3992 (0.3786)  loss_mask: 0.3375 (0.3207)  loss_objectness: 0.0923 (0.0785)  loss_rpn_box_reg: 0.2459 (0.2453)  time: 0.3882  data: 0.2157  max mem: 0
# Epoch: [0]  [1120/2965]  eta: 0:11:55  lr: 0.005000  loss: 1.4977 (1.3129)  loss_classifier: 0.2588 (0.2883)  loss_box_reg: 0.3777 (0.3787)  loss_mask: 0.3274 (0.3206)  loss_objectness: 0.1016 (0.0788)  loss_rpn_box_reg: 0.3739 (0.2466)  time: 0.3939  data: 0.2207  max mem: 0
# Epoch: [0]  [1130/2965]  eta: 0:11:51  lr: 0.005000  loss: 1.4977 (1.3140)  loss_classifier: 0.2588 (0.2887)  loss_box_reg: 0.4033 (0.3790)  loss_mask: 0.3076 (0.3204)  loss_objectness: 0.1097 (0.0790)  loss_rpn_box_reg: 0.3536 (0.2469)  time: 0.4091  data: 0.2320  max mem: 0
# Epoch: [0]  [1140/2965]  eta: 0:11:48  lr: 0.005000  loss: 1.2419 (1.3144)  loss_classifier: 0.2212 (0.2887)  loss_box_reg: 0.4256 (0.3791)  loss_mask: 0.3045 (0.3203)  loss_objectness: 0.0809 (0.0793)  loss_rpn_box_reg: 0.1823 (0.2470)  time: 0.4330  data: 0.2505  max mem: 0
# Epoch: [0]  [1150/2965]  eta: 0:11:45  lr: 0.005000  loss: 1.4785 (1.3163)  loss_classifier: 0.2982 (0.2888)  loss_box_reg: 0.4299 (0.3796)  loss_mask: 0.3081 (0.3206)  loss_objectness: 0.0809 (0.0794)  loss_rpn_box_reg: 0.2640 (0.2479)  time: 0.4433  data: 0.2606  max mem: 0
# Epoch: [0]  [1160/2965]  eta: 0:11:42  lr: 0.005000  loss: 1.3606 (1.3151)  loss_classifier: 0.2690 (0.2887)  loss_box_reg: 0.3862 (0.3797)  loss_mask: 0.2935 (0.3204)  loss_objectness: 0.0652 (0.0793)  loss_rpn_box_reg: 0.1777 (0.2471)  time: 0.4226  data: 0.2442  max mem: 0
# Epoch: [0]  [1170/2965]  eta: 0:11:37  lr: 0.005000  loss: 1.1694 (1.3154)  loss_classifier: 0.2514 (0.2890)  loss_box_reg: 0.3794 (0.3798)  loss_mask: 0.2935 (0.3204)  loss_objectness: 0.0605 (0.0792)  loss_rpn_box_reg: 0.1055 (0.2470)  time: 0.3983  data: 0.2214  max mem: 0
# Epoch: [0]  [1180/2965]  eta: 0:11:33  lr: 0.005000  loss: 1.3927 (1.3140)  loss_classifier: 0.2684 (0.2886)  loss_box_reg: 0.3989 (0.3796)  loss_mask: 0.3048 (0.3200)  loss_objectness: 0.0605 (0.0791)  loss_rpn_box_reg: 0.1509 (0.2468)  time: 0.3741  data: 0.1989  max mem: 0
# Epoch: [0]  [1190/2965]  eta: 0:11:31  lr: 0.005000  loss: 1.3078 (1.3134)  loss_classifier: 0.2565 (0.2884)  loss_box_reg: 0.3710 (0.3793)  loss_mask: 0.2823 (0.3198)  loss_objectness: 0.0618 (0.0792)  loss_rpn_box_reg: 0.1986 (0.2467)  time: 0.4163  data: 0.2381  max mem: 0
# Epoch: [0]  [1200/2965]  eta: 0:11:26  lr: 0.005000  loss: 1.3078 (1.3127)  loss_classifier: 0.2539 (0.2882)  loss_box_reg: 0.3797 (0.3792)  loss_mask: 0.2957 (0.3199)  loss_objectness: 0.0489 (0.0789)  loss_rpn_box_reg: 0.1986 (0.2465)  time: 0.4085  data: 0.2321  max mem: 0
# Epoch: [0]  [1210/2965]  eta: 0:11:22  lr: 0.005000  loss: 1.3869 (1.3137)  loss_classifier: 0.2816 (0.2881)  loss_box_reg: 0.3797 (0.3793)  loss_mask: 0.3227 (0.3201)  loss_objectness: 0.0487 (0.0793)  loss_rpn_box_reg: 0.2306 (0.2469)  time: 0.3782  data: 0.2055  max mem: 0
# Epoch: [0]  [1220/2965]  eta: 0:11:18  lr: 0.005000  loss: 1.3639 (1.3119)  loss_classifier: 0.2750 (0.2875)  loss_box_reg: 0.3639 (0.3789)  loss_mask: 0.3264 (0.3199)  loss_objectness: 0.0671 (0.0793)  loss_rpn_box_reg: 0.2433 (0.2464)  time: 0.3787  data: 0.2052  max mem: 0
# Epoch: [0]  [1230/2965]  eta: 0:11:15  lr: 0.005000  loss: 1.4074 (1.3149)  loss_classifier: 0.2548 (0.2876)  loss_box_reg: 0.3973 (0.3789)  loss_mask: 0.3100 (0.3200)  loss_objectness: 0.1034 (0.0807)  loss_rpn_box_reg: 0.2807 (0.2477)  time: 0.3862  data: 0.2100  max mem: 0
# Epoch: [0]  [1240/2965]  eta: 0:11:10  lr: 0.005000  loss: 1.5430 (1.3143)  loss_classifier: 0.2548 (0.2871)  loss_box_reg: 0.4093 (0.3785)  loss_mask: 0.3100 (0.3200)  loss_objectness: 0.1775 (0.0814)  loss_rpn_box_reg: 0.3237 (0.2474)  time: 0.3929  data: 0.2191  max mem: 0
# Epoch: [0]  [1250/2965]  eta: 0:11:06  lr: 0.005000  loss: 1.2306 (1.3142)  loss_classifier: 0.2326 (0.2869)  loss_box_reg: 0.4424 (0.3787)  loss_mask: 0.3343 (0.3202)  loss_objectness: 0.0607 (0.0812)  loss_rpn_box_reg: 0.1581 (0.2471)  time: 0.3755  data: 0.2048  max mem: 0
# Epoch: [0]  [1260/2965]  eta: 0:11:02  lr: 0.005000  loss: 1.1524 (1.3139)  loss_classifier: 0.2211 (0.2865)  loss_box_reg: 0.4300 (0.3785)  loss_mask: 0.3550 (0.3205)  loss_objectness: 0.0488 (0.0810)  loss_rpn_box_reg: 0.2998 (0.2473)  time: 0.3652  data: 0.1935  max mem: 0
# Epoch: [0]  [1270/2965]  eta: 0:10:58  lr: 0.005000  loss: 1.4785 (1.3167)  loss_classifier: 0.2238 (0.2867)  loss_box_reg: 0.3860 (0.3786)  loss_mask: 0.3376 (0.3207)  loss_objectness: 0.0561 (0.0813)  loss_rpn_box_reg: 0.3131 (0.2494)  time: 0.3739  data: 0.1993  max mem: 0
# Epoch: [0]  [1280/2965]  eta: 0:10:54  lr: 0.005000  loss: 1.4785 (1.3164)  loss_classifier: 0.2877 (0.2865)  loss_box_reg: 0.3860 (0.3784)  loss_mask: 0.3210 (0.3204)  loss_objectness: 0.0891 (0.0815)  loss_rpn_box_reg: 0.3551 (0.2496)  time: 0.3889  data: 0.2121  max mem: 0
# Epoch: [0]  [1290/2965]  eta: 0:10:50  lr: 0.005000  loss: 1.4116 (1.3173)  loss_classifier: 0.2877 (0.2864)  loss_box_reg: 0.3933 (0.3786)  loss_mask: 0.3210 (0.3208)  loss_objectness: 0.0833 (0.0815)  loss_rpn_box_reg: 0.2436 (0.2501)  time: 0.3907  data: 0.2132  max mem: 0
# Epoch: [0]  [1300/2965]  eta: 0:10:47  lr: 0.005000  loss: 1.5160 (1.3181)  loss_classifier: 0.2903 (0.2864)  loss_box_reg: 0.4501 (0.3792)  loss_mask: 0.3480 (0.3210)  loss_objectness: 0.0617 (0.0813)  loss_rpn_box_reg: 0.2436 (0.2502)  time: 0.3997  data: 0.2204  max mem: 0
# Epoch: [0]  [1310/2965]  eta: 0:10:43  lr: 0.005000  loss: 1.4734 (1.3183)  loss_classifier: 0.2610 (0.2861)  loss_box_reg: 0.4418 (0.3791)  loss_mask: 0.3158 (0.3209)  loss_objectness: 0.0617 (0.0814)  loss_rpn_box_reg: 0.2619 (0.2508)  time: 0.3979  data: 0.2207  max mem: 0
# Epoch: [0]  [1320/2965]  eta: 0:10:39  lr: 0.005000  loss: 1.2195 (1.3167)  loss_classifier: 0.2487 (0.2858)  loss_box_reg: 0.3785 (0.3784)  loss_mask: 0.2942 (0.3210)  loss_objectness: 0.0680 (0.0813)  loss_rpn_box_reg: 0.1516 (0.2502)  time: 0.3707  data: 0.1977  max mem: 0
# Epoch: [0]  [1330/2965]  eta: 0:10:35  lr: 0.005000  loss: 1.1067 (1.3156)  loss_classifier: 0.2578 (0.2855)  loss_box_reg: 0.3388 (0.3779)  loss_mask: 0.3195 (0.3208)  loss_objectness: 0.0612 (0.0811)  loss_rpn_box_reg: 0.1319 (0.2502)  time: 0.3706  data: 0.1998  max mem: 0
# Epoch: [0]  [1340/2965]  eta: 0:10:31  lr: 0.005000  loss: 1.3626 (1.3172)  loss_classifier: 0.2640 (0.2859)  loss_box_reg: 0.3973 (0.3786)  loss_mask: 0.3468 (0.3212)  loss_objectness: 0.0689 (0.0812)  loss_rpn_box_reg: 0.2500 (0.2503)  time: 0.4081  data: 0.2327  max mem: 0
# Epoch: [0]  [1350/2965]  eta: 0:10:27  lr: 0.005000  loss: 1.3235 (1.3155)  loss_classifier: 0.2129 (0.2852)  loss_box_reg: 0.3973 (0.3782)  loss_mask: 0.3199 (0.3210)  loss_objectness: 0.0670 (0.0811)  loss_rpn_box_reg: 0.2359 (0.2499)  time: 0.3816  data: 0.2067  max mem: 0
# Epoch: [0]  [1360/2965]  eta: 0:10:23  lr: 0.005000  loss: 1.0559 (1.3139)  loss_classifier: 0.1833 (0.2847)  loss_box_reg: 0.3663 (0.3783)  loss_mask: 0.2805 (0.3209)  loss_objectness: 0.0532 (0.0809)  loss_rpn_box_reg: 0.1285 (0.2491)  time: 0.3584  data: 0.1861  max mem: 0
# Epoch: [0]  [1370/2965]  eta: 0:10:19  lr: 0.005000  loss: 1.1091 (1.3135)  loss_classifier: 0.1878 (0.2844)  loss_box_reg: 0.3753 (0.3781)  loss_mask: 0.3000 (0.3205)  loss_objectness: 0.0479 (0.0811)  loss_rpn_box_reg: 0.1285 (0.2494)  time: 0.3700  data: 0.1968  max mem: 0
# Epoch: [0]  [1380/2965]  eta: 0:10:15  lr: 0.005000  loss: 1.2630 (1.3145)  loss_classifier: 0.2715 (0.2846)  loss_box_reg: 0.3881 (0.3785)  loss_mask: 0.3216 (0.3209)  loss_objectness: 0.0553 (0.0811)  loss_rpn_box_reg: 0.2353 (0.2494)  time: 0.4050  data: 0.2291  max mem: 0
# Epoch: [0]  [1390/2965]  eta: 0:10:12  lr: 0.005000  loss: 1.4523 (1.3148)  loss_classifier: 0.2715 (0.2844)  loss_box_reg: 0.4447 (0.3789)  loss_mask: 0.3837 (0.3211)  loss_objectness: 0.0639 (0.0811)  loss_rpn_box_reg: 0.2353 (0.2493)  time: 0.4317  data: 0.2519  max mem: 0
# Epoch: [0]  [1400/2965]  eta: 0:10:08  lr: 0.005000  loss: 1.3270 (1.3146)  loss_classifier: 0.2456 (0.2843)  loss_box_reg: 0.4400 (0.3787)  loss_mask: 0.3190 (0.3210)  loss_objectness: 0.0635 (0.0808)  loss_rpn_box_reg: 0.2454 (0.2497)  time: 0.3978  data: 0.2213  max mem: 0
# Epoch: [0]  [1410/2965]  eta: 0:10:04  lr: 0.005000  loss: 1.2274 (1.3131)  loss_classifier: 0.2594 (0.2839)  loss_box_reg: 0.3895 (0.3784)  loss_mask: 0.2956 (0.3209)  loss_objectness: 0.0351 (0.0806)  loss_rpn_box_reg: 0.1982 (0.2493)  time: 0.3725  data: 0.1994  max mem: 0
# Epoch: [0]  [1420/2965]  eta: 0:10:00  lr: 0.005000  loss: 1.1545 (1.3123)  loss_classifier: 0.2594 (0.2837)  loss_box_reg: 0.4059 (0.3783)  loss_mask: 0.2853 (0.3208)  loss_objectness: 0.0512 (0.0806)  loss_rpn_box_reg: 0.1048 (0.2489)  time: 0.3748  data: 0.2017  max mem: 0
# Epoch: [0]  [1430/2965]  eta: 0:09:56  lr: 0.005000  loss: 1.1529 (1.3104)  loss_classifier: 0.2071 (0.2832)  loss_box_reg: 0.3207 (0.3778)  loss_mask: 0.2608 (0.3203)  loss_objectness: 0.0573 (0.0804)  loss_rpn_box_reg: 0.1145 (0.2486)  time: 0.3723  data: 0.2002  max mem: 0
# Epoch: [0]  [1440/2965]  eta: 0:09:52  lr: 0.005000  loss: 1.1861 (1.3108)  loss_classifier: 0.2071 (0.2831)  loss_box_reg: 0.3606 (0.3780)  loss_mask: 0.2608 (0.3203)  loss_objectness: 0.0670 (0.0805)  loss_rpn_box_reg: 0.2481 (0.2490)  time: 0.3821  data: 0.2078  max mem: 0
# Epoch: [0]  [1450/2965]  eta: 0:09:48  lr: 0.005000  loss: 1.1520 (1.3094)  loss_classifier: 0.2145 (0.2826)  loss_box_reg: 0.3833 (0.3778)  loss_mask: 0.2877 (0.3202)  loss_objectness: 0.0621 (0.0803)  loss_rpn_box_reg: 0.2481 (0.2485)  time: 0.3952  data: 0.2193  max mem: 0
# Epoch: [0]  [1460/2965]  eta: 0:09:44  lr: 0.005000  loss: 1.0777 (1.3098)  loss_classifier: 0.2310 (0.2827)  loss_box_reg: 0.3718 (0.3779)  loss_mask: 0.3120 (0.3202)  loss_objectness: 0.0528 (0.0805)  loss_rpn_box_reg: 0.1356 (0.2486)  time: 0.3961  data: 0.2211  max mem: 0
# Epoch: [0]  [1470/2965]  eta: 0:09:40  lr: 0.005000  loss: 1.1886 (1.3106)  loss_classifier: 0.2577 (0.2828)  loss_box_reg: 0.3639 (0.3776)  loss_mask: 0.2931 (0.3201)  loss_objectness: 0.0677 (0.0805)  loss_rpn_box_reg: 0.2992 (0.2496)  time: 0.4005  data: 0.2263  max mem: 0
# Epoch: [0]  [1480/2965]  eta: 0:09:36  lr: 0.005000  loss: 1.3736 (1.3100)  loss_classifier: 0.2704 (0.2827)  loss_box_reg: 0.3639 (0.3775)  loss_mask: 0.2602 (0.3197)  loss_objectness: 0.0602 (0.0803)  loss_rpn_box_reg: 0.3042 (0.2497)  time: 0.3822  data: 0.2096  max mem: 0
# Epoch: [0]  [1490/2965]  eta: 0:09:32  lr: 0.005000  loss: 1.1136 (1.3089)  loss_classifier: 0.2439 (0.2823)  loss_box_reg: 0.3724 (0.3774)  loss_mask: 0.2602 (0.3196)  loss_objectness: 0.0507 (0.0801)  loss_rpn_box_reg: 0.1773 (0.2494)  time: 0.3634  data: 0.1916  max mem: 0
# Epoch: [0]  [1500/2965]  eta: 0:09:28  lr: 0.005000  loss: 1.2738 (1.3094)  loss_classifier: 0.2354 (0.2824)  loss_box_reg: 0.3769 (0.3774)  loss_mask: 0.2915 (0.3195)  loss_objectness: 0.0605 (0.0801)  loss_rpn_box_reg: 0.2617 (0.2501)  time: 0.3849  data: 0.2106  max mem: 0
# Epoch: [0]  [1510/2965]  eta: 0:09:25  lr: 0.005000  loss: 1.3610 (1.3106)  loss_classifier: 0.2897 (0.2826)  loss_box_reg: 0.4317 (0.3780)  loss_mask: 0.3062 (0.3197)  loss_objectness: 0.0639 (0.0803)  loss_rpn_box_reg: 0.2617 (0.2500)  time: 0.4300  data: 0.2496  max mem: 0
# Epoch: [0]  [1520/2965]  eta: 0:09:22  lr: 0.005000  loss: 1.2783 (1.3094)  loss_classifier: 0.2897 (0.2823)  loss_box_reg: 0.4370 (0.3779)  loss_mask: 0.3456 (0.3195)  loss_objectness: 0.0572 (0.0802)  loss_rpn_box_reg: 0.1211 (0.2495)  time: 0.4356  data: 0.2555  max mem: 0
# Epoch: [0]  [1530/2965]  eta: 0:09:17  lr: 0.005000  loss: 1.1276 (1.3081)  loss_classifier: 0.2363 (0.2818)  loss_box_reg: 0.3646 (0.3777)  loss_mask: 0.3045 (0.3196)  loss_objectness: 0.0603 (0.0803)  loss_rpn_box_reg: 0.0846 (0.2487)  time: 0.3911  data: 0.2170  max mem: 0
# Epoch: [0]  [1540/2965]  eta: 0:09:14  lr: 0.005000  loss: 1.2115 (1.3094)  loss_classifier: 0.2363 (0.2818)  loss_box_reg: 0.4004 (0.3779)  loss_mask: 0.3206 (0.3196)  loss_objectness: 0.0603 (0.0804)  loss_rpn_box_reg: 0.1338 (0.2498)  time: 0.4097  data: 0.2330  max mem: 0
# Epoch: [0]  [1550/2965]  eta: 0:09:10  lr: 0.005000  loss: 1.5227 (1.3103)  loss_classifier: 0.2561 (0.2816)  loss_box_reg: 0.4069 (0.3777)  loss_mask: 0.3002 (0.3193)  loss_objectness: 0.0744 (0.0809)  loss_rpn_box_reg: 0.2878 (0.2508)  time: 0.4091  data: 0.2317  max mem: 0
# Epoch: [0]  [1560/2965]  eta: 0:09:06  lr: 0.005000  loss: 1.3315 (1.3096)  loss_classifier: 0.2262 (0.2814)  loss_box_reg: 0.3685 (0.3778)  loss_mask: 0.3002 (0.3193)  loss_objectness: 0.0898 (0.0809)  loss_rpn_box_reg: 0.1122 (0.2501)  time: 0.3701  data: 0.1958  max mem: 0
# Epoch: [0]  [1570/2965]  eta: 0:09:02  lr: 0.005000  loss: 1.1944 (1.3087)  loss_classifier: 0.2896 (0.2813)  loss_box_reg: 0.3829 (0.3777)  loss_mask: 0.2951 (0.3189)  loss_objectness: 0.0763 (0.0810)  loss_rpn_box_reg: 0.0885 (0.2498)  time: 0.3577  data: 0.1845  max mem: 0
# Epoch: [0]  [1580/2965]  eta: 0:08:58  lr: 0.005000  loss: 1.2516 (1.3094)  loss_classifier: 0.3033 (0.2813)  loss_box_reg: 0.3630 (0.3775)  loss_mask: 0.2889 (0.3191)  loss_objectness: 0.0868 (0.0816)  loss_rpn_box_reg: 0.1275 (0.2500)  time: 0.3607  data: 0.1890  max mem: 0
# Epoch: [0]  [1590/2965]  eta: 0:08:54  lr: 0.005000  loss: 1.2308 (1.3082)  loss_classifier: 0.2372 (0.2810)  loss_box_reg: 0.3466 (0.3771)  loss_mask: 0.3501 (0.3192)  loss_objectness: 0.0740 (0.0815)  loss_rpn_box_reg: 0.1178 (0.2494)  time: 0.3908  data: 0.2147  max mem: 0
# Epoch: [0]  [1600/2965]  eta: 0:08:50  lr: 0.005000  loss: 1.2115 (1.3076)  loss_classifier: 0.1972 (0.2808)  loss_box_reg: 0.3889 (0.3772)  loss_mask: 0.2982 (0.3190)  loss_objectness: 0.0588 (0.0814)  loss_rpn_box_reg: 0.1114 (0.2491)  time: 0.3900  data: 0.2119  max mem: 0
# Epoch: [0]  [1610/2965]  eta: 0:08:46  lr: 0.005000  loss: 1.3319 (1.3090)  loss_classifier: 0.2704 (0.2809)  loss_box_reg: 0.4650 (0.3778)  loss_mask: 0.3140 (0.3192)  loss_objectness: 0.0661 (0.0815)  loss_rpn_box_reg: 0.2077 (0.2497)  time: 0.3983  data: 0.2198  max mem: 0
# Epoch: [0]  [1620/2965]  eta: 0:08:43  lr: 0.005000  loss: 1.4435 (1.3098)  loss_classifier: 0.3037 (0.2810)  loss_box_reg: 0.4668 (0.3782)  loss_mask: 0.3249 (0.3192)  loss_objectness: 0.0689 (0.0815)  loss_rpn_box_reg: 0.2790 (0.2499)  time: 0.4190  data: 0.2395  max mem: 0
# Epoch: [0]  [1630/2965]  eta: 0:08:39  lr: 0.005000  loss: 1.1987 (1.3088)  loss_classifier: 0.2561 (0.2807)  loss_box_reg: 0.4291 (0.3780)  loss_mask: 0.2693 (0.3189)  loss_objectness: 0.0632 (0.0815)  loss_rpn_box_reg: 0.2199 (0.2498)  time: 0.4250  data: 0.2481  max mem: 0
# Epoch: [0]  [1640/2965]  eta: 0:08:35  lr: 0.005000  loss: 1.0083 (1.3072)  loss_classifier: 0.1995 (0.2802)  loss_box_reg: 0.3284 (0.3776)  loss_mask: 0.2639 (0.3186)  loss_objectness: 0.0629 (0.0814)  loss_rpn_box_reg: 0.1410 (0.2495)  time: 0.4112  data: 0.2356  max mem: 0
# Epoch: [0]  [1650/2965]  eta: 0:08:31  lr: 0.005000  loss: 0.8884 (1.3056)  loss_classifier: 0.2111 (0.2799)  loss_box_reg: 0.2842 (0.3771)  loss_mask: 0.2531 (0.3184)  loss_objectness: 0.0517 (0.0813)  loss_rpn_box_reg: 0.1111 (0.2490)  time: 0.3720  data: 0.1980  max mem: 0
# Epoch: [0]  [1660/2965]  eta: 0:08:27  lr: 0.005000  loss: 1.1399 (1.3062)  loss_classifier: 0.2518 (0.2800)  loss_box_reg: 0.3640 (0.3773)  loss_mask: 0.2965 (0.3184)  loss_objectness: 0.0427 (0.0812)  loss_rpn_box_reg: 0.1721 (0.2494)  time: 0.3845  data: 0.2096  max mem: 0
# Epoch: [0]  [1670/2965]  eta: 0:08:24  lr: 0.005000  loss: 1.4183 (1.3076)  loss_classifier: 0.2928 (0.2803)  loss_box_reg: 0.3935 (0.3776)  loss_mask: 0.3186 (0.3186)  loss_objectness: 0.0515 (0.0811)  loss_rpn_box_reg: 0.2524 (0.2499)  time: 0.4338  data: 0.2542  max mem: 0
# Epoch: [0]  [1680/2965]  eta: 0:08:20  lr: 0.005000  loss: 1.4961 (1.3078)  loss_classifier: 0.2866 (0.2801)  loss_box_reg: 0.3736 (0.3776)  loss_mask: 0.3127 (0.3186)  loss_objectness: 0.0711 (0.0816)  loss_rpn_box_reg: 0.2528 (0.2500)  time: 0.4188  data: 0.2385  max mem: 0
# Epoch: [0]  [1690/2965]  eta: 0:08:16  lr: 0.005000  loss: 1.2146 (1.3074)  loss_classifier: 0.2557 (0.2799)  loss_box_reg: 0.3293 (0.3773)  loss_mask: 0.2729 (0.3184)  loss_objectness: 0.0742 (0.0816)  loss_rpn_box_reg: 0.2630 (0.2502)  time: 0.4060  data: 0.2288  max mem: 0
# Epoch: [0]  [1700/2965]  eta: 0:08:13  lr: 0.005000  loss: 1.1749 (1.3072)  loss_classifier: 0.2557 (0.2798)  loss_box_reg: 0.3293 (0.3774)  loss_mask: 0.2866 (0.3183)  loss_objectness: 0.0701 (0.0816)  loss_rpn_box_reg: 0.2871 (0.2501)  time: 0.4266  data: 0.2481  max mem: 0
# ...
# Epoch: [4]  [2420/2965]  eta: 0:03:36  lr: 0.000500  loss: 0.7698 (0.8567)  loss_classifier: 0.1179 (0.1613)  loss_box_reg: 0.1981 (0.2510)  loss_mask: 0.1934 (0.2514)  loss_objectness: 0.0161 (0.0300)  loss_rpn_box_reg: 0.1159 (0.1629)  time: 0.3892  data: 0.2105  max mem: 0
# Epoch: [4]  [2430/2965]  eta: 0:03:32  lr: 0.000500  loss: 0.8371 (0.8568)  loss_classifier: 0.1567 (0.1614)  loss_box_reg: 0.2358 (0.2511)  loss_mask: 0.2236 (0.2514)  loss_objectness: 0.0266 (0.0300)  loss_rpn_box_reg: 0.1457 (0.1629)  time: 0.4067  data: 0.2250  max mem: 0
# Epoch: [4]  [2440/2965]  eta: 0:03:28  lr: 0.000500  loss: 0.9059 (0.8567)  loss_classifier: 0.1580 (0.1613)  loss_box_reg: 0.2161 (0.2510)  loss_mask: 0.2280 (0.2513)  loss_objectness: 0.0189 (0.0300)  loss_rpn_box_reg: 0.1718 (0.1631)  time: 0.3900  data: 0.2105  max mem: 0
# Epoch: [4]  [2450/2965]  eta: 0:03:24  lr: 0.000500  loss: 0.9059 (0.8569)  loss_classifier: 0.1580 (0.1614)  loss_box_reg: 0.2118 (0.2510)  loss_mask: 0.2531 (0.2514)  loss_objectness: 0.0169 (0.0300)  loss_rpn_box_reg: 0.1272 (0.1631)  time: 0.4062  data: 0.2248  max mem: 0
# Epoch: [4]  [2460/2965]  eta: 0:03:20  lr: 0.000500  loss: 0.8299 (0.8567)  loss_classifier: 0.1360 (0.1613)  loss_box_reg: 0.2604 (0.2510)  loss_mask: 0.2531 (0.2514)  loss_objectness: 0.0184 (0.0300)  loss_rpn_box_reg: 0.1223 (0.1629)  time: 0.4181  data: 0.2331  max mem: 0
# Epoch: [4]  [2470/2965]  eta: 0:03:16  lr: 0.000500  loss: 0.8299 (0.8567)  loss_classifier: 0.1360 (0.1614)  loss_box_reg: 0.2436 (0.2510)  loss_mask: 0.2475 (0.2514)  loss_objectness: 0.0205 (0.0300)  loss_rpn_box_reg: 0.1470 (0.1629)  time: 0.4123  data: 0.2291  max mem: 0
# Epoch: [4]  [2480/2965]  eta: 0:03:12  lr: 0.000500  loss: 0.9118 (0.8569)  loss_classifier: 0.1572 (0.1615)  loss_box_reg: 0.2573 (0.2511)  loss_mask: 0.2555 (0.2515)  loss_objectness: 0.0227 (0.0300)  loss_rpn_box_reg: 0.1589 (0.1629)  time: 0.4101  data: 0.2295  max mem: 0
# Epoch: [4]  [2490/2965]  eta: 0:03:08  lr: 0.000500  loss: 0.9592 (0.8576)  loss_classifier: 0.1729 (0.1616)  loss_box_reg: 0.2849 (0.2512)  loss_mask: 0.2636 (0.2516)  loss_objectness: 0.0227 (0.0300)  loss_rpn_box_reg: 0.1997 (0.1632)  time: 0.4344  data: 0.2477  max mem: 0
# Epoch: [4]  [2500/2965]  eta: 0:03:04  lr: 0.000500  loss: 0.9739 (0.8583)  loss_classifier: 0.1803 (0.1617)  loss_box_reg: 0.2891 (0.2514)  loss_mask: 0.2622 (0.2517)  loss_objectness: 0.0272 (0.0300)  loss_rpn_box_reg: 0.1997 (0.1636)  time: 0.4520  data: 0.2627  max mem: 0
# Epoch: [4]  [2510/2965]  eta: 0:03:01  lr: 0.000500  loss: 0.8286 (0.8583)  loss_classifier: 0.1710 (0.1618)  loss_box_reg: 0.2578 (0.2514)  loss_mask: 0.2534 (0.2517)  loss_objectness: 0.0299 (0.0300)  loss_rpn_box_reg: 0.1632 (0.1634)  time: 0.4437  data: 0.2582  max mem: 0
# Epoch: [4]  [2520/2965]  eta: 0:02:57  lr: 0.000500  loss: 0.7088 (0.8577)  loss_classifier: 0.1315 (0.1616)  loss_box_reg: 0.1894 (0.2511)  loss_mask: 0.2077 (0.2516)  loss_objectness: 0.0220 (0.0300)  loss_rpn_box_reg: 0.0964 (0.1634)  time: 0.4162  data: 0.2348  max mem: 0
# Epoch: [4]  [2530/2965]  eta: 0:02:53  lr: 0.000500  loss: 0.8044 (0.8587)  loss_classifier: 0.1356 (0.1619)  loss_box_reg: 0.2357 (0.2514)  loss_mask: 0.2398 (0.2517)  loss_objectness: 0.0301 (0.0300)  loss_rpn_box_reg: 0.1244 (0.1637)  time: 0.4119  data: 0.2316  max mem: 0
# Epoch: [4]  [2540/2965]  eta: 0:02:49  lr: 0.000500  loss: 0.9016 (0.8585)  loss_classifier: 0.1655 (0.1619)  loss_box_reg: 0.2357 (0.2513)  loss_mask: 0.2435 (0.2516)  loss_objectness: 0.0326 (0.0300)  loss_rpn_box_reg: 0.1655 (0.1637)  time: 0.4147  data: 0.2343  max mem: 0
# Epoch: [4]  [2550/2965]  eta: 0:02:45  lr: 0.000500  loss: 0.6688 (0.8578)  loss_classifier: 0.1166 (0.1618)  loss_box_reg: 0.1885 (0.2511)  loss_mask: 0.2049 (0.2514)  loss_objectness: 0.0151 (0.0300)  loss_rpn_box_reg: 0.0794 (0.1635)  time: 0.3881  data: 0.2094  max mem: 0
# Epoch: [4]  [2560/2965]  eta: 0:02:41  lr: 0.000500  loss: 0.6688 (0.8578)  loss_classifier: 0.1300 (0.1618)  loss_box_reg: 0.2173 (0.2512)  loss_mask: 0.2049 (0.2514)  loss_objectness: 0.0158 (0.0300)  loss_rpn_box_reg: 0.0700 (0.1635)  time: 0.3871  data: 0.2079  max mem: 0
# Epoch: [4]  [2570/2965]  eta: 0:02:37  lr: 0.000500  loss: 0.7822 (0.8579)  loss_classifier: 0.1413 (0.1618)  loss_box_reg: 0.2665 (0.2512)  loss_mask: 0.2348 (0.2514)  loss_objectness: 0.0166 (0.0299)  loss_rpn_box_reg: 0.0920 (0.1635)  time: 0.4126  data: 0.2295  max mem: 0
# Epoch: [4]  [2580/2965]  eta: 0:02:33  lr: 0.000500  loss: 0.9086 (0.8580)  loss_classifier: 0.1413 (0.1619)  loss_box_reg: 0.2678 (0.2512)  loss_mask: 0.2426 (0.2515)  loss_objectness: 0.0175 (0.0299)  loss_rpn_box_reg: 0.1741 (0.1635)  time: 0.4254  data: 0.2391  max mem: 0
# Epoch: [4]  [2590/2965]  eta: 0:02:29  lr: 0.000500  loss: 0.9035 (0.8575)  loss_classifier: 0.1344 (0.1617)  loss_box_reg: 0.2615 (0.2511)  loss_mask: 0.2432 (0.2514)  loss_objectness: 0.0237 (0.0299)  loss_rpn_box_reg: 0.1260 (0.1633)  time: 0.4000  data: 0.2198  max mem: 0
# Epoch: [4]  [2600/2965]  eta: 0:02:25  lr: 0.000500  loss: 0.9035 (0.8579)  loss_classifier: 0.1350 (0.1618)  loss_box_reg: 0.2753 (0.2512)  loss_mask: 0.2530 (0.2515)  loss_objectness: 0.0206 (0.0299)  loss_rpn_box_reg: 0.1260 (0.1634)  time: 0.3941  data: 0.2156  max mem: 0
# Epoch: [4]  [2610/2965]  eta: 0:02:21  lr: 0.000500  loss: 0.9282 (0.8580)  loss_classifier: 0.1716 (0.1619)  loss_box_reg: 0.2908 (0.2514)  loss_mask: 0.2538 (0.2515)  loss_objectness: 0.0208 (0.0299)  loss_rpn_box_reg: 0.1719 (0.1633)  time: 0.4063  data: 0.2235  max mem: 0
# Epoch: [4]  [2620/2965]  eta: 0:02:17  lr: 0.000500  loss: 0.8202 (0.8577)  loss_classifier: 0.1674 (0.1619)  loss_box_reg: 0.2661 (0.2514)  loss_mask: 0.2386 (0.2514)  loss_objectness: 0.0202 (0.0298)  loss_rpn_box_reg: 0.1062 (0.1632)  time: 0.4022  data: 0.2202  max mem: 0
# Epoch: [4]  [2630/2965]  eta: 0:02:13  lr: 0.000500  loss: 0.8202 (0.8576)  loss_classifier: 0.1538 (0.1619)  loss_box_reg: 0.2339 (0.2514)  loss_mask: 0.2249 (0.2513)  loss_objectness: 0.0203 (0.0298)  loss_rpn_box_reg: 0.1428 (0.1631)  time: 0.4082  data: 0.2275  max mem: 0
# Epoch: [4]  [2640/2965]  eta: 0:02:09  lr: 0.000500  loss: 0.7578 (0.8573)  loss_classifier: 0.1538 (0.1619)  loss_box_reg: 0.2339 (0.2512)  loss_mask: 0.2365 (0.2513)  loss_objectness: 0.0225 (0.0298)  loss_rpn_box_reg: 0.1428 (0.1631)  time: 0.3965  data: 0.2179  max mem: 0
# Epoch: [4]  [2650/2965]  eta: 0:02:05  lr: 0.000500  loss: 0.7578 (0.8572)  loss_classifier: 0.1491 (0.1619)  loss_box_reg: 0.2214 (0.2513)  loss_mask: 0.2567 (0.2513)  loss_objectness: 0.0183 (0.0298)  loss_rpn_box_reg: 0.0866 (0.1630)  time: 0.3828  data: 0.2059  max mem: 0
# Epoch: [4]  [2660/2965]  eta: 0:02:01  lr: 0.000500  loss: 0.8037 (0.8573)  loss_classifier: 0.1491 (0.1619)  loss_box_reg: 0.2059 (0.2514)  loss_mask: 0.2311 (0.2512)  loss_objectness: 0.0207 (0.0298)  loss_rpn_box_reg: 0.1189 (0.1630)  time: 0.3947  data: 0.2157  max mem: 0
# Epoch: [4]  [2670/2965]  eta: 0:01:57  lr: 0.000500  loss: 0.6868 (0.8568)  loss_classifier: 0.1230 (0.1618)  loss_box_reg: 0.1998 (0.2512)  loss_mask: 0.2251 (0.2512)  loss_objectness: 0.0207 (0.0298)  loss_rpn_box_reg: 0.0743 (0.1628)  time: 0.3831  data: 0.2047  max mem: 0
# Epoch: [4]  [2680/2965]  eta: 0:01:53  lr: 0.000500  loss: 0.6939 (0.8565)  loss_classifier: 0.1097 (0.1617)  loss_box_reg: 0.1896 (0.2510)  loss_mask: 0.2008 (0.2511)  loss_objectness: 0.0207 (0.0298)  loss_rpn_box_reg: 0.0743 (0.1629)  time: 0.3676  data: 0.1913  max mem: 0
# Epoch: [4]  [2690/2965]  eta: 0:01:49  lr: 0.000500  loss: 0.7008 (0.8560)  loss_classifier: 0.1467 (0.1617)  loss_box_reg: 0.1994 (0.2509)  loss_mask: 0.2008 (0.2509)  loss_objectness: 0.0156 (0.0297)  loss_rpn_box_reg: 0.1048 (0.1628)  time: 0.3622  data: 0.1872  max mem: 0
# Epoch: [4]  [2700/2965]  eta: 0:01:45  lr: 0.000500  loss: 0.5895 (0.8556)  loss_classifier: 0.1467 (0.1616)  loss_box_reg: 0.2148 (0.2507)  loss_mask: 0.2165 (0.2509)  loss_objectness: 0.0214 (0.0298)  loss_rpn_box_reg: 0.0523 (0.1626)  time: 0.3751  data: 0.1999  max mem: 0
# Epoch: [4]  [2710/2965]  eta: 0:01:41  lr: 0.000500  loss: 0.7440 (0.8557)  loss_classifier: 0.1443 (0.1616)  loss_box_reg: 0.2177 (0.2508)  loss_mask: 0.2185 (0.2509)  loss_objectness: 0.0214 (0.0297)  loss_rpn_box_reg: 0.0603 (0.1628)  time: 0.3998  data: 0.2222  max mem: 0
# Epoch: [4]  [2720/2965]  eta: 0:01:37  lr: 0.000500  loss: 0.8500 (0.8560)  loss_classifier: 0.1557 (0.1616)  loss_box_reg: 0.2563 (0.2508)  loss_mask: 0.2477 (0.2509)  loss_objectness: 0.0168 (0.0297)  loss_rpn_box_reg: 0.1330 (0.1629)  time: 0.4220  data: 0.2406  max mem: 0
# Epoch: [4]  [2730/2965]  eta: 0:01:33  lr: 0.000500  loss: 0.7707 (0.8555)  loss_classifier: 0.1489 (0.1615)  loss_box_reg: 0.2299 (0.2507)  loss_mask: 0.2458 (0.2509)  loss_objectness: 0.0298 (0.0297)  loss_rpn_box_reg: 0.1140 (0.1627)  time: 0.4077  data: 0.2254  max mem: 0
# Epoch: [4]  [2740/2965]  eta: 0:01:29  lr: 0.000500  loss: 0.8478 (0.8561)  loss_classifier: 0.1498 (0.1617)  loss_box_reg: 0.2299 (0.2508)  loss_mask: 0.2329 (0.2508)  loss_objectness: 0.0221 (0.0297)  loss_rpn_box_reg: 0.1454 (0.1631)  time: 0.4069  data: 0.2254  max mem: 0
# Epoch: [4]  [2750/2965]  eta: 0:01:25  lr: 0.000500  loss: 0.7978 (0.8552)  loss_classifier: 0.1507 (0.1614)  loss_box_reg: 0.2154 (0.2506)  loss_mask: 0.2369 (0.2507)  loss_objectness: 0.0152 (0.0296)  loss_rpn_box_reg: 0.1427 (0.1628)  time: 0.3951  data: 0.2165  max mem: 0
# Epoch: [4]  [2760/2965]  eta: 0:01:21  lr: 0.000500  loss: 0.8661 (0.8562)  loss_classifier: 0.1513 (0.1616)  loss_box_reg: 0.2542 (0.2508)  loss_mask: 0.2570 (0.2509)  loss_objectness: 0.0189 (0.0297)  loss_rpn_box_reg: 0.0939 (0.1633)  time: 0.3888  data: 0.2094  max mem: 0
# Epoch: [4]  [2770/2965]  eta: 0:01:17  lr: 0.000500  loss: 0.9840 (0.8561)  loss_classifier: 0.1657 (0.1615)  loss_box_reg: 0.3079 (0.2508)  loss_mask: 0.2658 (0.2509)  loss_objectness: 0.0216 (0.0296)  loss_rpn_box_reg: 0.1660 (0.1632)  time: 0.4072  data: 0.2245  max mem: 0
# Epoch: [4]  [2780/2965]  eta: 0:01:13  lr: 0.000500  loss: 0.7418 (0.8557)  loss_classifier: 0.1392 (0.1615)  loss_box_reg: 0.2550 (0.2508)  loss_mask: 0.2436 (0.2510)  loss_objectness: 0.0133 (0.0296)  loss_rpn_box_reg: 0.0862 (0.1629)  time: 0.3869  data: 0.2073  max mem: 0
# Epoch: [4]  [2790/2965]  eta: 0:01:09  lr: 0.000500  loss: 0.8085 (0.8562)  loss_classifier: 0.1337 (0.1616)  loss_box_reg: 0.2563 (0.2509)  loss_mask: 0.2567 (0.2511)  loss_objectness: 0.0211 (0.0296)  loss_rpn_box_reg: 0.1018 (0.1630)  time: 0.4422  data: 0.2567  max mem: 0
# Epoch: [4]  [2800/2965]  eta: 0:01:05  lr: 0.000500  loss: 0.9368 (0.8570)  loss_classifier: 0.1563 (0.1617)  loss_box_reg: 0.2725 (0.2510)  loss_mask: 0.2683 (0.2511)  loss_objectness: 0.0216 (0.0296)  loss_rpn_box_reg: 0.2238 (0.1636)  time: 0.4660  data: 0.2764  max mem: 0
# Epoch: [4]  [2810/2965]  eta: 0:01:01  lr: 0.000500  loss: 0.9557 (0.8571)  loss_classifier: 0.1786 (0.1618)  loss_box_reg: 0.2365 (0.2510)  loss_mask: 0.2683 (0.2512)  loss_objectness: 0.0281 (0.0296)  loss_rpn_box_reg: 0.1443 (0.1635)  time: 0.4162  data: 0.2352  max mem: 0
# Epoch: [4]  [2820/2965]  eta: 0:00:57  lr: 0.000500  loss: 0.7800 (0.8571)  loss_classifier: 0.1503 (0.1618)  loss_box_reg: 0.2207 (0.2510)  loss_mask: 0.2556 (0.2512)  loss_objectness: 0.0292 (0.0296)  loss_rpn_box_reg: 0.1181 (0.1635)  time: 0.4029  data: 0.2259  max mem: 0
# Epoch: [4]  [2830/2965]  eta: 0:00:53  lr: 0.000500  loss: 0.6584 (0.8568)  loss_classifier: 0.1334 (0.1618)  loss_box_reg: 0.2217 (0.2510)  loss_mask: 0.2321 (0.2512)  loss_objectness: 0.0260 (0.0296)  loss_rpn_box_reg: 0.0493 (0.1632)  time: 0.3987  data: 0.2204  max mem: 0
# Epoch: [4]  [2840/2965]  eta: 0:00:49  lr: 0.000500  loss: 0.8125 (0.8574)  loss_classifier: 0.1453 (0.1618)  loss_box_reg: 0.2507 (0.2512)  loss_mask: 0.2743 (0.2513)  loss_objectness: 0.0241 (0.0297)  loss_rpn_box_reg: 0.1634 (0.1634)  time: 0.4139  data: 0.2328  max mem: 0
# Epoch: [4]  [2850/2965]  eta: 0:00:45  lr: 0.000500  loss: 0.9267 (0.8578)  loss_classifier: 0.1602 (0.1619)  loss_box_reg: 0.3001 (0.2514)  loss_mask: 0.2812 (0.2513)  loss_objectness: 0.0278 (0.0297)  loss_rpn_box_reg: 0.1822 (0.1635)  time: 0.4435  data: 0.2593  max mem: 0
# Epoch: [4]  [2860/2965]  eta: 0:00:41  lr: 0.000500  loss: 0.7830 (0.8576)  loss_classifier: 0.1402 (0.1618)  loss_box_reg: 0.2508 (0.2514)  loss_mask: 0.2553 (0.2513)  loss_objectness: 0.0244 (0.0297)  loss_rpn_box_reg: 0.1133 (0.1634)  time: 0.4317  data: 0.2494  max mem: 0
# Epoch: [4]  [2870/2965]  eta: 0:00:37  lr: 0.000500  loss: 0.8596 (0.8577)  loss_classifier: 0.1491 (0.1618)  loss_box_reg: 0.2446 (0.2513)  loss_mask: 0.2491 (0.2513)  loss_objectness: 0.0215 (0.0297)  loss_rpn_box_reg: 0.1581 (0.1635)  time: 0.4135  data: 0.2323  max mem: 0
# Epoch: [4]  [2880/2965]  eta: 0:00:33  lr: 0.000500  loss: 0.9663 (0.8585)  loss_classifier: 0.1677 (0.1620)  loss_box_reg: 0.2876 (0.2516)  loss_mask: 0.2819 (0.2515)  loss_objectness: 0.0201 (0.0297)  loss_rpn_box_reg: 0.2010 (0.1636)  time: 0.4272  data: 0.2428  max mem: 0
# Epoch: [4]  [2890/2965]  eta: 0:00:29  lr: 0.000500  loss: 0.9080 (0.8582)  loss_classifier: 0.1796 (0.1620)  loss_box_reg: 0.2876 (0.2516)  loss_mask: 0.3079 (0.2516)  loss_objectness: 0.0197 (0.0296)  loss_rpn_box_reg: 0.1797 (0.1634)  time: 0.4169  data: 0.2368  max mem: 0
# Epoch: [4]  [2900/2965]  eta: 0:00:25  lr: 0.000500  loss: 0.7227 (0.8580)  loss_classifier: 0.1447 (0.1620)  loss_box_reg: 0.2417 (0.2516)  loss_mask: 0.2633 (0.2516)  loss_objectness: 0.0167 (0.0296)  loss_rpn_box_reg: 0.0730 (0.1633)  time: 0.4209  data: 0.2408  max mem: 0
# Epoch: [4]  [2910/2965]  eta: 0:00:21  lr: 0.000500  loss: 0.7454 (0.8578)  loss_classifier: 0.1407 (0.1619)  loss_box_reg: 0.2517 (0.2516)  loss_mask: 0.2343 (0.2515)  loss_objectness: 0.0167 (0.0296)  loss_rpn_box_reg: 0.0852 (0.1632)  time: 0.4320  data: 0.2462  max mem: 0
# Epoch: [4]  [2920/2965]  eta: 0:00:17  lr: 0.000500  loss: 0.7718 (0.8577)  loss_classifier: 0.1407 (0.1619)  loss_box_reg: 0.2077 (0.2515)  loss_mask: 0.2103 (0.2514)  loss_objectness: 0.0213 (0.0296)  loss_rpn_box_reg: 0.1254 (0.1633)  time: 0.3941  data: 0.2111  max mem: 0
# Epoch: [4]  [2930/2965]  eta: 0:00:13  lr: 0.000500  loss: 0.7718 (0.8576)  loss_classifier: 0.1433 (0.1618)  loss_box_reg: 0.2063 (0.2514)  loss_mask: 0.2367 (0.2513)  loss_objectness: 0.0213 (0.0296)  loss_rpn_box_reg: 0.1254 (0.1635)  time: 0.4030  data: 0.2184  max mem: 0
# Epoch: [4]  [2940/2965]  eta: 0:00:09  lr: 0.000500  loss: 0.8384 (0.8578)  loss_classifier: 0.1581 (0.1619)  loss_box_reg: 0.2731 (0.2514)  loss_mask: 0.2781 (0.2514)  loss_objectness: 0.0242 (0.0296)  loss_rpn_box_reg: 0.1225 (0.1635)  time: 0.4405  data: 0.2550  max mem: 0
# Epoch: [4]  [2950/2965]  eta: 0:00:05  lr: 0.000500  loss: 0.8824 (0.8578)  loss_classifier: 0.1581 (0.1618)  loss_box_reg: 0.2633 (0.2515)  loss_mask: 0.2651 (0.2515)  loss_objectness: 0.0273 (0.0296)  loss_rpn_box_reg: 0.1648 (0.1634)  time: 0.4199  data: 0.2400  max mem: 0
# Epoch: [4]  [2960/2965]  eta: 0:00:01  lr: 0.000500  loss: 0.8830 (0.8581)  loss_classifier: 0.1607 (0.1619)  loss_box_reg: 0.2581 (0.2516)  loss_mask: 0.2483 (0.2515)  loss_objectness: 0.0280 (0.0296)  loss_rpn_box_reg: 0.1814 (0.1635)  time: 0.4095  data: 0.2292  max mem: 0
# Epoch: [4]  [2964/2965]  eta: 0:00:00  lr: 0.000500  loss: 0.8824 (0.8580)  loss_classifier: 0.1614 (0.1619)  loss_box_reg: 0.2473 (0.2515)  loss_mask: 0.2489 (0.2515)  loss_objectness: 0.0263 (0.0297)  loss_rpn_box_reg: 0.1814 (0.1634)  time: 0.4081  data: 0.2281  max mem: 0
# Epoch: [4] Total time: 0:19:44 (0.3995 s / it)
# Test:  [  0/500]  eta: 0:14:27  model_time: 0.6386 (0.6386)  evaluator_time: 0.6545 (0.6545)  time: 1.7354  data: 0.4359  max mem: 0
# Test:  [100/500]  eta: 0:10:38  model_time: 0.5801 (0.4770)  evaluator_time: 0.5755 (0.5935)  time: 1.6758  data: 0.5028  max mem: 0
# Test:  [200/500]  eta: 0:08:02  model_time: 0.5071 (0.5020)  evaluator_time: 0.5150 (0.5847)  time: 1.5720  data: 0.4365  max mem: 0

# %%
results = open("output_city_finetune.txt", "r")
print(results.read())

# %%
### Inference
