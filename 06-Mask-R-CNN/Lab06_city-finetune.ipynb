# %%
import torchvision
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
from torchvision.datasets import CocoDetection
import torch

import utils
from coco_utils_city import get_city
import transforms

# Load a model pre-trained on COCO and put it in inference mode

print('Loading pretrained model...')
model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
model.eval()

# Load the COCO 2017 train and val sets. We use the CocoDetection class definition
# from ./coco_utils.py, not the original torchvision.CocoDetection class. Also, we
# use transforms from ./transforms, not torchvision.transforms, because they need
# to transform the bboxes and masks along with the image.

# coco_path = "./COCO"

preprocess = transforms.Compose([
    transforms.ToTensor()
])
print('Loading Cityscapes train, val datasets...')
coco_train_dataset = get_city('train',preprocess)
coco_val_dataset = get_city('val',preprocess)

def collate_fn(batch):
    return tuple(zip(*batch))

train_dataloader = torch.utils.data.DataLoader(coco_train_dataset, batch_size=1, shuffle=True, num_workers=0, collate_fn=collate_fn)
val_dataloader = torch.utils.data.DataLoader(coco_val_dataset, batch_size=1, shuffle=False, num_workers=0, collate_fn=collate_fn)
# Out:
# Loading pretrained model...
# Loading Cityscapes train, val datasets...
# loading annotations into memory...
# Done (t=6.56s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=1.17s)
# creating index...
# index created!

# %%
from chosen_gpu import get_freer_gpu
device = torch.device(get_freer_gpu())# if torch.cuda.is_available() else torch.device("cpu")
print("Configured device: ", device)
# Out:
# Configured device:  cuda:2

# %%
#put model to device
model.to(device)
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign()
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign()
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace=True)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace=True)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace=True)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace=True)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace=True)
#       (mask_fcn_logits): Conv2d(256, 91, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
import numpy as np
import cv2
import random

# Array of labels for COCO dataset (91 elements)

coco_names = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# Random colors to use for labeling objects

COLORS = np.random.uniform(0, 255, size=(len(coco_names), 3)).astype(np.uint8)

# Overlay masks, bounding boxes, and labels on input numpy image

def draw_segmentation_map(image, masks, boxes, labels):
    alpha = 1
    beta = 0.5 # transparency for the segmentation map
    gamma = 0 # scalar added to each sum
    # convert from RGB to OpenCV BGR format
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    for i in range(len(masks)):
        mask = masks[i,:,:]
        red_map = np.zeros_like(mask).astype(np.uint8)
        green_map = np.zeros_like(mask).astype(np.uint8)
        blue_map = np.zeros_like(mask).astype(np.uint8)
        # apply a randon color mask to each object
        color = COLORS[random.randrange(0, len(COLORS))]
        red_map[mask > 0.5] = color[0]
        green_map[mask > 0.5] = color[1]
        blue_map[mask > 0.5] = color[2]
        # combine all the masks into a single image
        segmentation_map = np.stack([red_map, green_map, blue_map], axis=2)
        # apply colored mask to the image
        image = cv2.addWeighted(image, alpha, segmentation_map, beta, gamma)
        # draw the bounding box around each object
        p1 = (int(boxes[i][0]), int(boxes[i][1]))
        p2 = (int(boxes[i][2]), int(boxes[i][3]))
        color = (int(color[0]), int(color[1]), int(color[2]))
        cv2.rectangle(image, p1, p2, color, 2)
        # put the label text above the objects
        p = (int(boxes[i][0]), int(boxes[i][1]-10))
        cv2.putText(image, labels[i], p, cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)
    
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Overlay masks, bounding boxes, and labels of objects with scores greater than
# threshold on one of the images in the input tensor using the predictions output by Mask R-CNN.

def prediction_to_mask_image(images, predictions, img_index, threshold):
    scores = predictions[img_index]['scores']
    boxes_to_use = scores >= threshold
    img = (images[img_index].cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    masks = predictions[img_index]['masks'][boxes_to_use, :, :].cpu().detach().squeeze(1).numpy()
    boxes = predictions[img_index]['boxes'][boxes_to_use, :].cpu().detach().numpy()
    labels = predictions[img_index]['labels'][boxes_to_use].cpu().numpy()
    labels = [ coco_names[l] for l in labels ]

    return draw_segmentation_map(img, masks, boxes, labels)

# %%
from engine import train_one_epoch, evaluate
import utils
# Training
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=3,gamma=0.1)
num_epochs = 10
for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, train_dataloader, device, epoch, print_freq=10)
    lr_scheduler.step()
    evaluate(model, val_dataloader, device=device)

# for images, targets in train_dataloader:
#     images = list(image.to(device) for image in images)
#     targets = [{k: v for k, v in t.items()} for t in targets]
#     output = model(images,targets)   # Returns losses and detections
#     print(output)
#     break
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# Epoch: [0]  [   0/2965]  eta: 1:15:46  lr: 0.000010  loss: 1.6712 (1.6712)  loss_classifier: 0.8387 (0.8387)  loss_box_reg: 0.4069 (0.4069)  loss_mask: 0.2860 (0.2860)  loss_objectness: 0.1137 (0.1137)  loss_rpn_box_reg: 0.0260 (0.0260)  time: 1.5332  data: 1.1041  max mem: 0
# Epoch: [0]  [  10/2965]  eta: 0:27:38  lr: 0.000060  loss: 1.4807 (1.4741)  loss_classifier: 0.3395 (0.4278)  loss_box_reg: 0.3600 (0.3477)  loss_mask: 0.2860 (0.3125)  loss_objectness: 0.0964 (0.1899)  loss_rpn_box_reg: 0.0739 (0.1963)  time: 0.5612  data: 0.3630  max mem: 0
# Epoch: [0]  [  20/2965]  eta: 0:25:54  lr: 0.000110  loss: 1.3790 (1.5102)  loss_classifier: 0.3562 (0.4507)  loss_box_reg: 0.3963 (0.3836)  loss_mask: 0.3162 (0.3349)  loss_objectness: 0.0816 (0.1561)  loss_rpn_box_reg: 0.1423 (0.1849)  time: 0.4775  data: 0.3022  max mem: 0
# Epoch: [0]  [  30/2965]  eta: 0:25:36  lr: 0.000160  loss: 1.3533 (1.5734)  loss_classifier: 0.4195 (0.5032)  loss_box_reg: 0.4133 (0.3905)  loss_mask: 0.3320 (0.3485)  loss_objectness: 0.0617 (0.1418)  loss_rpn_box_reg: 0.1906 (0.1895)  time: 0.5027  data: 0.3231  max mem: 0
# Epoch: [0]  [  40/2965]  eta: 0:25:47  lr: 0.000210  loss: 1.5477 (1.5596)  loss_classifier: 0.2783 (0.4669)  loss_box_reg: 0.3790 (0.3878)  loss_mask: 0.3288 (0.3430)  loss_objectness: 0.0514 (0.1244)  loss_rpn_box_reg: 0.2407 (0.2375)  time: 0.5304  data: 0.3479  max mem: 0
# Epoch: [0]  [  50/2965]  eta: 0:25:10  lr: 0.000260  loss: 1.5477 (1.5677)  loss_classifier: 0.3090 (0.4551)  loss_box_reg: 0.3915 (0.3910)  loss_mask: 0.3288 (0.3460)  loss_objectness: 0.0617 (0.1152)  loss_rpn_box_reg: 0.2881 (0.2603)  time: 0.5103  data: 0.3319  max mem: 0
# Epoch: [0]  [  60/2965]  eta: 0:24:57  lr: 0.000310  loss: 1.2997 (1.5581)  loss_classifier: 0.3316 (0.4386)  loss_box_reg: 0.3820 (0.3886)  loss_mask: 0.3088 (0.3446)  loss_objectness: 0.0729 (0.1128)  loss_rpn_box_reg: 0.2911 (0.2735)  time: 0.4877  data: 0.3114  max mem: 0
# Epoch: [0]  [  70/2965]  eta: 0:24:58  lr: 0.000360  loss: 1.2847 (1.5403)  loss_classifier: 0.2576 (0.4372)  loss_box_reg: 0.3694 (0.3869)  loss_mask: 0.2932 (0.3422)  loss_objectness: 0.0659 (0.1058)  loss_rpn_box_reg: 0.2938 (0.2682)  time: 0.5154  data: 0.3359  max mem: 0
# Epoch: [0]  [  80/2965]  eta: 0:24:32  lr: 0.000410  loss: 1.3017 (1.4984)  loss_classifier: 0.2485 (0.4167)  loss_box_reg: 0.3559 (0.3799)  loss_mask: 0.3058 (0.3375)  loss_objectness: 0.0565 (0.1033)  loss_rpn_box_reg: 0.2251 (0.2610)  time: 0.4944  data: 0.3131  max mem: 0
# Epoch: [0]  [  90/2965]  eta: 0:24:08  lr: 0.000460  loss: 1.2426 (1.4628)  loss_classifier: 0.2485 (0.4054)  loss_box_reg: 0.3534 (0.3784)  loss_mask: 0.3080 (0.3346)  loss_objectness: 0.0477 (0.0966)  loss_rpn_box_reg: 0.1807 (0.2478)  time: 0.4560  data: 0.2787  max mem: 0
# Epoch: [0]  [ 100/2965]  eta: 0:23:45  lr: 0.000509  loss: 1.3771 (1.4692)  loss_classifier: 0.3362 (0.4056)  loss_box_reg: 0.4212 (0.3821)  loss_mask: 0.3328 (0.3366)  loss_objectness: 0.0409 (0.0949)  loss_rpn_box_reg: 0.1889 (0.2501)  time: 0.4456  data: 0.2698  max mem: 0
# Epoch: [0]  [ 110/2965]  eta: 0:23:25  lr: 0.000559  loss: 1.3972 (1.4589)  loss_classifier: 0.3492 (0.4055)  loss_box_reg: 0.3682 (0.3757)  loss_mask: 0.3335 (0.3312)  loss_objectness: 0.0644 (0.0932)  loss_rpn_box_reg: 0.2201 (0.2534)  time: 0.4401  data: 0.2647  max mem: 0
# Epoch: [0]  [ 120/2965]  eta: 0:23:04  lr: 0.000609  loss: 1.3398 (1.4422)  loss_classifier: 0.2973 (0.3959)  loss_box_reg: 0.3681 (0.3729)  loss_mask: 0.2852 (0.3285)  loss_objectness: 0.0644 (0.0932)  loss_rpn_box_reg: 0.1394 (0.2518)  time: 0.4316  data: 0.2584  max mem: 0
# Epoch: [0]  [ 130/2965]  eta: 0:23:01  lr: 0.000659  loss: 1.3248 (1.4408)  loss_classifier: 0.2578 (0.3914)  loss_box_reg: 0.3906 (0.3744)  loss_mask: 0.3103 (0.3301)  loss_objectness: 0.0650 (0.0916)  loss_rpn_box_reg: 0.2003 (0.2535)  time: 0.4590  data: 0.2850  max mem: 0
# Epoch: [0]  [ 140/2965]  eta: 0:22:49  lr: 0.000709  loss: 1.2172 (1.4277)  loss_classifier: 0.2368 (0.3839)  loss_box_reg: 0.3712 (0.3724)  loss_mask: 0.3268 (0.3315)  loss_objectness: 0.0449 (0.0885)  loss_rpn_box_reg: 0.2003 (0.2514)  time: 0.4728  data: 0.2984  max mem: 0
# Epoch: [0]  [ 150/2965]  eta: 0:22:42  lr: 0.000759  loss: 1.1708 (1.4190)  loss_classifier: 0.2840 (0.3802)  loss_box_reg: 0.3546 (0.3726)  loss_mask: 0.3374 (0.3319)  loss_objectness: 0.0382 (0.0874)  loss_rpn_box_reg: 0.1573 (0.2468)  time: 0.4615  data: 0.2867  max mem: 0
# Epoch: [0]  [ 160/2965]  eta: 0:22:26  lr: 0.000809  loss: 1.1710 (1.4111)  loss_classifier: 0.2840 (0.3738)  loss_box_reg: 0.3757 (0.3734)  loss_mask: 0.3328 (0.3320)  loss_objectness: 0.0507 (0.0858)  loss_rpn_box_reg: 0.1575 (0.2460)  time: 0.4474  data: 0.2711  max mem: 0
# Epoch: [0]  [ 170/2965]  eta: 0:22:19  lr: 0.000859  loss: 1.1728 (1.4032)  loss_classifier: 0.2088 (0.3668)  loss_box_reg: 0.4033 (0.3745)  loss_mask: 0.3188 (0.3306)  loss_objectness: 0.0544 (0.0844)  loss_rpn_box_reg: 0.2685 (0.2469)  time: 0.4445  data: 0.2671  max mem: 0
# Epoch: [0]  [ 180/2965]  eta: 0:22:14  lr: 0.000909  loss: 1.2217 (1.3956)  loss_classifier: 0.2354 (0.3605)  loss_box_reg: 0.3834 (0.3749)  loss_mask: 0.3038 (0.3294)  loss_objectness: 0.0588 (0.0834)  loss_rpn_box_reg: 0.2543 (0.2474)  time: 0.4713  data: 0.2920  max mem: 0
# Epoch: [0]  [ 190/2965]  eta: 0:22:05  lr: 0.000959  loss: 1.2617 (1.3942)  loss_classifier: 0.2670 (0.3591)  loss_box_reg: 0.3575 (0.3768)  loss_mask: 0.3243 (0.3293)  loss_objectness: 0.0593 (0.0827)  loss_rpn_box_reg: 0.1477 (0.2463)  time: 0.4634  data: 0.2839  max mem: 0
# Epoch: [0]  [ 200/2965]  eta: 0:21:57  lr: 0.001009  loss: 1.3518 (1.3980)  loss_classifier: 0.2689 (0.3542)  loss_box_reg: 0.4153 (0.3777)  loss_mask: 0.3459 (0.3297)  loss_objectness: 0.0434 (0.0836)  loss_rpn_box_reg: 0.2311 (0.2528)  time: 0.4537  data: 0.2755  max mem: 0
# Epoch: [0]  [ 210/2965]  eta: 0:21:46  lr: 0.001059  loss: 1.1672 (1.3830)  loss_classifier: 0.2086 (0.3481)  loss_box_reg: 0.3677 (0.3722)  loss_mask: 0.2922 (0.3266)  loss_objectness: 0.0511 (0.0829)  loss_rpn_box_reg: 0.2879 (0.2532)  time: 0.4403  data: 0.2655  max mem: 0
# Epoch: [0]  [ 220/2965]  eta: 0:21:44  lr: 0.001109  loss: 1.1112 (1.3737)  loss_classifier: 0.1554 (0.3414)  loss_box_reg: 0.2767 (0.3702)  loss_mask: 0.2732 (0.3261)  loss_objectness: 0.0588 (0.0822)  loss_rpn_box_reg: 0.2357 (0.2538)  time: 0.4605  data: 0.2853  max mem: 0
# Epoch: [0]  [ 230/2965]  eta: 0:21:39  lr: 0.001159  loss: 1.1805 (1.3691)  loss_classifier: 0.2236 (0.3381)  loss_box_reg: 0.3414 (0.3711)  loss_mask: 0.3020 (0.3252)  loss_objectness: 0.0564 (0.0810)  loss_rpn_box_reg: 0.2336 (0.2537)  time: 0.4864  data: 0.3083  max mem: 0
# Epoch: [0]  [ 240/2965]  eta: 0:21:38  lr: 0.001209  loss: 1.4010 (1.3746)  loss_classifier: 0.3009 (0.3386)  loss_box_reg: 0.3856 (0.3732)  loss_mask: 0.3056 (0.3252)  loss_objectness: 0.0564 (0.0802)  loss_rpn_box_reg: 0.2334 (0.2574)  time: 0.4927  data: 0.3137  max mem: 0
# Epoch: [0]  [ 250/2965]  eta: 0:21:29  lr: 0.001259  loss: 1.3556 (1.3656)  loss_classifier: 0.2857 (0.3342)  loss_box_reg: 0.4111 (0.3730)  loss_mask: 0.3049 (0.3240)  loss_objectness: 0.0419 (0.0785)  loss_rpn_box_reg: 0.2637 (0.2560)  time: 0.4737  data: 0.2954  max mem: 0
# Epoch: [0]  [ 260/2965]  eta: 0:21:23  lr: 0.001309  loss: 1.2652 (1.3600)  loss_classifier: 0.2761 (0.3326)  loss_box_reg: 0.3642 (0.3722)  loss_mask: 0.2891 (0.3225)  loss_objectness: 0.0419 (0.0786)  loss_rpn_box_reg: 0.1950 (0.2540)  time: 0.4511  data: 0.2740  max mem: 0
# Epoch: [0]  [ 270/2965]  eta: 0:21:12  lr: 0.001359  loss: 1.2468 (1.3576)  loss_classifier: 0.2761 (0.3293)  loss_box_reg: 0.3613 (0.3694)  loss_mask: 0.2934 (0.3223)  loss_objectness: 0.0519 (0.0785)  loss_rpn_box_reg: 0.2228 (0.2582)  time: 0.4358  data: 0.2606  max mem: 0
# Epoch: [0]  [ 280/2965]  eta: 0:21:06  lr: 0.001409  loss: 1.1893 (1.3517)  loss_classifier: 0.2695 (0.3267)  loss_box_reg: 0.3346 (0.3670)  loss_mask: 0.3026 (0.3211)  loss_objectness: 0.0520 (0.0781)  loss_rpn_box_reg: 0.2970 (0.2587)  time: 0.4351  data: 0.2619  max mem: 0
# Epoch: [0]  [ 290/2965]  eta: 0:21:07  lr: 0.001459  loss: 1.2717 (1.3581)  loss_classifier: 0.2742 (0.3262)  loss_box_reg: 0.3680 (0.3696)  loss_mask: 0.3307 (0.3222)  loss_objectness: 0.0614 (0.0791)  loss_rpn_box_reg: 0.2661 (0.2610)  time: 0.4965  data: 0.3185  max mem: 0
# Epoch: [0]  [ 300/2965]  eta: 0:20:59  lr: 0.001508  loss: 1.4178 (1.3555)  loss_classifier: 0.2742 (0.3241)  loss_box_reg: 0.3636 (0.3675)  loss_mask: 0.3307 (0.3224)  loss_objectness: 0.0786 (0.0795)  loss_rpn_box_reg: 0.2334 (0.2620)  time: 0.4825  data: 0.3035  max mem: 0
# Epoch: [0]  [ 310/2965]  eta: 0:20:55  lr: 0.001558  loss: 1.2588 (1.3526)  loss_classifier: 0.2680 (0.3225)  loss_box_reg: 0.3268 (0.3679)  loss_mask: 0.2825 (0.3220)  loss_objectness: 0.0786 (0.0793)  loss_rpn_box_reg: 0.2178 (0.2609)  time: 0.4604  data: 0.2825  max mem: 0
# Epoch: [0]  [ 320/2965]  eta: 0:20:48  lr: 0.001608  loss: 1.1743 (1.3572)  loss_classifier: 0.2623 (0.3217)  loss_box_reg: 0.3150 (0.3668)  loss_mask: 0.2951 (0.3221)  loss_objectness: 0.0723 (0.0848)  loss_rpn_box_reg: 0.1983 (0.2618)  time: 0.4628  data: 0.2818  max mem: 0
# Epoch: [0]  [ 330/2965]  eta: 0:20:44  lr: 0.001658  loss: 1.2125 (1.3548)  loss_classifier: 0.2958 (0.3209)  loss_box_reg: 0.3270 (0.3667)  loss_mask: 0.3215 (0.3229)  loss_objectness: 0.0930 (0.0855)  loss_rpn_box_reg: 0.1380 (0.2588)  time: 0.4597  data: 0.2797  max mem: 0
# Epoch: [0]  [ 340/2965]  eta: 0:20:41  lr: 0.001708  loss: 1.4190 (1.3589)  loss_classifier: 0.2560 (0.3193)  loss_box_reg: 0.4150 (0.3678)  loss_mask: 0.3519 (0.3234)  loss_objectness: 0.0957 (0.0857)  loss_rpn_box_reg: 0.2763 (0.2628)  time: 0.4917  data: 0.3138  max mem: 0
# Epoch: [0]  [ 350/2965]  eta: 0:20:35  lr: 0.001758  loss: 1.4076 (1.3540)  loss_classifier: 0.2469 (0.3178)  loss_box_reg: 0.4150 (0.3677)  loss_mask: 0.3459 (0.3233)  loss_objectness: 0.0577 (0.0847)  loss_rpn_box_reg: 0.2329 (0.2604)  time: 0.4783  data: 0.3016  max mem: 0
# Epoch: [0]  [ 360/2965]  eta: 0:20:26  lr: 0.001808  loss: 1.2049 (1.3497)  loss_classifier: 0.2179 (0.3158)  loss_box_reg: 0.3268 (0.3673)  loss_mask: 0.3538 (0.3235)  loss_objectness: 0.0360 (0.0838)  loss_rpn_box_reg: 0.1733 (0.2593)  time: 0.4302  data: 0.2550  max mem: 0
# Epoch: [0]  [ 370/2965]  eta: 0:20:18  lr: 0.001858  loss: 1.1676 (1.3478)  loss_classifier: 0.2575 (0.3155)  loss_box_reg: 0.3530 (0.3673)  loss_mask: 0.3068 (0.3226)  loss_objectness: 0.0384 (0.0829)  loss_rpn_box_reg: 0.1763 (0.2595)  time: 0.4178  data: 0.2428  max mem: 0
# Epoch: [0]  [ 380/2965]  eta: 0:20:16  lr: 0.001908  loss: 1.1676 (1.3474)  loss_classifier: 0.3381 (0.3150)  loss_box_reg: 0.3751 (0.3683)  loss_mask: 0.3060 (0.3231)  loss_objectness: 0.0384 (0.0822)  loss_rpn_box_reg: 0.2458 (0.2588)  time: 0.4696  data: 0.2926  max mem: 0
# Epoch: [0]  [ 390/2965]  eta: 0:20:11  lr: 0.001958  loss: 1.3089 (1.3445)  loss_classifier: 0.2738 (0.3136)  loss_box_reg: 0.4064 (0.3689)  loss_mask: 0.3715 (0.3237)  loss_objectness: 0.0404 (0.0811)  loss_rpn_box_reg: 0.2458 (0.2571)  time: 0.4895  data: 0.3130  max mem: 0
# Epoch: [0]  [ 400/2965]  eta: 0:20:07  lr: 0.002008  loss: 1.2876 (1.3427)  loss_classifier: 0.2562 (0.3139)  loss_box_reg: 0.3887 (0.3693)  loss_mask: 0.3099 (0.3232)  loss_objectness: 0.0470 (0.0810)  loss_rpn_box_reg: 0.1297 (0.2553)  time: 0.4715  data: 0.2959  max mem: 0
# Epoch: [0]  [ 410/2965]  eta: 0:20:00  lr: 0.002058  loss: 1.2889 (1.3426)  loss_classifier: 0.2760 (0.3133)  loss_box_reg: 0.4116 (0.3704)  loss_mask: 0.3067 (0.3234)  loss_objectness: 0.0550 (0.0805)  loss_rpn_box_reg: 0.1894 (0.2551)  time: 0.4590  data: 0.2804  max mem: 0
# Epoch: [0]  [ 420/2965]  eta: 0:19:56  lr: 0.002108  loss: 1.3639 (1.3427)  loss_classifier: 0.2390 (0.3116)  loss_box_reg: 0.4116 (0.3705)  loss_mask: 0.3067 (0.3226)  loss_objectness: 0.0472 (0.0799)  loss_rpn_box_reg: 0.3215 (0.2582)  time: 0.4600  data: 0.2802  max mem: 0
# Epoch: [0]  [ 430/2965]  eta: 0:19:53  lr: 0.002158  loss: 1.3713 (1.3418)  loss_classifier: 0.2318 (0.3101)  loss_box_reg: 0.3393 (0.3702)  loss_mask: 0.2968 (0.3221)  loss_objectness: 0.0463 (0.0792)  loss_rpn_box_reg: 0.3889 (0.2601)  time: 0.4827  data: 0.3027  max mem: 0
# Epoch: [0]  [ 440/2965]  eta: 0:19:47  lr: 0.002208  loss: 1.2087 (1.3410)  loss_classifier: 0.2366 (0.3104)  loss_box_reg: 0.3492 (0.3705)  loss_mask: 0.2706 (0.3214)  loss_objectness: 0.0442 (0.0796)  loss_rpn_box_reg: 0.2718 (0.2590)  time: 0.4761  data: 0.2967  max mem: 0
# Epoch: [0]  [ 450/2965]  eta: 0:19:41  lr: 0.002258  loss: 1.3100 (1.3424)  loss_classifier: 0.2387 (0.3098)  loss_box_reg: 0.3593 (0.3699)  loss_mask: 0.2915 (0.3213)  loss_objectness: 0.0606 (0.0802)  loss_rpn_box_reg: 0.2545 (0.2612)  time: 0.4526  data: 0.2759  max mem: 0
# Epoch: [0]  [ 460/2965]  eta: 0:19:36  lr: 0.002308  loss: 1.1609 (1.3400)  loss_classifier: 0.2699 (0.3096)  loss_box_reg: 0.3568 (0.3698)  loss_mask: 0.2915 (0.3209)  loss_objectness: 0.0726 (0.0801)  loss_rpn_box_reg: 0.1144 (0.2596)  time: 0.4494  data: 0.2732  max mem: 0
# Epoch: [0]  [ 470/2965]  eta: 0:19:30  lr: 0.002358  loss: 1.0154 (1.3343)  loss_classifier: 0.2402 (0.3079)  loss_box_reg: 0.3417 (0.3681)  loss_mask: 0.2801 (0.3202)  loss_objectness: 0.0592 (0.0795)  loss_rpn_box_reg: 0.1030 (0.2586)  time: 0.4558  data: 0.2820  max mem: 0
# Epoch: [0]  [ 480/2965]  eta: 0:19:30  lr: 0.002408  loss: 1.2032 (1.3315)  loss_classifier: 0.2383 (0.3070)  loss_box_reg: 0.3417 (0.3675)  loss_mask: 0.2751 (0.3196)  loss_objectness: 0.0395 (0.0787)  loss_rpn_box_reg: 0.2108 (0.2587)  time: 0.5055  data: 0.3320  max mem: 0
# Epoch: [0]  [ 490/2965]  eta: 0:19:26  lr: 0.002458  loss: 1.1813 (1.3306)  loss_classifier: 0.2134 (0.3065)  loss_box_reg: 0.3572 (0.3686)  loss_mask: 0.2658 (0.3191)  loss_objectness: 0.0395 (0.0789)  loss_rpn_box_reg: 0.2072 (0.2574)  time: 0.5211  data: 0.3425  max mem: 0
# Epoch: [0]  [ 500/2965]  eta: 0:19:19  lr: 0.002507  loss: 1.1248 (1.3243)  loss_classifier: 0.2046 (0.3044)  loss_box_reg: 0.3491 (0.3679)  loss_mask: 0.2744 (0.3179)  loss_objectness: 0.0438 (0.0781)  loss_rpn_box_reg: 0.1370 (0.2559)  time: 0.4594  data: 0.2818  max mem: 0
# Epoch: [0]  [ 510/2965]  eta: 0:19:11  lr: 0.002557  loss: 1.1248 (1.3223)  loss_classifier: 0.2132 (0.3037)  loss_box_reg: 0.3734 (0.3677)  loss_mask: 0.2935 (0.3181)  loss_objectness: 0.0438 (0.0779)  loss_rpn_box_reg: 0.1549 (0.2549)  time: 0.4174  data: 0.2449  max mem: 0
# Epoch: [0]  [ 520/2965]  eta: 0:19:04  lr: 0.002607  loss: 1.0028 (1.3159)  loss_classifier: 0.1928 (0.3014)  loss_box_reg: 0.3340 (0.3661)  loss_mask: 0.3217 (0.3175)  loss_objectness: 0.0492 (0.0772)  loss_rpn_box_reg: 0.1549 (0.2537)  time: 0.4079  data: 0.2382  max mem: 0
# Epoch: [0]  [ 530/2965]  eta: 0:19:02  lr: 0.002657  loss: 1.0575 (1.3185)  loss_classifier: 0.2078 (0.3018)  loss_box_reg: 0.3437 (0.3668)  loss_mask: 0.2906 (0.3175)  loss_objectness: 0.0426 (0.0783)  loss_rpn_box_reg: 0.2136 (0.2542)  time: 0.4706  data: 0.2941  max mem: 0
# Epoch: [0]  [ 540/2965]  eta: 0:18:58  lr: 0.002707  loss: 1.1674 (1.3172)  loss_classifier: 0.2548 (0.3011)  loss_box_reg: 0.3735 (0.3665)  loss_mask: 0.3156 (0.3176)  loss_objectness: 0.0536 (0.0790)  loss_rpn_box_reg: 0.2136 (0.2530)  time: 0.5082  data: 0.3220  max mem: 0
# Epoch: [0]  [ 550/2965]  eta: 0:18:51  lr: 0.002757  loss: 1.1242 (1.3142)  loss_classifier: 0.2650 (0.3000)  loss_box_reg: 0.3743 (0.3663)  loss_mask: 0.3407 (0.3180)  loss_objectness: 0.0581 (0.0791)  loss_rpn_box_reg: 0.1288 (0.2507)  time: 0.4518  data: 0.2690  max mem: 0
# Epoch: [0]  [ 560/2965]  eta: 0:18:47  lr: 0.002807  loss: 1.2925 (1.3161)  loss_classifier: 0.2776 (0.2996)  loss_box_reg: 0.3765 (0.3663)  loss_mask: 0.3247 (0.3179)  loss_objectness: 0.0779 (0.0794)  loss_rpn_box_reg: 0.1290 (0.2529)  time: 0.4436  data: 0.2663  max mem: 0
# Epoch: [0]  [ 570/2965]  eta: 0:18:39  lr: 0.002857  loss: 1.3204 (1.3126)  loss_classifier: 0.2776 (0.2990)  loss_box_reg: 0.3666 (0.3656)  loss_mask: 0.2853 (0.3168)  loss_objectness: 0.0730 (0.0793)  loss_rpn_box_reg: 0.2366 (0.2518)  time: 0.4320  data: 0.2554  max mem: 0
# Epoch: [0]  [ 580/2965]  eta: 0:18:35  lr: 0.002907  loss: 1.2676 (1.3122)  loss_classifier: 0.2119 (0.2971)  loss_box_reg: 0.3160 (0.3652)  loss_mask: 0.2853 (0.3168)  loss_objectness: 0.0804 (0.0809)  loss_rpn_box_reg: 0.1974 (0.2521)  time: 0.4457  data: 0.2708  max mem: 0
# Epoch: [0]  [ 590/2965]  eta: 0:18:32  lr: 0.002957  loss: 1.3864 (1.3154)  loss_classifier: 0.2441 (0.2971)  loss_box_reg: 0.3498 (0.3659)  loss_mask: 0.3240 (0.3169)  loss_objectness: 0.1081 (0.0815)  loss_rpn_box_reg: 0.2986 (0.2541)  time: 0.4927  data: 0.3148  max mem: 0
# Epoch: [0]  [ 600/2965]  eta: 0:18:25  lr: 0.003007  loss: 1.3965 (1.3132)  loss_classifier: 0.2854 (0.2962)  loss_box_reg: 0.4092 (0.3658)  loss_mask: 0.3131 (0.3170)  loss_objectness: 0.0674 (0.0811)  loss_rpn_box_reg: 0.2337 (0.2531)  time: 0.4595  data: 0.2813  max mem: 0
# Epoch: [0]  [ 610/2965]  eta: 0:18:19  lr: 0.003057  loss: 1.2447 (1.3132)  loss_classifier: 0.2886 (0.2959)  loss_box_reg: 0.4092 (0.3655)  loss_mask: 0.3232 (0.3175)  loss_objectness: 0.0748 (0.0826)  loss_rpn_box_reg: 0.1648 (0.2518)  time: 0.4287  data: 0.2549  max mem: 0
# Epoch: [0]  [ 620/2965]  eta: 0:18:18  lr: 0.003107  loss: 1.2447 (1.3140)  loss_classifier: 0.2671 (0.2961)  loss_box_reg: 0.3844 (0.3658)  loss_mask: 0.3547 (0.3179)  loss_objectness: 0.1199 (0.0830)  loss_rpn_box_reg: 0.1200 (0.2512)  time: 0.4976  data: 0.3183  max mem: 0
# Epoch: [0]  [ 630/2965]  eta: 0:18:13  lr: 0.003157  loss: 1.4048 (1.3149)  loss_classifier: 0.2671 (0.2962)  loss_box_reg: 0.4023 (0.3667)  loss_mask: 0.3321 (0.3180)  loss_objectness: 0.0772 (0.0828)  loss_rpn_box_reg: 0.2353 (0.2512)  time: 0.5083  data: 0.3259  max mem: 0
# Epoch: [0]  [ 640/2965]  eta: 0:18:09  lr: 0.003207  loss: 1.3061 (1.3131)  loss_classifier: 0.2899 (0.2962)  loss_box_reg: 0.4252 (0.3668)  loss_mask: 0.3039 (0.3177)  loss_objectness: 0.0554 (0.0824)  loss_rpn_box_reg: 0.1345 (0.2500)  time: 0.4725  data: 0.2938  max mem: 0
# Epoch: [0]  [ 650/2965]  eta: 0:18:05  lr: 0.003257  loss: 1.2152 (1.3139)  loss_classifier: 0.3020 (0.2965)  loss_box_reg: 0.3843 (0.3671)  loss_mask: 0.2916 (0.3177)  loss_objectness: 0.0687 (0.0824)  loss_rpn_box_reg: 0.1345 (0.2502)  time: 0.4905  data: 0.3107  max mem: 0
# Epoch: [0]  [ 660/2965]  eta: 0:17:59  lr: 0.003307  loss: 1.3644 (1.3117)  loss_classifier: 0.2692 (0.2958)  loss_box_reg: 0.3667 (0.3664)  loss_mask: 0.3250 (0.3180)  loss_objectness: 0.0730 (0.0821)  loss_rpn_box_reg: 0.1986 (0.2494)  time: 0.4568  data: 0.2820  max mem: 0
# Epoch: [0]  [ 670/2965]  eta: 0:17:55  lr: 0.003357  loss: 1.2659 (1.3113)  loss_classifier: 0.2519 (0.2951)  loss_box_reg: 0.3862 (0.3670)  loss_mask: 0.3250 (0.3182)  loss_objectness: 0.0407 (0.0814)  loss_rpn_box_reg: 0.1940 (0.2495)  time: 0.4599  data: 0.2860  max mem: 0
# Epoch: [0]  [ 680/2965]  eta: 0:17:52  lr: 0.003407  loss: 1.4344 (1.3138)  loss_classifier: 0.2806 (0.2956)  loss_box_reg: 0.4416 (0.3680)  loss_mask: 0.3189 (0.3185)  loss_objectness: 0.0426 (0.0814)  loss_rpn_box_reg: 0.2404 (0.2503)  time: 0.5050  data: 0.3231  max mem: 0
# Epoch: [0]  [ 690/2965]  eta: 0:17:46  lr: 0.003457  loss: 1.4344 (1.3120)  loss_classifier: 0.3064 (0.2952)  loss_box_reg: 0.3903 (0.3678)  loss_mask: 0.3066 (0.3183)  loss_objectness: 0.0585 (0.0812)  loss_rpn_box_reg: 0.2404 (0.2496)  time: 0.4747  data: 0.2941  max mem: 0
# Epoch: [0]  [ 700/2965]  eta: 0:17:40  lr: 0.003506  loss: 1.2054 (1.3125)  loss_classifier: 0.2778 (0.2953)  loss_box_reg: 0.3770 (0.3683)  loss_mask: 0.2940 (0.3183)  loss_objectness: 0.0597 (0.0818)  loss_rpn_box_reg: 0.1649 (0.2489)  time: 0.4300  data: 0.2524  max mem: 0
# Epoch: [0]  [ 710/2965]  eta: 0:17:34  lr: 0.003556  loss: 1.2017 (1.3096)  loss_classifier: 0.2627 (0.2944)  loss_box_reg: 0.3753 (0.3678)  loss_mask: 0.2908 (0.3182)  loss_objectness: 0.0550 (0.0814)  loss_rpn_box_reg: 0.0976 (0.2478)  time: 0.4209  data: 0.2455  max mem: 0
# Epoch: [0]  [ 720/2965]  eta: 0:17:31  lr: 0.003606  loss: 1.3064 (1.3120)  loss_classifier: 0.2317 (0.2950)  loss_box_reg: 0.3625 (0.3688)  loss_mask: 0.3453 (0.3186)  loss_objectness: 0.0534 (0.0815)  loss_rpn_box_reg: 0.1969 (0.2481)  time: 0.4713  data: 0.2933  max mem: 0
# Epoch: [0]  [ 730/2965]  eta: 0:17:27  lr: 0.003656  loss: 1.4457 (1.3132)  loss_classifier: 0.3169 (0.2952)  loss_box_reg: 0.4334 (0.3695)  loss_mask: 0.3453 (0.3189)  loss_objectness: 0.0653 (0.0811)  loss_rpn_box_reg: 0.3070 (0.2486)  time: 0.5077  data: 0.3262  max mem: 0
# Epoch: [0]  [ 740/2965]  eta: 0:17:23  lr: 0.003706  loss: 1.4645 (1.3170)  loss_classifier: 0.2830 (0.2953)  loss_box_reg: 0.4246 (0.3705)  loss_mask: 0.3688 (0.3218)  loss_objectness: 0.0459 (0.0808)  loss_rpn_box_reg: 0.2581 (0.2486)  time: 0.4854  data: 0.3072  max mem: 0
# Epoch: [0]  [ 750/2965]  eta: 0:17:19  lr: 0.003756  loss: 1.5654 (1.3197)  loss_classifier: 0.2906 (0.2956)  loss_box_reg: 0.4032 (0.3705)  loss_mask: 0.4429 (0.3231)  loss_objectness: 0.0769 (0.0817)  loss_rpn_box_reg: 0.2581 (0.2489)  time: 0.4946  data: 0.3164  max mem: 0
# Epoch: [0]  [ 760/2965]  eta: 0:17:13  lr: 0.003806  loss: 1.4505 (1.3215)  loss_classifier: 0.2796 (0.2954)  loss_box_reg: 0.4032 (0.3712)  loss_mask: 0.3824 (0.3237)  loss_objectness: 0.0930 (0.0820)  loss_rpn_box_reg: 0.2574 (0.2492)  time: 0.4665  data: 0.2884  max mem: 0
# Epoch: [0]  [ 770/2965]  eta: 0:17:08  lr: 0.003856  loss: 1.4505 (1.3229)  loss_classifier: 0.2796 (0.2954)  loss_box_reg: 0.3988 (0.3716)  loss_mask: 0.3723 (0.3240)  loss_objectness: 0.1057 (0.0826)  loss_rpn_box_reg: 0.2045 (0.2492)  time: 0.4361  data: 0.2571  max mem: 0
# Epoch: [0]  [ 780/2965]  eta: 0:17:02  lr: 0.003906  loss: 1.2831 (1.3224)  loss_classifier: 0.2893 (0.2951)  loss_box_reg: 0.3763 (0.3716)  loss_mask: 0.3240 (0.3243)  loss_objectness: 0.0892 (0.0826)  loss_rpn_box_reg: 0.2045 (0.2488)  time: 0.4316  data: 0.2532  max mem: 0
# Epoch: [0]  [ 790/2965]  eta: 0:16:58  lr: 0.003956  loss: 1.2721 (1.3218)  loss_classifier: 0.2595 (0.2945)  loss_box_reg: 0.3642 (0.3716)  loss_mask: 0.3022 (0.3242)  loss_objectness: 0.0575 (0.0822)  loss_rpn_box_reg: 0.2524 (0.2492)  time: 0.4651  data: 0.2862  max mem: 0
# Epoch: [0]  [ 800/2965]  eta: 0:16:55  lr: 0.004006  loss: 1.3451 (1.3229)  loss_classifier: 0.2628 (0.2947)  loss_box_reg: 0.3574 (0.3716)  loss_mask: 0.3022 (0.3241)  loss_objectness: 0.0575 (0.0825)  loss_rpn_box_reg: 0.3290 (0.2501)  time: 0.5090  data: 0.3259  max mem: 0
# Epoch: [0]  [ 810/2965]  eta: 0:16:49  lr: 0.004056  loss: 1.4179 (1.3234)  loss_classifier: 0.2802 (0.2945)  loss_box_reg: 0.3986 (0.3719)  loss_mask: 0.3212 (0.3241)  loss_objectness: 0.0816 (0.0825)  loss_rpn_box_reg: 0.3020 (0.2504)  time: 0.4800  data: 0.2992  max mem: 0
# Epoch: [0]  [ 820/2965]  eta: 0:16:45  lr: 0.004106  loss: 1.4911 (1.3240)  loss_classifier: 0.2752 (0.2950)  loss_box_reg: 0.4137 (0.3721)  loss_mask: 0.3406 (0.3241)  loss_objectness: 0.0820 (0.0825)  loss_rpn_box_reg: 0.1691 (0.2504)  time: 0.4564  data: 0.2797  max mem: 0
# Epoch: [0]  [ 830/2965]  eta: 0:16:39  lr: 0.004156  loss: 1.1086 (1.3214)  loss_classifier: 0.2455 (0.2942)  loss_box_reg: 0.2879 (0.3712)  loss_mask: 0.2769 (0.3235)  loss_objectness: 0.0489 (0.0821)  loss_rpn_box_reg: 0.1616 (0.2504)  time: 0.4400  data: 0.2669  max mem: 0
# Epoch: [0]  [ 840/2965]  eta: 0:16:33  lr: 0.004206  loss: 1.0958 (1.3204)  loss_classifier: 0.2091 (0.2940)  loss_box_reg: 0.2990 (0.3711)  loss_mask: 0.2556 (0.3234)  loss_objectness: 0.0417 (0.0816)  loss_rpn_box_reg: 0.2489 (0.2502)  time: 0.4341  data: 0.2595  max mem: 0
# Epoch: [0]  [ 850/2965]  eta: 0:16:28  lr: 0.004256  loss: 1.2078 (1.3215)  loss_classifier: 0.2965 (0.2944)  loss_box_reg: 0.3709 (0.3710)  loss_mask: 0.3375 (0.3239)  loss_objectness: 0.0375 (0.0816)  loss_rpn_box_reg: 0.2614 (0.2506)  time: 0.4508  data: 0.2729  max mem: 0
# Epoch: [0]  [ 860/2965]  eta: 0:16:23  lr: 0.004306  loss: 1.2638 (1.3234)  loss_classifier: 0.2965 (0.2940)  loss_box_reg: 0.3812 (0.3715)  loss_mask: 0.3310 (0.3238)  loss_objectness: 0.0732 (0.0820)  loss_rpn_box_reg: 0.1337 (0.2521)  time: 0.4481  data: 0.2712  max mem: 0
# Epoch: [0]  [ 870/2965]  eta: 0:16:17  lr: 0.004356  loss: 1.1765 (1.3238)  loss_classifier: 0.2880 (0.2941)  loss_box_reg: 0.3812 (0.3718)  loss_mask: 0.2796 (0.3235)  loss_objectness: 0.0770 (0.0818)  loss_rpn_box_reg: 0.0802 (0.2526)  time: 0.4251  data: 0.2465  max mem: 0
# Epoch: [0]  [ 880/2965]  eta: 0:16:12  lr: 0.004406  loss: 1.5039 (1.3263)  loss_classifier: 0.2909 (0.2943)  loss_box_reg: 0.4231 (0.3725)  loss_mask: 0.3125 (0.3238)  loss_objectness: 0.0729 (0.0819)  loss_rpn_box_reg: 0.2312 (0.2538)  time: 0.4327  data: 0.2528  max mem: 0
# Epoch: [0]  [ 890/2965]  eta: 0:16:07  lr: 0.004456  loss: 1.6738 (1.3299)  loss_classifier: 0.2909 (0.2944)  loss_box_reg: 0.4305 (0.3726)  loss_mask: 0.3652 (0.3243)  loss_objectness: 0.1164 (0.0832)  loss_rpn_box_reg: 0.2909 (0.2554)  time: 0.4471  data: 0.2686  max mem: 0
# Epoch: [0]  [ 900/2965]  eta: 0:16:02  lr: 0.004505  loss: 1.4429 (1.3298)  loss_classifier: 0.2706 (0.2942)  loss_box_reg: 0.3619 (0.3723)  loss_mask: 0.3348 (0.3240)  loss_objectness: 0.1134 (0.0838)  loss_rpn_box_reg: 0.2429 (0.2555)  time: 0.4504  data: 0.2735  max mem: 0
# Epoch: [0]  [ 910/2965]  eta: 0:15:56  lr: 0.004555  loss: 1.2740 (1.3305)  loss_classifier: 0.3029 (0.2946)  loss_box_reg: 0.4247 (0.3728)  loss_mask: 0.3152 (0.3240)  loss_objectness: 0.1039 (0.0840)  loss_rpn_box_reg: 0.1995 (0.2550)  time: 0.4437  data: 0.2679  max mem: 0
# Epoch: [0]  [ 920/2965]  eta: 0:15:51  lr: 0.004605  loss: 1.3719 (1.3312)  loss_classifier: 0.2910 (0.2949)  loss_box_reg: 0.4247 (0.3733)  loss_mask: 0.3056 (0.3239)  loss_objectness: 0.0802 (0.0842)  loss_rpn_box_reg: 0.1344 (0.2550)  time: 0.4343  data: 0.2566  max mem: 0
# Epoch: [0]  [ 930/2965]  eta: 0:15:46  lr: 0.004655  loss: 1.2186 (1.3288)  loss_classifier: 0.2578 (0.2941)  loss_box_reg: 0.3736 (0.3729)  loss_mask: 0.2918 (0.3232)  loss_objectness: 0.0652 (0.0844)  loss_rpn_box_reg: 0.1547 (0.2543)  time: 0.4310  data: 0.2547  max mem: 0
# Epoch: [0]  [ 940/2965]  eta: 0:15:40  lr: 0.004705  loss: 1.2186 (1.3285)  loss_classifier: 0.2629 (0.2938)  loss_box_reg: 0.3859 (0.3732)  loss_mask: 0.3246 (0.3235)  loss_objectness: 0.0571 (0.0841)  loss_rpn_box_reg: 0.1547 (0.2539)  time: 0.4249  data: 0.2513  max mem: 0
# Epoch: [0]  [ 950/2965]  eta: 0:15:35  lr: 0.004755  loss: 1.2789 (1.3283)  loss_classifier: 0.2686 (0.2937)  loss_box_reg: 0.4179 (0.3736)  loss_mask: 0.3264 (0.3234)  loss_objectness: 0.0547 (0.0839)  loss_rpn_box_reg: 0.1652 (0.2537)  time: 0.4441  data: 0.2671  max mem: 0
# Epoch: [0]  [ 960/2965]  eta: 0:15:30  lr: 0.004805  loss: 1.2706 (1.3283)  loss_classifier: 0.2714 (0.2935)  loss_box_reg: 0.3905 (0.3732)  loss_mask: 0.2939 (0.3232)  loss_objectness: 0.0932 (0.0848)  loss_rpn_box_reg: 0.2011 (0.2536)  time: 0.4433  data: 0.2657  max mem: 0
# Epoch: [0]  [ 970/2965]  eta: 0:15:26  lr: 0.004855  loss: 1.3582 (1.3287)  loss_classifier: 0.2427 (0.2931)  loss_box_reg: 0.3716 (0.3733)  loss_mask: 0.2862 (0.3231)  loss_objectness: 0.1094 (0.0851)  loss_rpn_box_reg: 0.2295 (0.2542)  time: 0.4617  data: 0.2833  max mem: 0
# Epoch: [0]  [ 980/2965]  eta: 0:15:21  lr: 0.004905  loss: 1.3582 (1.3289)  loss_classifier: 0.2427 (0.2928)  loss_box_reg: 0.3814 (0.3736)  loss_mask: 0.3449 (0.3233)  loss_objectness: 0.0929 (0.0852)  loss_rpn_box_reg: 0.2328 (0.2540)  time: 0.4701  data: 0.2901  max mem: 0
# Epoch: [0]  [ 990/2965]  eta: 0:15:17  lr: 0.004955  loss: 1.3186 (1.3278)  loss_classifier: 0.2062 (0.2923)  loss_box_reg: 0.3948 (0.3733)  loss_mask: 0.3531 (0.3230)  loss_objectness: 0.0737 (0.0852)  loss_rpn_box_reg: 0.2048 (0.2540)  time: 0.4704  data: 0.2913  max mem: 0
# Epoch: [0]  [1000/2965]  eta: 0:15:12  lr: 0.005000  loss: 1.3624 (1.3279)  loss_classifier: 0.2337 (0.2922)  loss_box_reg: 0.3514 (0.3732)  loss_mask: 0.3480 (0.3234)  loss_objectness: 0.0675 (0.0854)  loss_rpn_box_reg: 0.2048 (0.2537)  time: 0.4607  data: 0.2853  max mem: 0
# Epoch: [0]  [1010/2965]  eta: 0:15:06  lr: 0.005000  loss: 1.1493 (1.3260)  loss_classifier: 0.2337 (0.2917)  loss_box_reg: 0.3514 (0.3726)  loss_mask: 0.3412 (0.3233)  loss_objectness: 0.0799 (0.0858)  loss_rpn_box_reg: 0.0817 (0.2526)  time: 0.4319  data: 0.2599  max mem: 0
# Epoch: [0]  [1020/2965]  eta: 0:15:01  lr: 0.005000  loss: 1.0564 (1.3254)  loss_classifier: 0.2958 (0.2917)  loss_box_reg: 0.3328 (0.3726)  loss_mask: 0.3104 (0.3231)  loss_objectness: 0.0696 (0.0859)  loss_rpn_box_reg: 0.0399 (0.2522)  time: 0.4287  data: 0.2558  max mem: 0
# Epoch: [0]  [1030/2965]  eta: 0:14:57  lr: 0.005000  loss: 1.2456 (1.3254)  loss_classifier: 0.2624 (0.2919)  loss_box_reg: 0.3648 (0.3727)  loss_mask: 0.2763 (0.3227)  loss_objectness: 0.0696 (0.0860)  loss_rpn_box_reg: 0.1280 (0.2521)  time: 0.4496  data: 0.2735  max mem: 0
# Epoch: [0]  [1040/2965]  eta: 0:14:52  lr: 0.005000  loss: 1.2456 (1.3238)  loss_classifier: 0.2372 (0.2911)  loss_box_reg: 0.3521 (0.3723)  loss_mask: 0.3114 (0.3228)  loss_objectness: 0.0696 (0.0859)  loss_rpn_box_reg: 0.1280 (0.2517)  time: 0.4587  data: 0.2834  max mem: 0
# Epoch: [0]  [1050/2965]  eta: 0:14:47  lr: 0.005000  loss: 1.3213 (1.3246)  loss_classifier: 0.2838 (0.2913)  loss_box_reg: 0.4053 (0.3727)  loss_mask: 0.3279 (0.3228)  loss_objectness: 0.0511 (0.0857)  loss_rpn_box_reg: 0.2112 (0.2520)  time: 0.4598  data: 0.2830  max mem: 0
# Epoch: [0]  [1060/2965]  eta: 0:14:42  lr: 0.005000  loss: 1.4014 (1.3244)  loss_classifier: 0.2901 (0.2912)  loss_box_reg: 0.3875 (0.3723)  loss_mask: 0.3325 (0.3229)  loss_objectness: 0.0503 (0.0857)  loss_rpn_box_reg: 0.2339 (0.2522)  time: 0.4552  data: 0.2781  max mem: 0
# Epoch: [0]  [1070/2965]  eta: 0:14:38  lr: 0.005000  loss: 1.3860 (1.3256)  loss_classifier: 0.2559 (0.2914)  loss_box_reg: 0.4240 (0.3733)  loss_mask: 0.3325 (0.3233)  loss_objectness: 0.0707 (0.0856)  loss_rpn_box_reg: 0.2339 (0.2519)  time: 0.4681  data: 0.2923  max mem: 0
# Epoch: [0]  [1080/2965]  eta: 0:14:34  lr: 0.005000  loss: 1.3860 (1.3253)  loss_classifier: 0.2821 (0.2913)  loss_box_reg: 0.4627 (0.3736)  loss_mask: 0.3270 (0.3232)  loss_objectness: 0.0640 (0.0854)  loss_rpn_box_reg: 0.2366 (0.2518)  time: 0.4899  data: 0.3110  max mem: 0
# Epoch: [0]  [1090/2965]  eta: 0:14:29  lr: 0.005000  loss: 1.3613 (1.3240)  loss_classifier: 0.2658 (0.2908)  loss_box_reg: 0.4129 (0.3733)  loss_mask: 0.2724 (0.3228)  loss_objectness: 0.0515 (0.0852)  loss_rpn_box_reg: 0.2366 (0.2519)  time: 0.4844  data: 0.3065  max mem: 0
# Epoch: [0]  [1100/2965]  eta: 0:14:26  lr: 0.005000  loss: 1.2377 (1.3237)  loss_classifier: 0.2079 (0.2903)  loss_box_reg: 0.3379 (0.3732)  loss_mask: 0.2708 (0.3226)  loss_objectness: 0.0591 (0.0852)  loss_rpn_box_reg: 0.2447 (0.2523)  time: 0.5011  data: 0.3227  max mem: 0
# Epoch: [0]  [1110/2965]  eta: 0:14:21  lr: 0.005000  loss: 1.5021 (1.3253)  loss_classifier: 0.2311 (0.2906)  loss_box_reg: 0.4164 (0.3739)  loss_mask: 0.3232 (0.3228)  loss_objectness: 0.0729 (0.0851)  loss_rpn_box_reg: 0.2722 (0.2528)  time: 0.4924  data: 0.3117  max mem: 0
# Epoch: [0]  [1120/2965]  eta: 0:14:17  lr: 0.005000  loss: 1.5132 (1.3246)  loss_classifier: 0.2311 (0.2902)  loss_box_reg: 0.4125 (0.3737)  loss_mask: 0.3117 (0.3223)  loss_objectness: 0.0661 (0.0850)  loss_rpn_box_reg: 0.3500 (0.2534)  time: 0.4713  data: 0.2905  max mem: 0
# Epoch: [0]  [1130/2965]  eta: 0:14:12  lr: 0.005000  loss: 1.2388 (1.3233)  loss_classifier: 0.2644 (0.2900)  loss_box_reg: 0.3867 (0.3736)  loss_mask: 0.2964 (0.3221)  loss_objectness: 0.0555 (0.0848)  loss_rpn_box_reg: 0.1495 (0.2527)  time: 0.4714  data: 0.2904  max mem: 0
# Epoch: [0]  [1140/2965]  eta: 0:14:08  lr: 0.005000  loss: 1.2679 (1.3259)  loss_classifier: 0.2960 (0.2904)  loss_box_reg: 0.3924 (0.3742)  loss_mask: 0.3031 (0.3222)  loss_objectness: 0.0554 (0.0847)  loss_rpn_box_reg: 0.2510 (0.2544)  time: 0.4925  data: 0.3084  max mem: 0
# Epoch: [0]  [1150/2965]  eta: 0:14:04  lr: 0.005000  loss: 1.5739 (1.3275)  loss_classifier: 0.3059 (0.2905)  loss_box_reg: 0.4131 (0.3746)  loss_mask: 0.2984 (0.3219)  loss_objectness: 0.0806 (0.0853)  loss_rpn_box_reg: 0.3679 (0.2552)  time: 0.5180  data: 0.3332  max mem: 0
# Epoch: [0]  [1160/2965]  eta: 0:14:00  lr: 0.005000  loss: 1.3451 (1.3283)  loss_classifier: 0.2640 (0.2902)  loss_box_reg: 0.3931 (0.3748)  loss_mask: 0.3168 (0.3221)  loss_objectness: 0.0911 (0.0853)  loss_rpn_box_reg: 0.2983 (0.2559)  time: 0.4995  data: 0.3193  max mem: 0
# Epoch: [0]  [1170/2965]  eta: 0:13:54  lr: 0.005000  loss: 1.1332 (1.3261)  loss_classifier: 0.2301 (0.2894)  loss_box_reg: 0.3771 (0.3743)  loss_mask: 0.3243 (0.3220)  loss_objectness: 0.0490 (0.0850)  loss_rpn_box_reg: 0.2058 (0.2554)  time: 0.4364  data: 0.2623  max mem: 0
# Epoch: [0]  [1180/2965]  eta: 0:13:49  lr: 0.005000  loss: 1.1332 (1.3258)  loss_classifier: 0.2314 (0.2892)  loss_box_reg: 0.3901 (0.3747)  loss_mask: 0.3169 (0.3221)  loss_objectness: 0.0484 (0.0848)  loss_rpn_box_reg: 0.0894 (0.2550)  time: 0.4227  data: 0.2484  max mem: 0
# Epoch: [0]  [1190/2965]  eta: 0:13:45  lr: 0.005000  loss: 1.4195 (1.3283)  loss_classifier: 0.2649 (0.2889)  loss_box_reg: 0.4440 (0.3748)  loss_mask: 0.3330 (0.3222)  loss_objectness: 0.0738 (0.0858)  loss_rpn_box_reg: 0.2939 (0.2565)  time: 0.4572  data: 0.2803  max mem: 0
# Epoch: [0]  [1200/2965]  eta: 0:13:40  lr: 0.005000  loss: 1.4183 (1.3295)  loss_classifier: 0.2245 (0.2887)  loss_box_reg: 0.4399 (0.3753)  loss_mask: 0.3277 (0.3221)  loss_objectness: 0.0893 (0.0859)  loss_rpn_box_reg: 0.3245 (0.2575)  time: 0.4705  data: 0.2923  max mem: 0
# Epoch: [0]  [1210/2965]  eta: 0:13:36  lr: 0.005000  loss: 1.3525 (1.3289)  loss_classifier: 0.2245 (0.2884)  loss_box_reg: 0.3936 (0.3755)  loss_mask: 0.2964 (0.3219)  loss_objectness: 0.0873 (0.0858)  loss_rpn_box_reg: 0.3054 (0.2573)  time: 0.4685  data: 0.2910  max mem: 0
# Epoch: [0]  [1220/2965]  eta: 0:13:32  lr: 0.005000  loss: 1.2741 (1.3296)  loss_classifier: 0.2629 (0.2884)  loss_box_reg: 0.4254 (0.3759)  loss_mask: 0.2985 (0.3218)  loss_objectness: 0.0707 (0.0857)  loss_rpn_box_reg: 0.2695 (0.2578)  time: 0.4861  data: 0.3056  max mem: 0
# Epoch: [0]  [1230/2965]  eta: 0:13:26  lr: 0.005000  loss: 1.4262 (1.3303)  loss_classifier: 0.2892 (0.2884)  loss_box_reg: 0.4049 (0.3760)  loss_mask: 0.3607 (0.3222)  loss_objectness: 0.0561 (0.0857)  loss_rpn_box_reg: 0.2733 (0.2580)  time: 0.4714  data: 0.2917  max mem: 0
# Epoch: [0]  [1240/2965]  eta: 0:13:21  lr: 0.005000  loss: 1.5202 (1.3324)  loss_classifier: 0.2958 (0.2885)  loss_box_reg: 0.3965 (0.3761)  loss_mask: 0.3624 (0.3228)  loss_objectness: 0.0801 (0.0864)  loss_rpn_box_reg: 0.2733 (0.2586)  time: 0.4337  data: 0.2582  max mem: 0
# Epoch: [0]  [1250/2965]  eta: 0:13:17  lr: 0.005000  loss: 1.4680 (1.3316)  loss_classifier: 0.2982 (0.2884)  loss_box_reg: 0.3725 (0.3761)  loss_mask: 0.3188 (0.3226)  loss_objectness: 0.0821 (0.0863)  loss_rpn_box_reg: 0.1382 (0.2582)  time: 0.4518  data: 0.2756  max mem: 0
# Epoch: [0]  [1260/2965]  eta: 0:13:12  lr: 0.005000  loss: 1.2088 (1.3319)  loss_classifier: 0.2591 (0.2883)  loss_box_reg: 0.3783 (0.3764)  loss_mask: 0.2890 (0.3225)  loss_objectness: 0.0640 (0.0862)  loss_rpn_box_reg: 0.0421 (0.2584)  time: 0.4451  data: 0.2703  max mem: 0
# Epoch: [0]  [1270/2965]  eta: 0:13:07  lr: 0.005000  loss: 1.1599 (1.3310)  loss_classifier: 0.2965 (0.2882)  loss_box_reg: 0.4077 (0.3763)  loss_mask: 0.3473 (0.3225)  loss_objectness: 0.0488 (0.0860)  loss_rpn_box_reg: 0.0477 (0.2580)  time: 0.4314  data: 0.2579  max mem: 0
# Epoch: [0]  [1280/2965]  eta: 0:13:02  lr: 0.005000  loss: 1.3187 (1.3308)  loss_classifier: 0.2687 (0.2883)  loss_box_reg: 0.3865 (0.3764)  loss_mask: 0.3318 (0.3225)  loss_objectness: 0.0509 (0.0858)  loss_rpn_box_reg: 0.1720 (0.2578)  time: 0.4514  data: 0.2750  max mem: 0
# Epoch: [0]  [1290/2965]  eta: 0:12:56  lr: 0.005000  loss: 1.3324 (1.3309)  loss_classifier: 0.2596 (0.2882)  loss_box_reg: 0.3262 (0.3762)  loss_mask: 0.3159 (0.3227)  loss_objectness: 0.0592 (0.0865)  loss_rpn_box_reg: 0.1826 (0.2574)  time: 0.4272  data: 0.2504  max mem: 0
# Epoch: [0]  [1300/2965]  eta: 0:12:52  lr: 0.005000  loss: 1.3881 (1.3312)  loss_classifier: 0.2596 (0.2882)  loss_box_reg: 0.3897 (0.3765)  loss_mask: 0.3368 (0.3227)  loss_objectness: 0.0659 (0.0866)  loss_rpn_box_reg: 0.2110 (0.2573)  time: 0.4422  data: 0.2660  max mem: 0
# Epoch: [0]  [1310/2965]  eta: 0:12:48  lr: 0.005000  loss: 1.3274 (1.3313)  loss_classifier: 0.2394 (0.2880)  loss_box_reg: 0.4376 (0.3770)  loss_mask: 0.3403 (0.3229)  loss_objectness: 0.0714 (0.0866)  loss_rpn_box_reg: 0.2110 (0.2568)  time: 0.4866  data: 0.3055  max mem: 0
# Epoch: [0]  [1320/2965]  eta: 0:12:43  lr: 0.005000  loss: 1.2596 (1.3311)  loss_classifier: 0.2394 (0.2878)  loss_box_reg: 0.4126 (0.3771)  loss_mask: 0.2983 (0.3226)  loss_objectness: 0.0648 (0.0870)  loss_rpn_box_reg: 0.1468 (0.2567)  time: 0.4656  data: 0.2858  max mem: 0
# Epoch: [0]  [1330/2965]  eta: 0:12:38  lr: 0.005000  loss: 1.3624 (1.3314)  loss_classifier: 0.2482 (0.2875)  loss_box_reg: 0.3608 (0.3770)  loss_mask: 0.2877 (0.3225)  loss_objectness: 0.0648 (0.0869)  loss_rpn_box_reg: 0.3613 (0.2575)  time: 0.4543  data: 0.2773  max mem: 0
# Epoch: [0]  [1340/2965]  eta: 0:12:34  lr: 0.005000  loss: 1.1645 (1.3296)  loss_classifier: 0.2482 (0.2874)  loss_box_reg: 0.3513 (0.3767)  loss_mask: 0.2694 (0.3221)  loss_objectness: 0.0705 (0.0868)  loss_rpn_box_reg: 0.2037 (0.2567)  time: 0.4650  data: 0.2879  max mem: 0
# Epoch: [0]  [1350/2965]  eta: 0:12:29  lr: 0.005000  loss: 1.2351 (1.3303)  loss_classifier: 0.2628 (0.2875)  loss_box_reg: 0.3705 (0.3768)  loss_mask: 0.2694 (0.3220)  loss_objectness: 0.0682 (0.0866)  loss_rpn_box_reg: 0.2037 (0.2573)  time: 0.4837  data: 0.3067  max mem: 0
# Epoch: [0]  [1360/2965]  eta: 0:12:24  lr: 0.005000  loss: 1.3396 (1.3299)  loss_classifier: 0.2529 (0.2873)  loss_box_reg: 0.3792 (0.3767)  loss_mask: 0.2916 (0.3219)  loss_objectness: 0.0543 (0.0864)  loss_rpn_box_reg: 0.3593 (0.2576)  time: 0.4680  data: 0.2915  max mem: 0
# Epoch: [0]  [1370/2965]  eta: 0:12:20  lr: 0.005000  loss: 1.3159 (1.3307)  loss_classifier: 0.2529 (0.2875)  loss_box_reg: 0.3792 (0.3771)  loss_mask: 0.3061 (0.3219)  loss_objectness: 0.0523 (0.0864)  loss_rpn_box_reg: 0.2878 (0.2578)  time: 0.4619  data: 0.2830  max mem: 0
# Epoch: [0]  [1380/2965]  eta: 0:12:15  lr: 0.005000  loss: 1.2132 (1.3292)  loss_classifier: 0.2548 (0.2871)  loss_box_reg: 0.3594 (0.3770)  loss_mask: 0.3061 (0.3218)  loss_objectness: 0.0456 (0.0862)  loss_rpn_box_reg: 0.2305 (0.2572)  time: 0.4574  data: 0.2792  max mem: 0
# Epoch: [0]  [1390/2965]  eta: 0:12:10  lr: 0.005000  loss: 1.1690 (1.3295)  loss_classifier: 0.2149 (0.2872)  loss_box_reg: 0.3640 (0.3770)  loss_mask: 0.2908 (0.3217)  loss_objectness: 0.0371 (0.0860)  loss_rpn_box_reg: 0.2495 (0.2576)  time: 0.4365  data: 0.2608  max mem: 0
# Epoch: [0]  [1400/2965]  eta: 0:12:05  lr: 0.005000  loss: 1.3157 (1.3291)  loss_classifier: 0.3201 (0.2873)  loss_box_reg: 0.3717 (0.3768)  loss_mask: 0.2937 (0.3216)  loss_objectness: 0.0580 (0.0858)  loss_rpn_box_reg: 0.3392 (0.2575)  time: 0.4284  data: 0.2523  max mem: 0
# Epoch: [0]  [1410/2965]  eta: 0:12:00  lr: 0.005000  loss: 1.2939 (1.3293)  loss_classifier: 0.2791 (0.2873)  loss_box_reg: 0.3852 (0.3769)  loss_mask: 0.3034 (0.3215)  loss_objectness: 0.0492 (0.0857)  loss_rpn_box_reg: 0.2491 (0.2579)  time: 0.4168  data: 0.2413  max mem: 0
# Epoch: [0]  [1420/2965]  eta: 0:11:55  lr: 0.005000  loss: 1.2939 (1.3287)  loss_classifier: 0.2687 (0.2873)  loss_box_reg: 0.3921 (0.3768)  loss_mask: 0.3034 (0.3214)  loss_objectness: 0.0426 (0.0855)  loss_rpn_box_reg: 0.2491 (0.2578)  time: 0.4335  data: 0.2569  max mem: 0
# Epoch: [0]  [1430/2965]  eta: 0:11:50  lr: 0.005000  loss: 1.2758 (1.3275)  loss_classifier: 0.2329 (0.2869)  loss_box_reg: 0.3616 (0.3767)  loss_mask: 0.2790 (0.3212)  loss_objectness: 0.0367 (0.0852)  loss_rpn_box_reg: 0.2373 (0.2576)  time: 0.4536  data: 0.2731  max mem: 0
# Epoch: [0]  [1440/2965]  eta: 0:11:46  lr: 0.005000  loss: 1.1993 (1.3284)  loss_classifier: 0.2384 (0.2874)  loss_box_reg: 0.3926 (0.3772)  loss_mask: 0.3057 (0.3214)  loss_objectness: 0.0446 (0.0851)  loss_rpn_box_reg: 0.1503 (0.2574)  time: 0.4649  data: 0.2827  max mem: 0
# Epoch: [0]  [1450/2965]  eta: 0:11:41  lr: 0.005000  loss: 1.3092 (1.3289)  loss_classifier: 0.2766 (0.2875)  loss_box_reg: 0.4276 (0.3773)  loss_mask: 0.3477 (0.3216)  loss_objectness: 0.0593 (0.0851)  loss_rpn_box_reg: 0.1503 (0.2574)  time: 0.4697  data: 0.2886  max mem: 0
# Epoch: [0]  [1460/2965]  eta: 0:11:36  lr: 0.005000  loss: 1.3808 (1.3290)  loss_classifier: 0.2713 (0.2876)  loss_box_reg: 0.4100 (0.3776)  loss_mask: 0.3265 (0.3217)  loss_objectness: 0.0617 (0.0850)  loss_rpn_box_reg: 0.2032 (0.2571)  time: 0.4651  data: 0.2852  max mem: 0
# Epoch: [0]  [1470/2965]  eta: 0:11:32  lr: 0.005000  loss: 1.1847 (1.3270)  loss_classifier: 0.2678 (0.2871)  loss_box_reg: 0.4100 (0.3775)  loss_mask: 0.2910 (0.3215)  loss_objectness: 0.0524 (0.0847)  loss_rpn_box_reg: 0.1292 (0.2561)  time: 0.4629  data: 0.2859  max mem: 0
# Epoch: [0]  [1480/2965]  eta: 0:11:28  lr: 0.005000  loss: 1.2345 (1.3273)  loss_classifier: 0.2678 (0.2873)  loss_box_reg: 0.4153 (0.3776)  loss_mask: 0.2931 (0.3216)  loss_objectness: 0.0524 (0.0846)  loss_rpn_box_reg: 0.1518 (0.2563)  time: 0.4931  data: 0.3141  max mem: 0
# Epoch: [0]  [1490/2965]  eta: 0:11:23  lr: 0.005000  loss: 1.2514 (1.3265)  loss_classifier: 0.2667 (0.2870)  loss_box_reg: 0.3764 (0.3773)  loss_mask: 0.2947 (0.3214)  loss_objectness: 0.0606 (0.0845)  loss_rpn_box_reg: 0.2338 (0.2563)  time: 0.4876  data: 0.3073  max mem: 0
# Epoch: [0]  [1500/2965]  eta: 0:11:19  lr: 0.005000  loss: 1.2557 (1.3263)  loss_classifier: 0.2183 (0.2868)  loss_box_reg: 0.3603 (0.3773)  loss_mask: 0.2882 (0.3212)  loss_objectness: 0.0602 (0.0843)  loss_rpn_box_reg: 0.2480 (0.2568)  time: 0.4780  data: 0.2985  max mem: 0
# Epoch: [0]  [1510/2965]  eta: 0:11:14  lr: 0.005000  loss: 1.3004 (1.3258)  loss_classifier: 0.2033 (0.2864)  loss_box_reg: 0.3603 (0.3769)  loss_mask: 0.2610 (0.3207)  loss_objectness: 0.0602 (0.0843)  loss_rpn_box_reg: 0.3460 (0.2575)  time: 0.4828  data: 0.3022  max mem: 0
# Epoch: [0]  [1520/2965]  eta: 0:11:09  lr: 0.005000  loss: 1.3525 (1.3259)  loss_classifier: 0.2375 (0.2865)  loss_box_reg: 0.3780 (0.3770)  loss_mask: 0.2723 (0.3207)  loss_objectness: 0.0540 (0.0841)  loss_rpn_box_reg: 0.3026 (0.2576)  time: 0.4232  data: 0.2456  max mem: 0
# Epoch: [0]  [1530/2965]  eta: 0:11:04  lr: 0.005000  loss: 1.3328 (1.3257)  loss_classifier: 0.2984 (0.2866)  loss_box_reg: 0.3895 (0.3771)  loss_mask: 0.3182 (0.3208)  loss_objectness: 0.0646 (0.0841)  loss_rpn_box_reg: 0.2063 (0.2571)  time: 0.4250  data: 0.2451  max mem: 0
# Epoch: [0]  [1540/2965]  eta: 0:11:00  lr: 0.005000  loss: 1.2164 (1.3259)  loss_classifier: 0.2921 (0.2865)  loss_box_reg: 0.3895 (0.3770)  loss_mask: 0.3159 (0.3207)  loss_objectness: 0.1024 (0.0850)  loss_rpn_box_reg: 0.1872 (0.2567)  time: 0.4698  data: 0.2872  max mem: 0
# Epoch: [0]  [1550/2965]  eta: 0:10:55  lr: 0.005000  loss: 1.2164 (1.3258)  loss_classifier: 0.2537 (0.2864)  loss_box_reg: 0.4022 (0.3772)  loss_mask: 0.3104 (0.3208)  loss_objectness: 0.0932 (0.0849)  loss_rpn_box_reg: 0.2110 (0.2565)  time: 0.4635  data: 0.2795  max mem: 0
# Epoch: [0]  [1560/2965]  eta: 0:10:50  lr: 0.005000  loss: 1.1415 (1.3254)  loss_classifier: 0.2501 (0.2861)  loss_box_reg: 0.3633 (0.3772)  loss_mask: 0.2637 (0.3206)  loss_objectness: 0.0643 (0.0850)  loss_rpn_box_reg: 0.2398 (0.2565)  time: 0.4395  data: 0.2573  max mem: 0
# Epoch: [0]  [1570/2965]  eta: 0:10:45  lr: 0.005000  loss: 1.2103 (1.3253)  loss_classifier: 0.2563 (0.2862)  loss_box_reg: 0.3649 (0.3775)  loss_mask: 0.3055 (0.3206)  loss_objectness: 0.0744 (0.0849)  loss_rpn_box_reg: 0.2154 (0.2562)  time: 0.4303  data: 0.2510  max mem: 0
# Epoch: [0]  [1580/2965]  eta: 0:10:40  lr: 0.005000  loss: 1.1898 (1.3240)  loss_classifier: 0.2312 (0.2859)  loss_box_reg: 0.4046 (0.3774)  loss_mask: 0.3055 (0.3204)  loss_objectness: 0.0653 (0.0848)  loss_rpn_box_reg: 0.1266 (0.2554)  time: 0.4214  data: 0.2446  max mem: 0
# Epoch: [0]  [1590/2965]  eta: 0:10:36  lr: 0.005000  loss: 1.1792 (1.3234)  loss_classifier: 0.2254 (0.2858)  loss_box_reg: 0.3965 (0.3776)  loss_mask: 0.3031 (0.3203)  loss_objectness: 0.0630 (0.0847)  loss_rpn_box_reg: 0.1283 (0.2551)  time: 0.4504  data: 0.2720  max mem: 0
# Epoch: [0]  [1600/2965]  eta: 0:10:31  lr: 0.005000  loss: 1.1942 (1.3209)  loss_classifier: 0.2071 (0.2851)  loss_box_reg: 0.3708 (0.3770)  loss_mask: 0.3030 (0.3199)  loss_objectness: 0.0403 (0.0844)  loss_rpn_box_reg: 0.1641 (0.2545)  time: 0.4533  data: 0.2751  max mem: 0
# Epoch: [0]  [1610/2965]  eta: 0:10:26  lr: 0.005000  loss: 1.0519 (1.3196)  loss_classifier: 0.1715 (0.2847)  loss_box_reg: 0.3109 (0.3765)  loss_mask: 0.2625 (0.3196)  loss_objectness: 0.0296 (0.0841)  loss_rpn_box_reg: 0.1914 (0.2547)  time: 0.4455  data: 0.2714  max mem: 0
# Epoch: [0]  [1620/2965]  eta: 0:10:22  lr: 0.005000  loss: 1.3668 (1.3202)  loss_classifier: 0.2320 (0.2848)  loss_box_reg: 0.3496 (0.3769)  loss_mask: 0.3115 (0.3198)  loss_objectness: 0.0499 (0.0843)  loss_rpn_box_reg: 0.2479 (0.2543)  time: 0.4756  data: 0.2970  max mem: 0
# Epoch: [0]  [1630/2965]  eta: 0:10:17  lr: 0.005000  loss: 1.3668 (1.3191)  loss_classifier: 0.2320 (0.2847)  loss_box_reg: 0.3655 (0.3768)  loss_mask: 0.3320 (0.3197)  loss_objectness: 0.0466 (0.0842)  loss_rpn_box_reg: 0.1074 (0.2537)  time: 0.4473  data: 0.2663  max mem: 0
# Epoch: [0]  [1640/2965]  eta: 0:10:11  lr: 0.005000  loss: 0.9410 (1.3171)  loss_classifier: 0.2224 (0.2845)  loss_box_reg: 0.3510 (0.3765)  loss_mask: 0.2704 (0.3195)  loss_objectness: 0.0452 (0.0840)  loss_rpn_box_reg: 0.0693 (0.2527)  time: 0.4104  data: 0.2330  max mem: 0
# Epoch: [0]  [1650/2965]  eta: 0:10:07  lr: 0.005000  loss: 1.0705 (1.3163)  loss_classifier: 0.2261 (0.2844)  loss_box_reg: 0.3645 (0.3764)  loss_mask: 0.3015 (0.3195)  loss_objectness: 0.0377 (0.0838)  loss_rpn_box_reg: 0.0617 (0.2522)  time: 0.4508  data: 0.2756  max mem: 0
# Epoch: [0]  [1660/2965]  eta: 0:10:02  lr: 0.005000  loss: 1.1757 (1.3154)  loss_classifier: 0.2261 (0.2840)  loss_box_reg: 0.3564 (0.3761)  loss_mask: 0.3015 (0.3193)  loss_objectness: 0.0439 (0.0838)  loss_rpn_box_reg: 0.1611 (0.2522)  time: 0.4520  data: 0.2770  max mem: 0
# Epoch: [0]  [1670/2965]  eta: 0:09:57  lr: 0.005000  loss: 1.2118 (1.3154)  loss_classifier: 0.2313 (0.2839)  loss_box_reg: 0.3564 (0.3763)  loss_mask: 0.2850 (0.3195)  loss_objectness: 0.0476 (0.0836)  loss_rpn_box_reg: 0.2366 (0.2521)  time: 0.4355  data: 0.2598  max mem: 0
# Epoch: [0]  [1680/2965]  eta: 0:09:53  lr: 0.005000  loss: 1.2778 (1.3155)  loss_classifier: 0.2788 (0.2840)  loss_box_reg: 0.4158 (0.3765)  loss_mask: 0.3129 (0.3194)  loss_objectness: 0.0529 (0.0835)  loss_rpn_box_reg: 0.2366 (0.2520)  time: 0.4700  data: 0.2917  max mem: 0
# Epoch: [0]  [1690/2965]  eta: 0:09:48  lr: 0.005000  loss: 1.2206 (1.3156)  loss_classifier: 0.2788 (0.2841)  loss_box_reg: 0.3841 (0.3765)  loss_mask: 0.2991 (0.3194)  loss_objectness: 0.0612 (0.0835)  loss_rpn_box_reg: 0.2455 (0.2522)  time: 0.4638  data: 0.2823  max mem: 0
# Epoch: [0]  [1700/2965]  eta: 0:09:43  lr: 0.005000  loss: 1.2429 (1.3153)  loss_classifier: 0.2594 (0.2842)  loss_box_reg: 0.3515 (0.3766)  loss_mask: 0.2784 (0.3194)  loss_objectness: 0.0621 (0.0833)  loss_rpn_box_reg: 0.2540 (0.2519)  time: 0.4477  data: 0.2673  max mem: 0
# ...
# Epoch: [9]  [2520/2965]  eta: 0:02:50  lr: 0.000005  loss: 0.7253 (0.7919)  loss_classifier: 0.1339 (0.1461)  loss_box_reg: 0.2328 (0.2296)  loss_mask: 0.2373 (0.2439)  loss_objectness: 0.0116 (0.0246)  loss_rpn_box_reg: 0.0951 (0.1477)  time: 0.3752  data: 0.1993  max mem: 0
# Epoch: [9]  [2530/2965]  eta: 0:02:46  lr: 0.000005  loss: 0.7253 (0.7919)  loss_classifier: 0.1339 (0.1461)  loss_box_reg: 0.2328 (0.2296)  loss_mask: 0.2278 (0.2438)  loss_objectness: 0.0119 (0.0246)  loss_rpn_box_reg: 0.1595 (0.1477)  time: 0.3972  data: 0.2170  max mem: 0
# Epoch: [9]  [2540/2965]  eta: 0:02:42  lr: 0.000005  loss: 0.7372 (0.7920)  loss_classifier: 0.1481 (0.1462)  loss_box_reg: 0.2417 (0.2295)  loss_mask: 0.2300 (0.2437)  loss_objectness: 0.0222 (0.0246)  loss_rpn_box_reg: 0.1482 (0.1480)  time: 0.4011  data: 0.2218  max mem: 0
# Epoch: [9]  [2550/2965]  eta: 0:02:38  lr: 0.000005  loss: 0.6897 (0.7917)  loss_classifier: 0.1204 (0.1461)  loss_box_reg: 0.2319 (0.2295)  loss_mask: 0.2300 (0.2437)  loss_objectness: 0.0213 (0.0246)  loss_rpn_box_reg: 0.0980 (0.1478)  time: 0.3784  data: 0.2033  max mem: 0
# Epoch: [9]  [2560/2965]  eta: 0:02:34  lr: 0.000005  loss: 0.6043 (0.7910)  loss_classifier: 0.1150 (0.1460)  loss_box_reg: 0.2163 (0.2294)  loss_mask: 0.2188 (0.2436)  loss_objectness: 0.0132 (0.0246)  loss_rpn_box_reg: 0.0337 (0.1475)  time: 0.3525  data: 0.1786  max mem: 0
# Epoch: [9]  [2570/2965]  eta: 0:02:31  lr: 0.000005  loss: 0.7009 (0.7911)  loss_classifier: 0.1262 (0.1460)  loss_box_reg: 0.2135 (0.2294)  loss_mask: 0.2240 (0.2437)  loss_objectness: 0.0157 (0.0246)  loss_rpn_box_reg: 0.0644 (0.1474)  time: 0.3618  data: 0.1864  max mem: 0
# Epoch: [9]  [2580/2965]  eta: 0:02:27  lr: 0.000005  loss: 0.7124 (0.7910)  loss_classifier: 0.1564 (0.1461)  loss_box_reg: 0.2184 (0.2295)  loss_mask: 0.2518 (0.2438)  loss_objectness: 0.0175 (0.0246)  loss_rpn_box_reg: 0.0643 (0.1471)  time: 0.3860  data: 0.2088  max mem: 0
# Epoch: [9]  [2590/2965]  eta: 0:02:23  lr: 0.000005  loss: 0.7037 (0.7909)  loss_classifier: 0.1466 (0.1461)  loss_box_reg: 0.2343 (0.2295)  loss_mask: 0.2603 (0.2438)  loss_objectness: 0.0151 (0.0246)  loss_rpn_box_reg: 0.0488 (0.1469)  time: 0.3951  data: 0.2179  max mem: 0
# Epoch: [9]  [2600/2965]  eta: 0:02:19  lr: 0.000005  loss: 0.7987 (0.7915)  loss_classifier: 0.1670 (0.1463)  loss_box_reg: 0.2614 (0.2298)  loss_mask: 0.2746 (0.2440)  loss_objectness: 0.0187 (0.0246)  loss_rpn_box_reg: 0.1181 (0.1469)  time: 0.4185  data: 0.2379  max mem: 0
# Epoch: [9]  [2610/2965]  eta: 0:02:15  lr: 0.000005  loss: 0.8685 (0.7913)  loss_classifier: 0.1587 (0.1462)  loss_box_reg: 0.2547 (0.2298)  loss_mask: 0.2836 (0.2440)  loss_objectness: 0.0174 (0.0246)  loss_rpn_box_reg: 0.1216 (0.1468)  time: 0.3978  data: 0.2179  max mem: 0
# Epoch: [9]  [2620/2965]  eta: 0:02:12  lr: 0.000005  loss: 0.7106 (0.7910)  loss_classifier: 0.1184 (0.1461)  loss_box_reg: 0.2029 (0.2296)  loss_mask: 0.2185 (0.2439)  loss_objectness: 0.0173 (0.0246)  loss_rpn_box_reg: 0.0820 (0.1468)  time: 0.3662  data: 0.1908  max mem: 0
# Epoch: [9]  [2630/2965]  eta: 0:02:08  lr: 0.000005  loss: 0.7106 (0.7904)  loss_classifier: 0.1089 (0.1460)  loss_box_reg: 0.1880 (0.2294)  loss_mask: 0.2033 (0.2437)  loss_objectness: 0.0173 (0.0246)  loss_rpn_box_reg: 0.0988 (0.1467)  time: 0.3531  data: 0.1802  max mem: 0
# Epoch: [9]  [2640/2965]  eta: 0:02:04  lr: 0.000005  loss: 0.6569 (0.7904)  loss_classifier: 0.1325 (0.1461)  loss_box_reg: 0.2095 (0.2294)  loss_mask: 0.2126 (0.2437)  loss_objectness: 0.0141 (0.0246)  loss_rpn_box_reg: 0.0676 (0.1467)  time: 0.3548  data: 0.1827  max mem: 0
# Epoch: [9]  [2650/2965]  eta: 0:02:00  lr: 0.000005  loss: 0.7799 (0.7904)  loss_classifier: 0.1328 (0.1460)  loss_box_reg: 0.2217 (0.2294)  loss_mask: 0.2436 (0.2438)  loss_objectness: 0.0197 (0.0246)  loss_rpn_box_reg: 0.1089 (0.1467)  time: 0.3651  data: 0.1925  max mem: 0
# Epoch: [9]  [2660/2965]  eta: 0:01:56  lr: 0.000005  loss: 0.7171 (0.7903)  loss_classifier: 0.1328 (0.1460)  loss_box_reg: 0.2013 (0.2293)  loss_mask: 0.2472 (0.2438)  loss_objectness: 0.0171 (0.0246)  loss_rpn_box_reg: 0.1261 (0.1467)  time: 0.3608  data: 0.1895  max mem: 0
# Epoch: [9]  [2670/2965]  eta: 0:01:52  lr: 0.000005  loss: 0.8085 (0.7910)  loss_classifier: 0.1735 (0.1462)  loss_box_reg: 0.2368 (0.2295)  loss_mask: 0.2632 (0.2440)  loss_objectness: 0.0170 (0.0246)  loss_rpn_box_reg: 0.1300 (0.1467)  time: 0.3910  data: 0.2150  max mem: 0
# Epoch: [9]  [2680/2965]  eta: 0:01:49  lr: 0.000005  loss: 0.8132 (0.7910)  loss_classifier: 0.1436 (0.1462)  loss_box_reg: 0.2368 (0.2296)  loss_mask: 0.2509 (0.2439)  loss_objectness: 0.0158 (0.0246)  loss_rpn_box_reg: 0.1364 (0.1467)  time: 0.4029  data: 0.2237  max mem: 0
# Epoch: [9]  [2690/2965]  eta: 0:01:45  lr: 0.000005  loss: 0.6453 (0.7905)  loss_classifier: 0.1170 (0.1461)  loss_box_reg: 0.2074 (0.2294)  loss_mask: 0.2194 (0.2439)  loss_objectness: 0.0147 (0.0246)  loss_rpn_box_reg: 0.0522 (0.1466)  time: 0.3644  data: 0.1892  max mem: 0
# Epoch: [9]  [2700/2965]  eta: 0:01:41  lr: 0.000005  loss: 0.6941 (0.7905)  loss_classifier: 0.1344 (0.1462)  loss_box_reg: 0.1964 (0.2294)  loss_mask: 0.2186 (0.2437)  loss_objectness: 0.0159 (0.0246)  loss_rpn_box_reg: 0.0574 (0.1466)  time: 0.3683  data: 0.1938  max mem: 0
# Epoch: [9]  [2710/2965]  eta: 0:01:37  lr: 0.000005  loss: 0.7438 (0.7903)  loss_classifier: 0.1453 (0.1461)  loss_box_reg: 0.2185 (0.2294)  loss_mask: 0.2354 (0.2437)  loss_objectness: 0.0159 (0.0246)  loss_rpn_box_reg: 0.1302 (0.1466)  time: 0.3895  data: 0.2139  max mem: 0
# Epoch: [9]  [2720/2965]  eta: 0:01:33  lr: 0.000005  loss: 0.7438 (0.7906)  loss_classifier: 0.1404 (0.1461)  loss_box_reg: 0.2371 (0.2296)  loss_mask: 0.2354 (0.2438)  loss_objectness: 0.0131 (0.0245)  loss_rpn_box_reg: 0.1056 (0.1466)  time: 0.3923  data: 0.2160  max mem: 0
# Epoch: [9]  [2730/2965]  eta: 0:01:29  lr: 0.000005  loss: 0.8427 (0.7909)  loss_classifier: 0.1477 (0.1462)  loss_box_reg: 0.2559 (0.2296)  loss_mask: 0.2607 (0.2439)  loss_objectness: 0.0216 (0.0246)  loss_rpn_box_reg: 0.0818 (0.1466)  time: 0.4103  data: 0.2311  max mem: 0
# Epoch: [9]  [2740/2965]  eta: 0:01:26  lr: 0.000005  loss: 0.8427 (0.7911)  loss_classifier: 0.1356 (0.1463)  loss_box_reg: 0.2559 (0.2297)  loss_mask: 0.2731 (0.2440)  loss_objectness: 0.0260 (0.0246)  loss_rpn_box_reg: 0.0776 (0.1466)  time: 0.4158  data: 0.2339  max mem: 0
# Epoch: [9]  [2750/2965]  eta: 0:01:22  lr: 0.000005  loss: 1.0375 (0.7916)  loss_classifier: 0.1672 (0.1463)  loss_box_reg: 0.2517 (0.2297)  loss_mask: 0.2928 (0.2441)  loss_objectness: 0.0283 (0.0245)  loss_rpn_box_reg: 0.1695 (0.1470)  time: 0.4019  data: 0.2219  max mem: 0
# Epoch: [9]  [2760/2965]  eta: 0:01:18  lr: 0.000005  loss: 1.0375 (0.7922)  loss_classifier: 0.1672 (0.1464)  loss_box_reg: 0.2427 (0.2299)  loss_mask: 0.2618 (0.2441)  loss_objectness: 0.0282 (0.0246)  loss_rpn_box_reg: 0.2016 (0.1472)  time: 0.3841  data: 0.2073  max mem: 0
# Epoch: [9]  [2770/2965]  eta: 0:01:14  lr: 0.000005  loss: 0.9227 (0.7927)  loss_classifier: 0.1610 (0.1465)  loss_box_reg: 0.2662 (0.2300)  loss_mask: 0.2574 (0.2441)  loss_objectness: 0.0245 (0.0246)  loss_rpn_box_reg: 0.2078 (0.1474)  time: 0.3812  data: 0.2040  max mem: 0
# Epoch: [9]  [2780/2965]  eta: 0:01:10  lr: 0.000005  loss: 0.6510 (0.7919)  loss_classifier: 0.1319 (0.1464)  loss_box_reg: 0.2108 (0.2298)  loss_mask: 0.2433 (0.2440)  loss_objectness: 0.0201 (0.0246)  loss_rpn_box_reg: 0.1309 (0.1472)  time: 0.3650  data: 0.1900  max mem: 0
# Epoch: [9]  [2790/2965]  eta: 0:01:06  lr: 0.000005  loss: 0.6138 (0.7914)  loss_classifier: 0.1157 (0.1463)  loss_box_reg: 0.1778 (0.2297)  loss_mask: 0.2158 (0.2439)  loss_objectness: 0.0190 (0.0246)  loss_rpn_box_reg: 0.0428 (0.1470)  time: 0.3401  data: 0.1675  max mem: 0
# Epoch: [9]  [2800/2965]  eta: 0:01:03  lr: 0.000005  loss: 0.7020 (0.7918)  loss_classifier: 0.1380 (0.1464)  loss_box_reg: 0.2109 (0.2298)  loss_mask: 0.2481 (0.2440)  loss_objectness: 0.0194 (0.0246)  loss_rpn_box_reg: 0.0452 (0.1470)  time: 0.3862  data: 0.2070  max mem: 0
# Epoch: [9]  [2810/2965]  eta: 0:00:59  lr: 0.000005  loss: 0.8320 (0.7921)  loss_classifier: 0.1521 (0.1464)  loss_box_reg: 0.2169 (0.2297)  loss_mask: 0.2737 (0.2440)  loss_objectness: 0.0133 (0.0246)  loss_rpn_box_reg: 0.1026 (0.1473)  time: 0.4040  data: 0.2238  max mem: 0
# Epoch: [9]  [2820/2965]  eta: 0:00:55  lr: 0.000005  loss: 0.8320 (0.7921)  loss_classifier: 0.1399 (0.1465)  loss_box_reg: 0.2082 (0.2297)  loss_mask: 0.2296 (0.2440)  loss_objectness: 0.0233 (0.0247)  loss_rpn_box_reg: 0.1294 (0.1473)  time: 0.3750  data: 0.1995  max mem: 0
# Epoch: [9]  [2830/2965]  eta: 0:00:51  lr: 0.000005  loss: 0.7369 (0.7917)  loss_classifier: 0.1545 (0.1464)  loss_box_reg: 0.2057 (0.2296)  loss_mask: 0.2288 (0.2440)  loss_objectness: 0.0233 (0.0246)  loss_rpn_box_reg: 0.1294 (0.1471)  time: 0.3593  data: 0.1837  max mem: 0
# Epoch: [9]  [2840/2965]  eta: 0:00:47  lr: 0.000005  loss: 0.7323 (0.7915)  loss_classifier: 0.1479 (0.1465)  loss_box_reg: 0.2107 (0.2295)  loss_mask: 0.2193 (0.2440)  loss_objectness: 0.0172 (0.0246)  loss_rpn_box_reg: 0.1147 (0.1469)  time: 0.3415  data: 0.1660  max mem: 0
# Epoch: [9]  [2850/2965]  eta: 0:00:43  lr: 0.000005  loss: 0.6899 (0.7914)  loss_classifier: 0.1396 (0.1464)  loss_box_reg: 0.2191 (0.2295)  loss_mask: 0.2193 (0.2440)  loss_objectness: 0.0208 (0.0246)  loss_rpn_box_reg: 0.1147 (0.1469)  time: 0.3592  data: 0.1821  max mem: 0
# Epoch: [9]  [2860/2965]  eta: 0:00:40  lr: 0.000005  loss: 0.6990 (0.7914)  loss_classifier: 0.1143 (0.1465)  loss_box_reg: 0.1942 (0.2294)  loss_mask: 0.2246 (0.2440)  loss_objectness: 0.0206 (0.0246)  loss_rpn_box_reg: 0.1046 (0.1469)  time: 0.3785  data: 0.1986  max mem: 0
# Epoch: [9]  [2870/2965]  eta: 0:00:36  lr: 0.000005  loss: 0.6990 (0.7912)  loss_classifier: 0.1143 (0.1464)  loss_box_reg: 0.2289 (0.2294)  loss_mask: 0.2568 (0.2441)  loss_objectness: 0.0125 (0.0246)  loss_rpn_box_reg: 0.0740 (0.1468)  time: 0.3700  data: 0.1932  max mem: 0
# Epoch: [9]  [2880/2965]  eta: 0:00:32  lr: 0.000005  loss: 0.7296 (0.7912)  loss_classifier: 0.1353 (0.1464)  loss_box_reg: 0.2322 (0.2294)  loss_mask: 0.2402 (0.2440)  loss_objectness: 0.0170 (0.0246)  loss_rpn_box_reg: 0.1007 (0.1467)  time: 0.3626  data: 0.1888  max mem: 0
# Epoch: [9]  [2890/2965]  eta: 0:00:28  lr: 0.000005  loss: 0.7296 (0.7908)  loss_classifier: 0.1326 (0.1463)  loss_box_reg: 0.1930 (0.2292)  loss_mask: 0.2259 (0.2440)  loss_objectness: 0.0174 (0.0246)  loss_rpn_box_reg: 0.1090 (0.1467)  time: 0.3547  data: 0.1809  max mem: 0
# Epoch: [9]  [2900/2965]  eta: 0:00:24  lr: 0.000005  loss: 0.7215 (0.7905)  loss_classifier: 0.1026 (0.1462)  loss_box_reg: 0.1837 (0.2291)  loss_mask: 0.2281 (0.2439)  loss_objectness: 0.0111 (0.0246)  loss_rpn_box_reg: 0.1020 (0.1467)  time: 0.3518  data: 0.1784  max mem: 0
# Epoch: [9]  [2910/2965]  eta: 0:00:20  lr: 0.000005  loss: 0.6656 (0.7902)  loss_classifier: 0.1082 (0.1462)  loss_box_reg: 0.1942 (0.2290)  loss_mask: 0.2290 (0.2439)  loss_objectness: 0.0140 (0.0246)  loss_rpn_box_reg: 0.0667 (0.1465)  time: 0.3510  data: 0.1780  max mem: 0
# Epoch: [9]  [2920/2965]  eta: 0:00:17  lr: 0.000005  loss: 0.7441 (0.7903)  loss_classifier: 0.1355 (0.1462)  loss_box_reg: 0.2151 (0.2290)  loss_mask: 0.2423 (0.2439)  loss_objectness: 0.0107 (0.0245)  loss_rpn_box_reg: 0.0583 (0.1466)  time: 0.3597  data: 0.1866  max mem: 0
# Epoch: [9]  [2930/2965]  eta: 0:00:13  lr: 0.000005  loss: 0.8229 (0.7904)  loss_classifier: 0.1368 (0.1462)  loss_box_reg: 0.2351 (0.2290)  loss_mask: 0.2369 (0.2439)  loss_objectness: 0.0143 (0.0245)  loss_rpn_box_reg: 0.1892 (0.1468)  time: 0.3889  data: 0.2101  max mem: 0
# Epoch: [9]  [2940/2965]  eta: 0:00:09  lr: 0.000005  loss: 0.8404 (0.7909)  loss_classifier: 0.1398 (0.1463)  loss_box_reg: 0.2537 (0.2291)  loss_mask: 0.2500 (0.2439)  loss_objectness: 0.0322 (0.0246)  loss_rpn_box_reg: 0.1962 (0.1470)  time: 0.4230  data: 0.2375  max mem: 0
# Epoch: [9]  [2950/2965]  eta: 0:00:05  lr: 0.000005  loss: 0.8344 (0.7909)  loss_classifier: 0.1490 (0.1463)  loss_box_reg: 0.2537 (0.2291)  loss_mask: 0.2517 (0.2440)  loss_objectness: 0.0286 (0.0246)  loss_rpn_box_reg: 0.1436 (0.1470)  time: 0.4016  data: 0.2209  max mem: 0
# Epoch: [9]  [2960/2965]  eta: 0:00:01  lr: 0.000005  loss: 0.7816 (0.7909)  loss_classifier: 0.1367 (0.1462)  loss_box_reg: 0.2305 (0.2290)  loss_mask: 0.2539 (0.2440)  loss_objectness: 0.0194 (0.0246)  loss_rpn_box_reg: 0.1421 (0.1470)  time: 0.3638  data: 0.1897  max mem: 0
# Epoch: [9]  [2964/2965]  eta: 0:00:00  lr: 0.000005  loss: 0.7816 (0.7903)  loss_classifier: 0.1459 (0.1461)  loss_box_reg: 0.2262 (0.2289)  loss_mask: 0.2495 (0.2439)  loss_objectness: 0.0165 (0.0246)  loss_rpn_box_reg: 0.1259 (0.1468)  time: 0.3568  data: 0.1837  max mem: 0
# Epoch: [9] Total time: 0:18:52 (0.3820 s / it)
# Test:  [  0/500]  eta: 0:10:15  model_time: 0.3353 (0.3353)  evaluator_time: 0.4794 (0.4794)  time: 1.2312  data: 0.4116  max mem: 0
# Test:  [100/500]  eta: 0:09:22  model_time: 0.2776 (0.3872)  evaluator_time: 0.5096 (0.5309)  time: 1.4586  data: 0.4764  max mem: 0
# Test:  [200/500]  eta: 0:07:00  model_time: 0.4108 (0.3998)  evaluator_time: 0.4299 (0.5161)  time: 1.3586  data: 0.4188  max mem: 0
# Test:  [300/500]  eta: 0:04:37  model_time: 0.3806 (0.4076)  evaluator_time: 0.3855 (0.4990)  time: 1.3496  data: 0.4589  max mem: 0
# Test:  [400/500]  eta: 0:02:18  model_time: 0.3739 (0.4115)  evaluator_time: 0.3837 (0.4914)  time: 1.3951  data: 0.4691  max mem: 0
# Test:  [499/500]  eta: 0:00:01  model_time: 0.1728 (0.3894)  evaluator_time: 0.1293 (0.4554)  time: 0.5981  data: 0.2151  max mem: 0
# Test: Total time: 0:10:49 (1.2995 s / it)
# Averaged stats: model_time: 0.1728 (0.3894)  evaluator_time: 0.1293 (0.4554)
# Accumulating evaluation results...
# DONE (t=0.69s).
# Accumulating evaluation results...
# DONE (t=0.68s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.348
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.562
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.456
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.707
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.506
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.265
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.226
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.620

# %%
results = open("output_city_finetune.txt", "r")
print(results.read())

# %%
### Inference
