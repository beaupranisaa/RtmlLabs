# %% [markdown]
# ## Lab08

# %% [markdown]
# This lab focuses on a generative model specifically the Cycle-GANs. Cycle-GAN learn transformation between images of different styles.
# This lab consists of two parts. One being to transform horse2zebra and one being to transform ait student images to celeb images and vice versa. Images, loss of train and test images can be found below.

# %% [markdown]
# ### Preparation
#
# This includes cloning pytorch-CycleGAN-and-pix2pix git and the installation of visdom

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2337, done.
# remote: Total 2337 (delta 0), reused 0 (delta 0), pack-reused 2337
# Receiving objects: 100% (2337/2337), 8.09 MiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (1499/1499), done.

# %%
# !pip install dominate visdom
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#      |████████████████████████████████| 676 kB 377 bytes/s  0:00:01
# ...
#      |████████████████████████████████| 61 kB 3.4 kB/s eta 0:00:01
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=668534 sha256=12a3aa06d8b839fab13a5d290a1458a7668734086673a26881af1a5c7d8291f9
#   Stored in directory: /root/.cache/pip/wheels/2d/cd/fb/005445070865d4e45365b2946ee88085a7392370f152cf371c
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=6623 sha256=71db8572c52067beb0ee54435464a4b17833ff5bacacf9684bf57cabcc39e674
# ...

# %% [markdown]
# ## 1. horse2zebra

# %% [markdown]
# #### 1.1 Set up my visdom

# %%
# Set up my visdom
# On one terminal run:
#      python3 -m visdom.server
# On another terminal run:
#      unset http_proxy 
#      unset https_proxy

# %% [markdown]
# For some odd reasons these two command do not work for me, so i ran my code in the terminal instead.

# %%
# !cd pytorch-CycleGAN-and-pix2pix
# !./datasets/download_cyclegan_dataset.sh horse2zebra
# Out:
# /bin/sh: 1: ./datasets/download_cyclegan_dataset.sh: not found

# %% [markdown]
# #### 1.2 Train

# %%
# python3 train.py --dataroot ./datasets/horse2zebra --name horse2zebra_cyclegan --model cycle_gan > output_horse2zebra.txt

# %%
results = open("pytorch-CycleGAN-and-pix2pix/output_horse2zebra.txt", "r")
print(results.read())
# Out:
# Setting up a new session...
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/horse2zebra        	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
# ...

# %% [markdown]
# #### 1.3 Results

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('result_hz1.png')
plt.figure(figsize = (20,10))
imgplot = plt.imshow(img)
plt.show()

img2 = mpimg.imread('result_hz2.png')
plt.figure(figsize = (10,5))
imgplot = plt.imshow(img2)
plt.show()

img3 = mpimg.imread('result_hz3.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img3)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Discussion
# As shown above, it can be seen that the model is able to transform horse to zebra and vice versa. The resulting images and loss plots

# %% [markdown]
# ## 2. ait2celeb
#
# Training CycleGAN on ait student face dataset and celeb dataset was relatively simple. I started from downloading the datasets namely ait-ict.zip as well as celevA-264.zip by doing a !wget. Afterwards, I unzipped them and moved them to the corresponding folder in the corresponding format which is 'datasets/ait2celeb'. Inside, there are 2 folders called trainA and trainB. Then the training was just as simple as training on horses2zebra.

# %% [markdown]
# #### 2.1 Load datasets

# %%
# !wget http://www.cs.ait.ac.th/~mdailey/ait-ict.zip

# %%
# !wget http://www.cs.ait.ac.th/~mdailey/celebA-317.zip
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2021-03-09 12:10:08--  https://www.cs.ait.ac.th/~mdailey/celebA-317.zip
# Connecting to 192.41.170.23:3128... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 971794 (949K) [application/zip]
# Saving to: ‘celebA-317.zip’
#
# celebA-317.zip      100%[===================>] 949.02K  --.-KB/s    in 0.02s
#
# 2021-03-09 12:10:08 (52.0 MB/s) - ‘celebA-317.zip’ saved [971794/971794]

# %% [markdown]
# #### 2.2 Set up visdom

# %%
# Set up my visdom
# On one terminal run:
#      python3 -m visdom.server
# On another terminal run:
#      unset http_proxy 
#      unset https_proxy

# %% [markdown]
# #### 2.3 Train
#
# Also write results on a .txt file

# %%
# python3 train.py --dataroot ./datasets/ait2celeb --name ait2celeb_cyclegan --model cycle_gan > output_ait2celeb.txt

# %%
results = open("pytorch-CycleGAN-and-pix2pix/output_ait2celeb.txt", "r")
print(results.read())
# Out:
# Setting up a new session...
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/ait2celeb          	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 2
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                  lambda_A: 10.0
# ...

# %% [markdown]
# #### 2.4 Results

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('result_face.png')
plt.figure(figsize = (20,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Test results

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_fake_A.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img)
plt.show()

img2 = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_fake_B.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img2)
plt.show()

img3 = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_real_A.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img3)
plt.show()

img4 = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_real_B.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img4)
plt.show()

img5 = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_rec_A.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img5)
plt.show()

img6 = mpimg.imread('pytorch-CycleGAN-and-pix2pix/results/ait2celeb_cyclegan/test_latest/images/000271_rec_B.png')
plt.figure(figsize = (5,5))
imgplot = plt.imshow(img6)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### Discussion
#
# As shown above, after training for 200 epochs, despite, the convergence of losses, there is still room for improvement when look at the resulting images. This could be because the number of samples is less than that of horses2zebra.
